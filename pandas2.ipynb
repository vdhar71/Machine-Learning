# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_excel('/Users/vchitr014/Documents/AWS-Trusted-Advisor.xls')

df
# Out:
#                   Low Utilization Amazon EC2 Instances  \
# 0                         AWS Account ID: 287432581570
# 1    Description: Checks the Amazon Elastic Compute...
# 2                                      Status: warning
# 3                                              Summary
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                            Region/AZ
# 10                                          us-east-1b
# 11                                          us-east-1b
# 12                                          us-east-1b
# 13                                          us-east-1b
# 14                                          us-east-1b
# 15                                          us-east-1a
# 16                                          us-east-1b
# 17                                          us-east-1a
# 18                                          us-east-1a
# 19                                          us-east-1d
# 20                                          us-east-1a
# 21                                          us-east-1a
# 22                                          us-east-1a
# 23                                          us-east-1a
# 24                                          us-east-1a
# 25                                          us-east-1a
# 26                                          us-east-1a
# 27                                          us-east-1d
# 28                                          us-east-1b
# 29                                          us-east-1a
# ..                                                 ...
# 375                                         us-west-2b
# 376                                         us-west-2b
# 377                                         us-west-2b
# 378                                         us-west-2b
# 379                                         us-west-2b
# 380                                         us-west-2a
# 381                                         us-west-2a
# 382                                         us-west-2c
# 383                                         us-west-2b
# 384                                         us-west-2a
# 385                                         us-west-2a
# 386                                         us-west-2a
# 387                                         us-west-2b
# 388                                         us-west-2a
# 389                                         us-west-2c
# 390                                         us-west-2c
# 391                                         us-west-2a
# 392                                         us-west-2a
# 393                                         us-west-2c
# 394                                         us-west-2a
# 395                                         us-west-2c
# 396                                         us-west-2a
# 397                                         us-west-2c
# 398                                         us-west-2b
# 399                                         us-west-2b
# 400                                         us-west-2a
# 401                                         us-west-2c
# 402                                         us-west-2a
# 403                                         us-west-2a
# 404                                         us-west-2b
#
#                                    Unnamed: 1  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4    Total number of resources processed: 604
# 5            Number of resources flagged: 395
# 6           Number of suppressed resources: 0
# 7                  Monthly savings: $96193.34
# 8                                         NaN
# 9                                 Instance ID
# 10                        i-0b8c413d9408beffd
# 11                        i-04273cd6ba4f96e13
# 12                        i-06fdd339e4dd0c201
# 13                        i-0ea7b16baee2b6a4e
# 14                        i-0799accd01f99ced4
# 15                        i-06d31cee3dda4deef
# 16                        i-09cbdb36893061df2
# 17                        i-07fb4f02d91195d15
# 18                        i-0d1479acf8da50b79
# 19                                 i-05796685
# 20                        i-08e131de99f5df529
# 21                                 i-1ba68582
# 22                        i-0d7c1335eb078fbbc
# 23                                 i-ff2b7e66
# 24                        i-0ea5aae11f2dff98b
# 25                        i-0fb195dc77040aefd
# 26                        i-046db2ec47a78e978
# 27                        i-063b159a3eb19859a
# 28                        i-0e67624235981119f
# 29                        i-082b2f013ad943078
# ..                                        ...
# 375                       i-0644d7ce3fd34ac1c
# 376                       i-04672d63c22ccf398
# 377                       i-04dd1b3446d09d42e
# 378                       i-0130bd4dd18e6d454
# 379                       i-0c6da90e44073fa61
# 380                       i-0b21036a62bb8c15b
# 381                       i-09693da91e4b48924
# 382                       i-0eef23416ad0bc235
# 383                       i-0e06a4028aba142f8
# 384                       i-0e1279e2468a761f0
# 385                       i-0968e78091fa22a9e
# 386                       i-027a6ee33c4195cfe
# 387                       i-09595d133b3aa414f
# 388                       i-021d8edb75f24cf3d
# 389                       i-0adbda33e7af57464
# 390                       i-05bff8c0774270e7b
# 391                       i-0ecd40787b9b666b7
# 392                       i-0e4851b99203dfd38
# 393                       i-079c6439572c3dc8d
# 394                       i-0319137377b855c09
# 395                       i-027abbd572db684eb
# 396                       i-05e469826ac040b59
# 397                       i-05e1e56dda75b13c6
# 398                       i-0d54e9c0569920289
# 399                       i-002540052279ee66d
# 400                       i-07abd2d3f879ca525
# 401                       i-0717a93f09aa3e5e4
# 402                       i-047acb4371d2800f7
# 403                       i-04395870150b6739c
# 404                       i-04c9cb74f423207c9
#
#                                             Unnamed: 2     Unnamed: 3  \
# 0                                                  NaN            NaN
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# 5                                                  NaN            NaN
# 6                                                  NaN            NaN
# 7                                                  NaN            NaN
# 8                                                  NaN            NaN
# 9                                        Instance Name  Instance Type
# 10                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 11                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 12                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 13                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 14                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 15                    cbelkdata-e1a-01s.cb.comcast.net      i3.xlarge
# 16                    odprabbit-e1b-01.odp.comcast.net      c4.xlarge
# 17                                    cb-puppet-master      t2.xlarge
# 18                          new-dev-elk-master-node-1a     m4.2xlarge
# 19                                     Cassandra-dev-2     c3.4xlarge
# 20                   odpcworker-e1a-02.odp.comcast.net     c4.2xlarge
# 21                        cbapi-e1a-04s.cb.comcast.net      c4.xlarge
# 22                    odprabbit-e1a-03.odp.comcast.net      c4.xlarge
# 23                         cbapi-e1a-02.cb.comcast.net      c4.xlarge
# 24                   odpcworker-e1a-01.odp.comcast.net     c4.2xlarge
# 25                   cbelkweb-e1a-01stg.cb.comcast.net       m4.large
# 26                     odpredis-e1a-03.odp.comcast.net      c4.xlarge
# 27                                         django_test       m4.large
# 28                                      CB-STG-NODE-1B     m4.4xlarge
# 29                   odpcworker-e1a-03.odp.comcast.net     c4.2xlarge
# ..                                                 ...            ...
# 375                    odpsprkw-w2b-09.odp.comcast.net     m4.4xlarge
# 376                     odphook-w2b-04.odp.comcast.net     c4.2xlarge
# 377                  odpcworker-w2b-01.odp.comcast.net     c4.2xlarge
# 378                       odplb-w2b-04.odp.comcast.net      c4.xlarge
# 379  optimizer-chi-01.prod.us-west-2.plume.comcast.net      c4.xlarge
# 380                    odpsprkw-w2a-01.odp.comcast.net     m4.4xlarge
# 381                      odpque-w2a-04.odp.comcast.net      c4.xlarge
# 382   rabbitmq-chi-03.prod.us-west-2.plume.comcast.net      m4.xlarge
# 383                       odplb-w2b-02.odp.comcast.net      c4.xlarge
# 384                      odpzoo-w2a-02.odp.comcast.net      c4.xlarge
# 385                     odpsync-w2a-05.odp.comcast.net     c4.2xlarge
# 386  mongodb-production-04.shared.us-west-2.plume.c...       m4.large
# 387                     odpsync-w2b-03.odp.comcast.net     c4.2xlarge
# 388    es-es-esdata-02.inf.us-west-2.plume.comcast.net      i2.xlarge
# 389  controllershardv2-chi-02.prod.us-west-2.plume....      m4.xlarge
# 390                    odpsprkw-w2c-10.odp.comcast.net     m4.4xlarge
# 391                    odpsprkw-w2a-05.odp.comcast.net     m4.4xlarge
# 392                     odpcore-w2a-05.odp.comcast.net     c4.2xlarge
# 393                    odpsprkw-w2c-13.odp.comcast.net     m4.4xlarge
# 394                    odpsprkw-w2a-12.odp.comcast.net     m4.4xlarge
# 395                    odpsprkw-w2c-06.odp.comcast.net     m4.4xlarge
# 396                    odpsprkw-w2a-09.odp.comcast.net     m4.4xlarge
# 397                       odplb-w2c-01.odp.comcast.net      c4.xlarge
# 398                    odpredis-w2b-02.odp.comcast.net      c4.xlarge
# 399                     odpcore-w2b-07.odp.comcast.net     c4.2xlarge
# 400  rabbitmq-production-01.shared.us-west-2.plume....       c4.large
# 401                       odplb-w2c-03.odp.comcast.net      c4.xlarge
# 402                     odpsync-w2a-01.odp.comcast.net     c4.2xlarge
# 403                     odpcore-w2a-08.odp.comcast.net     c4.2xlarge
# 404                     odpcore-w2b-05.odp.comcast.net     c4.2xlarge
#
#                     Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# 0                          NaN           NaN           NaN           NaN
# 1                          NaN           NaN           NaN           NaN
# 2                          NaN           NaN           NaN           NaN
# 3                          NaN           NaN           NaN           NaN
# 4                          NaN           NaN           NaN           NaN
# 5                          NaN           NaN           NaN           NaN
# 6                          NaN           NaN           NaN           NaN
# 7                          NaN           NaN           NaN           NaN
# 8                          NaN           NaN           NaN           NaN
# 9    Estimated Monthly Savings         Day 1         Day 2         Day 3
# 10                     $136.80  0.7%  3.12MB  0.6%  0.08MB  0.5%  0.08MB
# 11                     $136.80  0.7%  3.02MB  0.6%  0.08MB  0.5%  0.08MB
# 12                     $136.80  0.6%  3.13MB  0.5%  0.08MB  0.5%  0.08MB
# 13                     $123.12  0.6%  3.05MB  0.5%  0.08MB  0.5%  0.08MB
# 14                     $136.80  0.6%  3.05MB  0.6%  0.09MB  0.6%  0.10MB
# 15                     $224.64  0.5%  0.08MB  0.5%  0.08MB  0.5%  0.09MB
# 16                     $143.28  1.5%  1.78MB  1.5%  1.83MB  1.5%  1.81MB
# 17                     $135.36  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 18                     $288.00  0.1%  2.24MB  0.1%  2.24MB  0.1%  2.24MB
# 19                     $604.80  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 20                     $286.56  0.7%  0.86MB  0.7%  0.91MB  0.6%  0.87MB
# 21                     $143.28  0.9%  0.17MB  1.0%  0.17MB  0.9%  0.17MB
# 22                     $143.28  1.0%  0.60MB  1.0%  0.64MB  1.0%  0.62MB
# 23                      $40.94  0.8%  0.16MB  0.9%  0.16MB  0.8%  0.16MB
# 24                     $286.56  0.9%  0.87MB  0.9%  0.92MB  0.8%  0.88MB
# 25                      $72.00  0.1%  0.11MB  0.1%  0.10MB  0.1%  0.11MB
# 26                     $143.28  0.9%  0.84MB  0.9%  0.85MB  0.9%  0.83MB
# 27                      $72.00  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 28                     $576.00  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 29                     $286.56  1.0%  0.85MB  1.0%  0.88MB  0.9%  0.88MB
# ..                         ...           ...           ...           ...
# 375                    $164.57  0.4%  5.26MB  0.4%  5.29MB  0.4%  5.28MB
# 376                    $286.56  0.5%  0.39MB  0.5%  0.42MB  0.5%  0.42MB
# 377                    $286.56  1.0%  0.21MB  0.8%  0.73MB  0.8%  0.72MB
# 378                    $143.28  1.4%  3.03MB  1.4%  3.20MB  1.4%  3.19MB
# 379                    $143.28  1.3%  0.15MB  0.5%  0.14MB  0.3%  0.13MB
# 380                    $576.00  0.3%  0.50MB  0.3%  0.44MB  0.3%  0.45MB
# 381                    $112.58  1.7%  0.23MB  1.7%  0.26MB  1.7%  0.26MB
# 382                    $133.71  0.6%  2.38MB  0.6%  2.83MB  0.6%  2.45MB
# 383                    $143.28  1.2%  3.02MB  1.2%  3.05MB  1.2%  3.05MB
# 384                    $143.28  1.5%  0.21MB  1.5%  0.24MB  1.5%  0.24MB
# 385                    $286.56  1.0%  0.59MB  1.0%  0.62MB  1.0%  0.62MB
# 386                     $72.00  0.4%  0.25MB  0.4%  0.25MB  0.4%  0.25MB
# 387                    $286.56  1.0%  0.59MB  1.0%  0.62MB  1.0%  0.62MB
# 388                    $438.69  2.4%  4.30MB  2.4%  4.31MB  2.5%  4.30MB
# 389                    $144.00  0.5%  0.03MB  0.4%  0.03MB  0.5%  0.03MB
# 390                    $452.57  0.5%  6.39MB  0.5%  6.43MB  0.5%  6.44MB
# 391                    $576.00  0.3%  0.49MB  0.3%  0.44MB  0.3%  0.44MB
# 392                    $286.56  1.1%  0.69MB  1.2%  0.70MB  1.2%  0.70MB
# 393                    $452.57  0.5%  7.50MB  0.6%  7.54MB  0.5%  7.52MB
# 394                    $576.00  0.3%  0.49MB  0.3%  0.44MB  0.3%  0.44MB
# 395                    $452.57  0.4%  5.70MB  0.4%  5.75MB  0.4%  5.74MB
# 396                    $576.00  0.2%  0.43MB  0.2%  0.37MB  0.2%  0.37MB
# 397                    $143.28  1.4%  2.81MB  1.5%  2.84MB  1.5%  2.84MB
# 398                    $143.28  1.0%  0.57MB  1.1%  0.60MB  1.1%  0.60MB
# 399                    $286.56  0.7%  0.68MB  0.7%  0.71MB  0.7%  0.71MB
# 400                     $72.00  0.4%  0.09MB  0.4%  0.09MB  0.4%  0.09MB
# 401                    $143.28  1.2%  2.82MB  1.2%  2.85MB  1.2%  2.86MB
# 402                    $286.56  1.1%  0.59MB  1.1%  0.61MB  1.1%  0.61MB
# 403                    $286.56  1.1%  0.69MB  1.1%  0.70MB  1.1%  0.70MB
# 404                    $286.56  0.7%  0.66MB  0.7%  0.69MB  0.7%  0.69MB
#
#        Unnamed: 8    Unnamed: 9               ...                \
# 0             NaN           NaN               ...
# 1             NaN           NaN               ...
# 2             NaN           NaN               ...
# 3             NaN           NaN               ...
# 4             NaN           NaN               ...
# 5             NaN           NaN               ...
# 6             NaN           NaN               ...
# 7             NaN           NaN               ...
# 8             NaN           NaN               ...
# 9           Day 4         Day 5               ...
# 10   0.5%  0.60MB  0.7%  7.07MB               ...
# 11   0.6%  0.60MB  0.7%  7.18MB               ...
# 12   0.6%  0.64MB  0.7%  7.70MB               ...
# 13   0.6%  0.60MB  0.8%  7.12MB               ...
# 14   0.5%  0.61MB  0.8%  6.97MB               ...
# 15   0.5%  0.10MB  0.5%  0.07MB               ...
# 16   1.4%  1.84MB  1.5%  1.83MB               ...
# 17   0.0%  0.00MB  0.0%  0.00MB               ...
# 18   0.1%  2.24MB  0.1%  2.24MB               ...
# 19   0.0%  0.00MB  0.0%  0.00MB               ...
# 20   0.6%  0.90MB  0.6%  0.87MB               ...
# 21   0.9%  0.17MB  0.9%  0.17MB               ...
# 22   1.0%  0.63MB  1.0%  0.62MB               ...
# 23   0.8%  0.16MB  8.3%  6.04MB               ...
# 24   0.8%  0.91MB  0.8%  0.88MB               ...
# 25   0.1%  0.10MB  0.1%  0.11MB               ...
# 26   0.9%  0.83MB  0.9%  0.84MB               ...
# 27   0.0%  0.00MB  0.0%  0.00MB               ...
# 28   0.0%  0.00MB  0.0%  0.00MB               ...
# 29   0.8%  0.90MB  1.0%  0.88MB               ...
# ..            ...           ...               ...
# 375  0.4%  5.29MB  0.4%  5.29MB               ...
# 376  0.5%  0.43MB  0.5%  0.43MB               ...
# 377  0.8%  0.73MB  0.8%  0.73MB               ...
# 378  1.4%  3.20MB  1.6%  3.21MB               ...
# 379  0.5%  0.13MB  0.4%  0.17MB               ...
# 380  0.3%  0.45MB  0.3%  0.46MB               ...
# 381  1.8%  0.26MB  1.8%  0.26MB               ...
# 382  0.6%  2.24MB  0.6%  2.25MB               ...
# 383  1.2%  3.05MB  1.2%  3.06MB               ...
# 384  1.5%  0.24MB  1.5%  0.24MB               ...
# 385  0.9%  0.62MB  0.8%  0.62MB               ...
# 386  0.4%  0.25MB  0.4%  0.25MB               ...
# 387  1.0%  0.62MB  1.0%  0.63MB               ...
# 388  2.5%  4.32MB  2.5%  4.31MB               ...
# 389  0.5%  0.03MB  0.5%  0.08MB               ...
# 390  0.4%  2.76MB  0.4%  1.96MB               ...
# 391  0.3%  0.44MB  0.3%  0.45MB               ...
# 392  1.0%  0.70MB  1.0%  0.71MB               ...
# 393  0.5%  2.94MB  0.4%  1.98MB               ...
# 394  0.3%  0.44MB  0.3%  0.45MB               ...
# 395  0.4%  2.67MB  0.3%  1.97MB               ...
# 396  0.3%  0.38MB  0.3%  0.38MB               ...
# 397  1.5%  2.84MB  1.5%  2.79MB               ...
# 398  1.1%  0.60MB  1.1%  0.60MB               ...
# 399  0.7%  0.71MB  0.8%  0.72MB               ...
# 400  0.4%  0.09MB  0.4%  0.09MB               ...
# 401  1.2%  2.85MB  1.2%  2.81MB               ...
# 402  1.1%  0.62MB  1.1%  0.62MB               ...
# 403  1.1%  0.71MB  1.1%  0.71MB               ...
# 404  0.7%  0.69MB  0.7%  0.70MB               ...
#
#         Unnamed: 12    Unnamed: 13    Unnamed: 14    Unnamed: 15  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# 5               NaN            NaN            NaN            NaN
# 6               NaN            NaN            NaN            NaN
# 7               NaN            NaN            NaN            NaN
# 8               NaN            NaN            NaN            NaN
# 9             Day 8          Day 9         Day 10         Day 11
# 10     0.5%  0.41MB   0.5%  0.08MB   0.5%  0.08MB  3.5%  19.02MB
# 11     0.5%  0.21MB   0.5%  0.08MB   0.5%  0.08MB  3.9%  14.50MB
# 12     0.5%  0.40MB   0.5%  0.08MB   0.5%  0.08MB  2.3%  11.53MB
# 13     0.6%  0.40MB   0.5%  0.08MB   0.5%  0.08MB  4.1%  17.81MB
# 14     0.6%  0.08MB   0.6%  0.08MB   0.6%  0.08MB  2.9%  14.51MB
# 15     0.5%  0.09MB   0.5%  0.09MB   0.5%  0.10MB   0.5%  0.11MB
# 16     1.4%  1.85MB   1.4%  1.88MB   1.4%  1.87MB   1.4%  1.91MB
# 17     0.0%  0.00MB   0.0%  0.00MB   0.0%  0.01MB   0.0%  0.00MB
# 18     0.1%  2.26MB   0.1%  2.24MB   0.1%  2.24MB   0.1%  2.26MB
# 19     0.0%  0.00MB   0.0%  0.00MB   0.0%  0.00MB   0.0%  0.00MB
# 20     0.7%  0.87MB   0.7%  0.90MB   0.6%  0.87MB   0.6%  0.86MB
# 21     0.9%  0.17MB   0.9%  0.17MB   0.9%  0.17MB   0.9%  0.17MB
# 22     1.0%  0.63MB   1.0%  0.64MB   1.1%  0.62MB   1.1%  0.62MB
# 23   19.5%  14.82MB  14.5%  9.92MB  14.5%  9.94MB  14.2%  9.86MB
# 24     1.0%  0.88MB   1.0%  0.87MB   1.0%  0.88MB   1.0%  0.87MB
# 25     0.1%  0.11MB   0.1%  0.11MB   0.2%  0.11MB   0.1%  0.11MB
# 26     0.9%  0.97MB   1.0%  0.93MB   1.0%  0.67MB   0.8%  0.73MB
# 27     0.0%  0.00MB   0.0%  0.00MB   0.0%  0.00MB   0.0%  0.00MB
# 28     0.0%  0.00MB   0.0%  0.00MB   0.0%  0.00MB   0.0%  0.00MB
# 29     1.0%  0.88MB   1.1%  0.91MB   1.0%  0.88MB   1.0%  0.88MB
# ..              ...            ...            ...            ...
# 375    0.4%  5.30MB   0.4%  5.33MB   0.4%  5.30MB   0.4%  4.90MB
# 376    0.6%  0.43MB   0.6%  0.46MB   0.6%  0.43MB   0.5%  0.41MB
# 377    0.8%  0.56MB   0.8%  0.56MB   0.8%  0.56MB   0.8%  0.56MB
# 378    1.4%  2.91MB   1.4%  2.91MB   1.4%  2.91MB   1.4%  2.91MB
# 379    2.2%  0.16MB   1.1%  0.16MB   1.2%  0.15MB   1.4%  0.16MB
# 380    0.3%  0.43MB   0.3%  0.46MB   0.3%  0.43MB   0.3%  0.39MB
# 381    1.7%  0.25MB   1.7%  0.25MB   1.7%  0.25MB  2.9%  23.90MB
# 382    0.7%  2.90MB   0.7%  2.96MB   0.7%  3.16MB   0.7%  3.30MB
# 383    1.2%  3.06MB   1.2%  3.06MB   1.2%  3.06MB   1.2%  3.06MB
# 384    1.5%  0.23MB   1.5%  0.23MB   1.5%  0.23MB   1.5%  0.23MB
# 385    0.9%  0.62MB   0.8%  0.63MB   0.7%  0.63MB   0.7%  0.58MB
# 386    0.4%  0.25MB   0.5%  0.25MB   0.5%  0.25MB   0.4%  0.25MB
# 387    1.0%  0.63MB   1.0%  0.62MB   1.0%  0.62MB   1.0%  0.58MB
# 388    2.6%  5.38MB   2.7%  5.38MB   2.8%  5.40MB   2.9%  4.43MB
# 389    0.5%  0.08MB   0.4%  0.03MB   0.5%  0.03MB   0.5%  0.03MB
# 390    0.4%  0.44MB   0.4%  0.46MB   0.4%  0.44MB   0.4%  0.38MB
# 391    0.3%  0.42MB   0.3%  0.45MB   0.3%  0.42MB   0.3%  0.38MB
# 392    1.2%  0.70MB   1.2%  0.70MB   1.1%  0.70MB   1.1%  0.66MB
# 393    0.4%  0.46MB   0.4%  0.48MB   0.4%  0.46MB   0.4%  0.40MB
# 394    0.3%  0.41MB   0.3%  0.44MB   0.3%  0.41MB   0.3%  0.37MB
# 395    0.3%  0.44MB   0.3%  0.47MB   0.3%  0.44MB   0.3%  0.38MB
# 396    0.3%  0.36MB   0.2%  0.40MB   0.3%  0.37MB   0.2%  0.33MB
# 397    1.5%  2.47MB   1.5%  2.47MB   1.5%  2.47MB   1.5%  2.47MB
# 398    1.1%  0.59MB   1.3%  0.59MB   1.3%  0.59MB   1.2%  0.59MB
# 399    0.8%  0.71MB   0.8%  0.71MB   0.8%  0.71MB   0.7%  0.66MB
# 400    0.5%  0.09MB   0.5%  0.09MB   0.5%  0.09MB   0.5%  0.09MB
# 401    1.0%  2.19MB   1.0%  2.19MB   1.0%  2.19MB   1.0%  2.19MB
# 402    1.0%  0.62MB   1.1%  0.62MB   1.0%  0.62MB   1.0%  0.57MB
# 403    1.1%  0.70MB   1.1%  0.70MB   1.1%  0.71MB   1.1%  0.66MB
# 404    0.7%  0.69MB   0.7%  0.69MB   0.7%  0.69MB   0.7%  0.65MB
#
#          Unnamed: 16    Unnamed: 17    Unnamed: 18  \
# 0                NaN            NaN            NaN
# 1                NaN            NaN            NaN
# 2                NaN            NaN            NaN
# 3                NaN            NaN            NaN
# 4                NaN            NaN            NaN
# 5                NaN            NaN            NaN
# 6                NaN            NaN            NaN
# 7                NaN            NaN            NaN
# 8                NaN            NaN            NaN
# 9             Day 12         Day 13         Day 14
# 10      0.8%  1.68MB   2.1%  2.85MB   5.2%  8.29MB
# 11      0.6%  0.77MB   3.7%  9.70MB   5.1%  8.11MB
# 12      0.7%  1.42MB   2.5%  4.47MB   5.3%  7.71MB
# 13      0.6%  0.90MB   3.5%  8.75MB   5.1%  7.69MB
# 14      0.9%  1.70MB   3.7%  9.27MB   5.2%  7.86MB
# 15      0.5%  0.08MB   0.5%  0.09MB   0.5%  0.10MB
# 16      1.4%  1.86MB   1.4%  1.82MB   1.4%  1.87MB
# 17      0.0%  0.01MB   0.0%  0.00MB   0.0%  0.00MB
# 18      0.1%  2.27MB   0.1%  2.24MB   0.1%  2.24MB
# 19      0.0%  0.00MB   0.0%  0.00MB   0.0%  0.00MB
# 20      0.6%  0.81MB   0.7%  0.88MB   0.7%  0.87MB
# 21      0.9%  0.17MB   0.9%  0.17MB   0.9%  0.17MB
# 22      1.0%  0.56MB   1.1%  0.35MB   1.2%  0.36MB
# 23     14.1%  9.82MB  14.1%  9.86MB  14.0%  9.91MB
# 24      0.9%  0.82MB   1.0%  0.91MB   1.0%  0.88MB
# 25      0.1%  0.11MB   0.1%  0.10MB   0.1%  0.11MB
# 26      0.8%  0.93MB   0.9%  0.93MB   0.9%  1.00MB
# 27      0.0%  0.03MB   0.0%  0.00MB   0.0%  0.00MB
# 28      0.0%  0.03MB   0.0%  0.00MB   0.0%  0.00MB
# 29      0.9%  0.81MB   1.0%  0.89MB   1.0%  0.88MB
# ..               ...            ...            ...
# 375     0.3%  0.42MB   0.3%  0.41MB   0.3%  1.42MB
# 376     0.6%  0.43MB   0.6%  0.42MB   0.7%  0.78MB
# 377     0.9%  0.75MB   0.9%  0.71MB   0.9%  0.71MB
# 378     1.5%  2.87MB   1.5%  2.87MB   1.7%  3.17MB
# 379     1.3%  0.19MB   2.0%  0.16MB   2.8%  0.18MB
# 380     0.2%  0.09MB   0.2%  0.09MB   0.3%  1.99MB
# 381  18.4%  350.58MB   2.4%  3.80MB   2.6%  7.53MB
# 382     0.7%  3.37MB   0.7%  4.86MB   0.8%  5.23MB
# 383     1.2%  3.00MB   1.2%  3.00MB   1.3%  4.53MB
# 384     1.5%  0.23MB   1.5%  0.22MB   1.4%  0.24MB
# 385     0.8%  0.68MB   0.7%  0.60MB   0.7%  0.63MB
# 386     0.5%  0.25MB   0.5%  0.25MB   0.4%  0.25MB
# 387     1.0%  0.66MB   1.0%  0.60MB   1.0%  0.62MB
# 388     2.6%  4.38MB   2.4%  4.49MB   2.5%  4.48MB
# 389     0.5%  0.08MB   0.4%  0.03MB   0.4%  0.03MB
# 390     0.4%  0.42MB   0.3%  0.42MB   0.3%  1.40MB
# 391     0.2%  0.10MB   0.2%  0.10MB   0.3%  2.01MB
# 392     1.1%  0.77MB   1.1%  0.68MB   1.1%  0.98MB
# 393     0.4%  0.44MB   0.3%  0.44MB   0.4%  1.43MB
# 394     0.2%  0.08MB   0.2%  0.08MB   0.2%  2.22MB
# 395     0.3%  0.43MB   0.2%  0.42MB   0.3%  1.57MB
# 396     0.2%  0.09MB   0.2%  0.09MB   0.3%  2.55MB
# 397     1.5%  2.48MB   1.5%  2.74MB   1.6%  4.05MB
# 398     1.2%  0.59MB   1.1%  0.59MB   1.1%  0.66MB
# 399     0.8%  0.75MB   0.7%  0.70MB   0.8%  0.71MB
# 400     0.5%  0.09MB   0.5%  0.09MB   0.5%  0.09MB
# 401     1.0%  2.21MB   1.0%  2.47MB   1.2%  2.75MB
# 402     1.1%  0.67MB   1.1%  0.59MB   1.1%  0.63MB
# 403     1.2%  0.76MB   1.2%  0.68MB   1.2%  0.95MB
# 404     0.7%  0.73MB   0.7%  0.67MB   0.8%  0.69MB
#
#                         Unnamed: 19                 Unnamed: 20  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# 5                               NaN                         NaN
# 6                               NaN                         NaN
# 7                               NaN                         NaN
# 8                               NaN                         NaN
# 9    14-Day Average CPU Utilization  14-Day Average Network I/O
# 10                             1.3%                      3.61MB
# 11                             1.4%                      3.29MB
# 12                             1.2%                      3.21MB
# 13                             1.4%                      3.82MB
# 14                             1.3%                      3.29MB
# 15                             0.5%                      0.09MB
# 16                             1.4%                      1.85MB
# 17                             0.0%                      0.00MB
# 18                             0.1%                      2.24MB
# 19                             0.0%                      0.00MB
# 20                             0.6%                      0.87MB
# 21                             0.9%                      0.17MB
# 22                             1.0%                      0.58MB
# 23                            11.0%                      7.82MB
# 24                             0.9%                      0.88MB
# 25                             0.1%                      0.11MB
# 26                             0.9%                      0.86MB
# 27                             0.0%                      0.00MB
# 28                             0.0%                      0.00MB
# 29                             1.0%                      0.88MB
# ..                              ...                         ...
# 375                            0.3%                      4.29MB
# 376                            0.6%                      0.45MB
# 377                            0.8%                      0.62MB
# 378                            1.5%                      3.05MB
# 379                            1.4%                      0.16MB
# 380                            0.3%                      0.51MB
# 381                            3.1%                     27.74MB
# 382                            0.7%                      3.13MB
# 383                            1.2%                      3.15MB
# 384                            1.5%                      0.23MB
# 385                            0.8%                      0.62MB
# 386                            0.4%                      0.25MB
# 387                            1.0%                      0.62MB
# 388                            2.6%                      4.70MB
# 389                            0.5%                      0.04MB
# 390                            0.4%                      2.06MB
# 391                            0.3%                      0.50MB
# 392                            1.1%                      0.72MB
# 393                            0.4%                      2.32MB
# 394                            0.3%                      0.51MB
# 395                            0.3%                      1.92MB
# 396                            0.2%                      0.49MB
# 397                            1.5%                      2.73MB
# 398                            1.1%                      0.60MB
# 399                            0.8%                      0.71MB
# 400                            0.5%                      0.09MB
# 401                            1.1%                      2.52MB
# 402                            1.1%                      0.62MB
# 403                            1.1%                      0.72MB
# 404                            0.7%                      0.69MB
#
#                         Unnamed: 21
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9    Number of Days Low Utilization
# 10                          10 days
# 11                          10 days
# 12                          10 days
# 13                           9 days
# 14                          10 days
# 15                          14 days
# 16                          14 days
# 17                          14 days
# 18                          14 days
# 19                          14 days
# 20                          14 days
# 21                          14 days
# 22                          14 days
# 23                           4 days
# 24                          14 days
# 25                          14 days
# 26                          14 days
# 27                          14 days
# 28                          14 days
# 29                          14 days
# ..                              ...
# 375                          4 days
# 376                         14 days
# 377                         14 days
# 378                         14 days
# 379                         14 days
# 380                         14 days
# 381                         11 days
# 382                         13 days
# 383                         14 days
# 384                         14 days
# 385                         14 days
# 386                         14 days
# 387                         14 days
# 388                         10 days
# 389                         14 days
# 390                         11 days
# 391                         14 days
# 392                         14 days
# 393                         11 days
# 394                         14 days
# 395                         11 days
# 396                         14 days
# 397                         14 days
# 398                         14 days
# 399                         14 days
# 400                         14 days
# 401                         14 days
# 402                         14 days
# 403                         14 days
# 404                         14 days
#
# [405 rows x 22 columns]

# %%
df.tail(20)
# Out:
#     Low Utilization Amazon EC2 Instances           Unnamed: 1  \
# 385                           us-west-2a  i-0968e78091fa22a9e
# 386                           us-west-2a  i-027a6ee33c4195cfe
# 387                           us-west-2b  i-09595d133b3aa414f
# 388                           us-west-2a  i-021d8edb75f24cf3d
# 389                           us-west-2c  i-0adbda33e7af57464
# 390                           us-west-2c  i-05bff8c0774270e7b
# 391                           us-west-2a  i-0ecd40787b9b666b7
# 392                           us-west-2a  i-0e4851b99203dfd38
# 393                           us-west-2c  i-079c6439572c3dc8d
# 394                           us-west-2a  i-0319137377b855c09
# 395                           us-west-2c  i-027abbd572db684eb
# 396                           us-west-2a  i-05e469826ac040b59
# 397                           us-west-2c  i-05e1e56dda75b13c6
# 398                           us-west-2b  i-0d54e9c0569920289
# 399                           us-west-2b  i-002540052279ee66d
# 400                           us-west-2a  i-07abd2d3f879ca525
# 401                           us-west-2c  i-0717a93f09aa3e5e4
# 402                           us-west-2a  i-047acb4371d2800f7
# 403                           us-west-2a  i-04395870150b6739c
# 404                           us-west-2b  i-04c9cb74f423207c9
#
#                                             Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 385                     odpsync-w2a-05.odp.comcast.net  c4.2xlarge    $286.56
# 386  mongodb-production-04.shared.us-west-2.plume.c...    m4.large     $72.00
# 387                     odpsync-w2b-03.odp.comcast.net  c4.2xlarge    $286.56
# 388    es-es-esdata-02.inf.us-west-2.plume.comcast.net   i2.xlarge    $438.69
# 389  controllershardv2-chi-02.prod.us-west-2.plume....   m4.xlarge    $144.00
# 390                    odpsprkw-w2c-10.odp.comcast.net  m4.4xlarge    $452.57
# 391                    odpsprkw-w2a-05.odp.comcast.net  m4.4xlarge    $576.00
# 392                     odpcore-w2a-05.odp.comcast.net  c4.2xlarge    $286.56
# 393                    odpsprkw-w2c-13.odp.comcast.net  m4.4xlarge    $452.57
# 394                    odpsprkw-w2a-12.odp.comcast.net  m4.4xlarge    $576.00
# 395                    odpsprkw-w2c-06.odp.comcast.net  m4.4xlarge    $452.57
# 396                    odpsprkw-w2a-09.odp.comcast.net  m4.4xlarge    $576.00
# 397                       odplb-w2c-01.odp.comcast.net   c4.xlarge    $143.28
# 398                    odpredis-w2b-02.odp.comcast.net   c4.xlarge    $143.28
# 399                     odpcore-w2b-07.odp.comcast.net  c4.2xlarge    $286.56
# 400  rabbitmq-production-01.shared.us-west-2.plume....    c4.large     $72.00
# 401                       odplb-w2c-03.odp.comcast.net   c4.xlarge    $143.28
# 402                     odpsync-w2a-01.odp.comcast.net  c4.2xlarge    $286.56
# 403                     odpcore-w2a-08.odp.comcast.net  c4.2xlarge    $286.56
# 404                     odpcore-w2b-05.odp.comcast.net  c4.2xlarge    $286.56
#
#        Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 385  1.0%  0.59MB  1.0%  0.62MB  1.0%  0.62MB  0.9%  0.62MB  0.8%  0.62MB
# 386  0.4%  0.25MB  0.4%  0.25MB  0.4%  0.25MB  0.4%  0.25MB  0.4%  0.25MB
# 387  1.0%  0.59MB  1.0%  0.62MB  1.0%  0.62MB  1.0%  0.62MB  1.0%  0.63MB
# 388  2.4%  4.30MB  2.4%  4.31MB  2.5%  4.30MB  2.5%  4.32MB  2.5%  4.31MB
# 389  0.5%  0.03MB  0.4%  0.03MB  0.5%  0.03MB  0.5%  0.03MB  0.5%  0.08MB
# 390  0.5%  6.39MB  0.5%  6.43MB  0.5%  6.44MB  0.4%  2.76MB  0.4%  1.96MB
# 391  0.3%  0.49MB  0.3%  0.44MB  0.3%  0.44MB  0.3%  0.44MB  0.3%  0.45MB
# 392  1.1%  0.69MB  1.2%  0.70MB  1.2%  0.70MB  1.0%  0.70MB  1.0%  0.71MB
# 393  0.5%  7.50MB  0.6%  7.54MB  0.5%  7.52MB  0.5%  2.94MB  0.4%  1.98MB
# 394  0.3%  0.49MB  0.3%  0.44MB  0.3%  0.44MB  0.3%  0.44MB  0.3%  0.45MB
# 395  0.4%  5.70MB  0.4%  5.75MB  0.4%  5.74MB  0.4%  2.67MB  0.3%  1.97MB
# 396  0.2%  0.43MB  0.2%  0.37MB  0.2%  0.37MB  0.3%  0.38MB  0.3%  0.38MB
# 397  1.4%  2.81MB  1.5%  2.84MB  1.5%  2.84MB  1.5%  2.84MB  1.5%  2.79MB
# 398  1.0%  0.57MB  1.1%  0.60MB  1.1%  0.60MB  1.1%  0.60MB  1.1%  0.60MB
# 399  0.7%  0.68MB  0.7%  0.71MB  0.7%  0.71MB  0.7%  0.71MB  0.8%  0.72MB
# 400  0.4%  0.09MB  0.4%  0.09MB  0.4%  0.09MB  0.4%  0.09MB  0.4%  0.09MB
# 401  1.2%  2.82MB  1.2%  2.85MB  1.2%  2.86MB  1.2%  2.85MB  1.2%  2.81MB
# 402  1.1%  0.59MB  1.1%  0.61MB  1.1%  0.61MB  1.1%  0.62MB  1.1%  0.62MB
# 403  1.1%  0.69MB  1.1%  0.70MB  1.1%  0.70MB  1.1%  0.71MB  1.1%  0.71MB
# 404  0.7%  0.66MB  0.7%  0.69MB  0.7%  0.69MB  0.7%  0.69MB  0.7%  0.70MB
#
#         ...       Unnamed: 12   Unnamed: 13   Unnamed: 14   Unnamed: 15  \
# 385     ...      0.9%  0.62MB  0.8%  0.63MB  0.7%  0.63MB  0.7%  0.58MB
# 386     ...      0.4%  0.25MB  0.5%  0.25MB  0.5%  0.25MB  0.4%  0.25MB
# 387     ...      1.0%  0.63MB  1.0%  0.62MB  1.0%  0.62MB  1.0%  0.58MB
# 388     ...      2.6%  5.38MB  2.7%  5.38MB  2.8%  5.40MB  2.9%  4.43MB
# 389     ...      0.5%  0.08MB  0.4%  0.03MB  0.5%  0.03MB  0.5%  0.03MB
# 390     ...      0.4%  0.44MB  0.4%  0.46MB  0.4%  0.44MB  0.4%  0.38MB
# 391     ...      0.3%  0.42MB  0.3%  0.45MB  0.3%  0.42MB  0.3%  0.38MB
# 392     ...      1.2%  0.70MB  1.2%  0.70MB  1.1%  0.70MB  1.1%  0.66MB
# 393     ...      0.4%  0.46MB  0.4%  0.48MB  0.4%  0.46MB  0.4%  0.40MB
# 394     ...      0.3%  0.41MB  0.3%  0.44MB  0.3%  0.41MB  0.3%  0.37MB
# 395     ...      0.3%  0.44MB  0.3%  0.47MB  0.3%  0.44MB  0.3%  0.38MB
# 396     ...      0.3%  0.36MB  0.2%  0.40MB  0.3%  0.37MB  0.2%  0.33MB
# 397     ...      1.5%  2.47MB  1.5%  2.47MB  1.5%  2.47MB  1.5%  2.47MB
# 398     ...      1.1%  0.59MB  1.3%  0.59MB  1.3%  0.59MB  1.2%  0.59MB
# 399     ...      0.8%  0.71MB  0.8%  0.71MB  0.8%  0.71MB  0.7%  0.66MB
# 400     ...      0.5%  0.09MB  0.5%  0.09MB  0.5%  0.09MB  0.5%  0.09MB
# 401     ...      1.0%  2.19MB  1.0%  2.19MB  1.0%  2.19MB  1.0%  2.19MB
# 402     ...      1.0%  0.62MB  1.1%  0.62MB  1.0%  0.62MB  1.0%  0.57MB
# 403     ...      1.1%  0.70MB  1.1%  0.70MB  1.1%  0.71MB  1.1%  0.66MB
# 404     ...      0.7%  0.69MB  0.7%  0.69MB  0.7%  0.69MB  0.7%  0.65MB
#
#       Unnamed: 16   Unnamed: 17   Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 385  0.8%  0.68MB  0.7%  0.60MB  0.7%  0.63MB        0.8%      0.62MB
# 386  0.5%  0.25MB  0.5%  0.25MB  0.4%  0.25MB        0.4%      0.25MB
# 387  1.0%  0.66MB  1.0%  0.60MB  1.0%  0.62MB        1.0%      0.62MB
# 388  2.6%  4.38MB  2.4%  4.49MB  2.5%  4.48MB        2.6%      4.70MB
# 389  0.5%  0.08MB  0.4%  0.03MB  0.4%  0.03MB        0.5%      0.04MB
# 390  0.4%  0.42MB  0.3%  0.42MB  0.3%  1.40MB        0.4%      2.06MB
# 391  0.2%  0.10MB  0.2%  0.10MB  0.3%  2.01MB        0.3%      0.50MB
# 392  1.1%  0.77MB  1.1%  0.68MB  1.1%  0.98MB        1.1%      0.72MB
# 393  0.4%  0.44MB  0.3%  0.44MB  0.4%  1.43MB        0.4%      2.32MB
# 394  0.2%  0.08MB  0.2%  0.08MB  0.2%  2.22MB        0.3%      0.51MB
# 395  0.3%  0.43MB  0.2%  0.42MB  0.3%  1.57MB        0.3%      1.92MB
# 396  0.2%  0.09MB  0.2%  0.09MB  0.3%  2.55MB        0.2%      0.49MB
# 397  1.5%  2.48MB  1.5%  2.74MB  1.6%  4.05MB        1.5%      2.73MB
# 398  1.2%  0.59MB  1.1%  0.59MB  1.1%  0.66MB        1.1%      0.60MB
# 399  0.8%  0.75MB  0.7%  0.70MB  0.8%  0.71MB        0.8%      0.71MB
# 400  0.5%  0.09MB  0.5%  0.09MB  0.5%  0.09MB        0.5%      0.09MB
# 401  1.0%  2.21MB  1.0%  2.47MB  1.2%  2.75MB        1.1%      2.52MB
# 402  1.1%  0.67MB  1.1%  0.59MB  1.1%  0.63MB        1.1%      0.62MB
# 403  1.2%  0.76MB  1.2%  0.68MB  1.2%  0.95MB        1.1%      0.72MB
# 404  0.7%  0.73MB  0.7%  0.67MB  0.8%  0.69MB        0.7%      0.69MB
#
#     Unnamed: 21
# 385     14 days
# 386     14 days
# 387     14 days
# 388     10 days
# 389     14 days
# 390     11 days
# 391     14 days
# 392     14 days
# 393     11 days
# 394     14 days
# 395     11 days
# 396     14 days
# 397     14 days
# 398     14 days
# 399     14 days
# 400     14 days
# 401     14 days
# 402     14 days
# 403     14 days
# 404     14 days
#
# [20 rows x 22 columns]

# %%
awsdf = df[9:]

# %%
awsdf.info
# Out:
# <bound method DataFrame.info of     Low Utilization Amazon EC2 Instances           Unnamed: 1  \
# 9                              Region/AZ          Instance ID
# 10                            us-east-1b  i-0b8c413d9408beffd
# 11                            us-east-1b  i-04273cd6ba4f96e13
# 12                            us-east-1b  i-06fdd339e4dd0c201
# 13                            us-east-1b  i-0ea7b16baee2b6a4e
# 14                            us-east-1b  i-0799accd01f99ced4
# 15                            us-east-1a  i-06d31cee3dda4deef
# 16                            us-east-1b  i-09cbdb36893061df2
# 17                            us-east-1a  i-07fb4f02d91195d15
# 18                            us-east-1a  i-0d1479acf8da50b79
# 19                            us-east-1d           i-05796685
# 20                            us-east-1a  i-08e131de99f5df529
# 21                            us-east-1a           i-1ba68582
# 22                            us-east-1a  i-0d7c1335eb078fbbc
# 23                            us-east-1a           i-ff2b7e66
# 24                            us-east-1a  i-0ea5aae11f2dff98b
# 25                            us-east-1a  i-0fb195dc77040aefd
# 26                            us-east-1a  i-046db2ec47a78e978
# 27                            us-east-1d  i-063b159a3eb19859a
# 28                            us-east-1b  i-0e67624235981119f
# 29                            us-east-1a  i-082b2f013ad943078
# 30                            us-east-1a  i-01ab0b254fc3b4d27
# 31                            us-east-1a  i-0fa419f85c5953797
# 32                            us-east-1a  i-010d1716f2e866436
# 33                            us-east-1d  i-0635ef4116afb19cb
# 34                            us-east-1b  i-0bc83aa3c255e5aa5
# 35                            us-east-1d  i-050c27614d0ee1ab3
# 36                            us-east-1a  i-0a4f2943e5c3387a5
# 37                            us-east-1a  i-088b01b14287e5abf
# 38                            us-east-1b           i-972e5604
# ..                                   ...                  ...
# 375                           us-west-2b  i-0644d7ce3fd34ac1c
# 376                           us-west-2b  i-04672d63c22ccf398
# 377                           us-west-2b  i-04dd1b3446d09d42e
# 378                           us-west-2b  i-0130bd4dd18e6d454
# 379                           us-west-2b  i-0c6da90e44073fa61
# 380                           us-west-2a  i-0b21036a62bb8c15b
# 381                           us-west-2a  i-09693da91e4b48924
# 382                           us-west-2c  i-0eef23416ad0bc235
# 383                           us-west-2b  i-0e06a4028aba142f8
# 384                           us-west-2a  i-0e1279e2468a761f0
# 385                           us-west-2a  i-0968e78091fa22a9e
# 386                           us-west-2a  i-027a6ee33c4195cfe
# 387                           us-west-2b  i-09595d133b3aa414f
# 388                           us-west-2a  i-021d8edb75f24cf3d
# 389                           us-west-2c  i-0adbda33e7af57464
# 390                           us-west-2c  i-05bff8c0774270e7b
# 391                           us-west-2a  i-0ecd40787b9b666b7
# 392                           us-west-2a  i-0e4851b99203dfd38
# 393                           us-west-2c  i-079c6439572c3dc8d
# 394                           us-west-2a  i-0319137377b855c09
# 395                           us-west-2c  i-027abbd572db684eb
# 396                           us-west-2a  i-05e469826ac040b59
# 397                           us-west-2c  i-05e1e56dda75b13c6
# 398                           us-west-2b  i-0d54e9c0569920289
# 399                           us-west-2b  i-002540052279ee66d
# 400                           us-west-2a  i-07abd2d3f879ca525
# 401                           us-west-2c  i-0717a93f09aa3e5e4
# 402                           us-west-2a  i-047acb4371d2800f7
# 403                           us-west-2a  i-04395870150b6739c
# 404                           us-west-2b  i-04c9cb74f423207c9
#
#                                             Unnamed: 2     Unnamed: 3  \
# 9                                        Instance Name  Instance Type
# 10                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 11                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 12                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 13                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 14                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 15                    cbelkdata-e1a-01s.cb.comcast.net      i3.xlarge
# 16                    odprabbit-e1b-01.odp.comcast.net      c4.xlarge
# 17                                    cb-puppet-master      t2.xlarge
# 18                          new-dev-elk-master-node-1a     m4.2xlarge
# 19                                     Cassandra-dev-2     c3.4xlarge
# 20                   odpcworker-e1a-02.odp.comcast.net     c4.2xlarge
# 21                        cbapi-e1a-04s.cb.comcast.net      c4.xlarge
# 22                    odprabbit-e1a-03.odp.comcast.net      c4.xlarge
# 23                         cbapi-e1a-02.cb.comcast.net      c4.xlarge
# 24                   odpcworker-e1a-01.odp.comcast.net     c4.2xlarge
# 25                   cbelkweb-e1a-01stg.cb.comcast.net       m4.large
# 26                     odpredis-e1a-03.odp.comcast.net      c4.xlarge
# 27                                         django_test       m4.large
# 28                                      CB-STG-NODE-1B     m4.4xlarge
# 29                   odpcworker-e1a-03.odp.comcast.net     c4.2xlarge
# 30                      odpsync-e1a-06.odp.comcast.net      c4.xlarge
# 31                             Netscout Kpi hourly dev      m3.xlarge
# 32                    odprabbit-e1a-02.odp.comcast.net      c4.xlarge
# 33                                    django_exec2_STG      m4.xlarge
# 34                     odpredis-e1b-01.odp.comcast.net      c4.xlarge
# 35                                          Django STG     m4.2xlarge
# 36                                                 NaN      m3.xlarge
# 37                      odpsync-e1a-01.odp.comcast.net      c4.xlarge
# 38                          cbdb-e1b-05.cb.comcast.net     c3.4xlarge
# ..                                                 ...            ...
# 375                    odpsprkw-w2b-09.odp.comcast.net     m4.4xlarge
# 376                     odphook-w2b-04.odp.comcast.net     c4.2xlarge
# 377                  odpcworker-w2b-01.odp.comcast.net     c4.2xlarge
# 378                       odplb-w2b-04.odp.comcast.net      c4.xlarge
# 379  optimizer-chi-01.prod.us-west-2.plume.comcast.net      c4.xlarge
# 380                    odpsprkw-w2a-01.odp.comcast.net     m4.4xlarge
# 381                      odpque-w2a-04.odp.comcast.net      c4.xlarge
# 382   rabbitmq-chi-03.prod.us-west-2.plume.comcast.net      m4.xlarge
# 383                       odplb-w2b-02.odp.comcast.net      c4.xlarge
# 384                      odpzoo-w2a-02.odp.comcast.net      c4.xlarge
# 385                     odpsync-w2a-05.odp.comcast.net     c4.2xlarge
# 386  mongodb-production-04.shared.us-west-2.plume.c...       m4.large
# 387                     odpsync-w2b-03.odp.comcast.net     c4.2xlarge
# 388    es-es-esdata-02.inf.us-west-2.plume.comcast.net      i2.xlarge
# 389  controllershardv2-chi-02.prod.us-west-2.plume....      m4.xlarge
# 390                    odpsprkw-w2c-10.odp.comcast.net     m4.4xlarge
# 391                    odpsprkw-w2a-05.odp.comcast.net     m4.4xlarge
# 392                     odpcore-w2a-05.odp.comcast.net     c4.2xlarge
# 393                    odpsprkw-w2c-13.odp.comcast.net     m4.4xlarge
# 394                    odpsprkw-w2a-12.odp.comcast.net     m4.4xlarge
# 395                    odpsprkw-w2c-06.odp.comcast.net     m4.4xlarge
# 396                    odpsprkw-w2a-09.odp.comcast.net     m4.4xlarge
# 397                       odplb-w2c-01.odp.comcast.net      c4.xlarge
# 398                    odpredis-w2b-02.odp.comcast.net      c4.xlarge
# 399                     odpcore-w2b-07.odp.comcast.net     c4.2xlarge
# 400  rabbitmq-production-01.shared.us-west-2.plume....       c4.large
# 401                       odplb-w2c-03.odp.comcast.net      c4.xlarge
# 402                     odpsync-w2a-01.odp.comcast.net     c4.2xlarge
# 403                     odpcore-w2a-08.odp.comcast.net     c4.2xlarge
# 404                     odpcore-w2b-05.odp.comcast.net     c4.2xlarge
#
#                     Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# 9    Estimated Monthly Savings         Day 1         Day 2         Day 3
# 10                     $136.80  0.7%  3.12MB  0.6%  0.08MB  0.5%  0.08MB
# 11                     $136.80  0.7%  3.02MB  0.6%  0.08MB  0.5%  0.08MB
# 12                     $136.80  0.6%  3.13MB  0.5%  0.08MB  0.5%  0.08MB
# 13                     $123.12  0.6%  3.05MB  0.5%  0.08MB  0.5%  0.08MB
# 14                     $136.80  0.6%  3.05MB  0.6%  0.09MB  0.6%  0.10MB
# 15                     $224.64  0.5%  0.08MB  0.5%  0.08MB  0.5%  0.09MB
# 16                     $143.28  1.5%  1.78MB  1.5%  1.83MB  1.5%  1.81MB
# 17                     $135.36  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 18                     $288.00  0.1%  2.24MB  0.1%  2.24MB  0.1%  2.24MB
# 19                     $604.80  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 20                     $286.56  0.7%  0.86MB  0.7%  0.91MB  0.6%  0.87MB
# 21                     $143.28  0.9%  0.17MB  1.0%  0.17MB  0.9%  0.17MB
# 22                     $143.28  1.0%  0.60MB  1.0%  0.64MB  1.0%  0.62MB
# 23                      $40.94  0.8%  0.16MB  0.9%  0.16MB  0.8%  0.16MB
# 24                     $286.56  0.9%  0.87MB  0.9%  0.92MB  0.8%  0.88MB
# 25                      $72.00  0.1%  0.11MB  0.1%  0.10MB  0.1%  0.11MB
# 26                     $143.28  0.9%  0.84MB  0.9%  0.85MB  0.9%  0.83MB
# 27                      $72.00  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 28                     $576.00  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 29                     $286.56  1.0%  0.85MB  1.0%  0.88MB  0.9%  0.88MB
# 30                     $143.28  2.1%  0.68MB  2.1%  0.69MB  2.1%  0.69MB
# 31                     $191.52  0.6%  0.08MB  0.6%  0.08MB  0.6%  0.08MB
# 32                     $143.28  1.6%  1.35MB  1.5%  1.38MB  1.6%  1.40MB
# 33                     $144.00  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 34                     $143.28  0.9%  0.99MB  0.9%  1.03MB  0.9%  1.06MB
# 35                     $288.00  0.0%  0.00MB  0.0%  0.00MB  0.0%  0.00MB
# 36                     $191.52           NaN           NaN           NaN
# 37                     $143.28  2.4%  0.67MB  2.4%  0.70MB  2.4%  0.69MB
# 38                     $172.80  1.0%  0.30MB  1.0%  0.30MB  1.0%  0.30MB
# ..                         ...           ...           ...           ...
# 375                    $164.57  0.4%  5.26MB  0.4%  5.29MB  0.4%  5.28MB
# 376                    $286.56  0.5%  0.39MB  0.5%  0.42MB  0.5%  0.42MB
# 377                    $286.56  1.0%  0.21MB  0.8%  0.73MB  0.8%  0.72MB
# 378                    $143.28  1.4%  3.03MB  1.4%  3.20MB  1.4%  3.19MB
# 379                    $143.28  1.3%  0.15MB  0.5%  0.14MB  0.3%  0.13MB
# 380                    $576.00  0.3%  0.50MB  0.3%  0.44MB  0.3%  0.45MB
# 381                    $112.58  1.7%  0.23MB  1.7%  0.26MB  1.7%  0.26MB
# 382                    $133.71  0.6%  2.38MB  0.6%  2.83MB  0.6%  2.45MB
# 383                    $143.28  1.2%  3.02MB  1.2%  3.05MB  1.2%  3.05MB
# 384                    $143.28  1.5%  0.21MB  1.5%  0.24MB  1.5%  0.24MB
# 385                    $286.56  1.0%  0.59MB  1.0%  0.62MB  1.0%  0.62MB
# 386                     $72.00  0.4%  0.25MB  0.4%  0.25MB  0.4%  0.25MB
# 387                    $286.56  1.0%  0.59MB  1.0%  0.62MB  1.0%  0.62MB
# 388                    $438.69  2.4%  4.30MB  2.4%  4.31MB  2.5%  4.30MB
# 389                    $144.00  0.5%  0.03MB  0.4%  0.03MB  0.5%  0.03MB
# 390                    $452.57  0.5%  6.39MB  0.5%  6.43MB  0.5%  6.44MB
# 391                    $576.00  0.3%  0.49MB  0.3%  0.44MB  0.3%  0.44MB
# 392                    $286.56  1.1%  0.69MB  1.2%  0.70MB  1.2%  0.70MB
# 393                    $452.57  0.5%  7.50MB  0.6%  7.54MB  0.5%  7.52MB
# 394                    $576.00  0.3%  0.49MB  0.3%  0.44MB  0.3%  0.44MB
# 395                    $452.57  0.4%  5.70MB  0.4%  5.75MB  0.4%  5.74MB
# 396                    $576.00  0.2%  0.43MB  0.2%  0.37MB  0.2%  0.37MB
# 397                    $143.28  1.4%  2.81MB  1.5%  2.84MB  1.5%  2.84MB
# 398                    $143.28  1.0%  0.57MB  1.1%  0.60MB  1.1%  0.60MB
# 399                    $286.56  0.7%  0.68MB  0.7%  0.71MB  0.7%  0.71MB
# 400                     $72.00  0.4%  0.09MB  0.4%  0.09MB  0.4%  0.09MB
# 401                    $143.28  1.2%  2.82MB  1.2%  2.85MB  1.2%  2.86MB
# 402                    $286.56  1.1%  0.59MB  1.1%  0.61MB  1.1%  0.61MB
# 403                    $286.56  1.1%  0.69MB  1.1%  0.70MB  1.1%  0.70MB
# 404                    $286.56  0.7%  0.66MB  0.7%  0.69MB  0.7%  0.69MB
#
#        Unnamed: 8     Unnamed: 9               ...                \
# 9           Day 4          Day 5               ...
# 10   0.5%  0.60MB   0.7%  7.07MB               ...
# 11   0.6%  0.60MB   0.7%  7.18MB               ...
# 12   0.6%  0.64MB   0.7%  7.70MB               ...
# 13   0.6%  0.60MB   0.8%  7.12MB               ...
# 14   0.5%  0.61MB   0.8%  6.97MB               ...
# 15   0.5%  0.10MB   0.5%  0.07MB               ...
# 16   1.4%  1.84MB   1.5%  1.83MB               ...
# 17   0.0%  0.00MB   0.0%  0.00MB               ...
# 18   0.1%  2.24MB   0.1%  2.24MB               ...
# 19   0.0%  0.00MB   0.0%  0.00MB               ...
# 20   0.6%  0.90MB   0.6%  0.87MB               ...
# 21   0.9%  0.17MB   0.9%  0.17MB               ...
# 22   1.0%  0.63MB   1.0%  0.62MB               ...
# 23   0.8%  0.16MB   8.3%  6.04MB               ...
# 24   0.8%  0.91MB   0.8%  0.88MB               ...
# 25   0.1%  0.10MB   0.1%  0.11MB               ...
# 26   0.9%  0.83MB   0.9%  0.84MB               ...
# 27   0.0%  0.00MB   0.0%  0.00MB               ...
# 28   0.0%  0.00MB   0.0%  0.00MB               ...
# 29   0.8%  0.90MB   1.0%  0.88MB               ...
# 30   2.1%  0.70MB   2.1%  0.67MB               ...
# 31   0.6%  0.08MB   0.6%  0.59MB               ...
# 32   1.6%  1.41MB   1.7%  1.41MB               ...
# 33   0.0%  0.00MB   0.0%  0.00MB               ...
# 34   0.9%  0.95MB   0.9%  1.02MB               ...
# 35   0.0%  0.00MB   0.0%  0.00MB               ...
# 36            NaN   1.0%  0.12MB               ...
# 37   2.5%  0.71MB   2.4%  0.69MB               ...
# 38   1.0%  0.30MB  2.0%  69.25MB               ...
# ..            ...            ...               ...
# 375  0.4%  5.29MB   0.4%  5.29MB               ...
# 376  0.5%  0.43MB   0.5%  0.43MB               ...
# 377  0.8%  0.73MB   0.8%  0.73MB               ...
# 378  1.4%  3.20MB   1.6%  3.21MB               ...
# 379  0.5%  0.13MB   0.4%  0.17MB               ...
# 380  0.3%  0.45MB   0.3%  0.46MB               ...
# 381  1.8%  0.26MB   1.8%  0.26MB               ...
# 382  0.6%  2.24MB   0.6%  2.25MB               ...
# 383  1.2%  3.05MB   1.2%  3.06MB               ...
# 384  1.5%  0.24MB   1.5%  0.24MB               ...
# 385  0.9%  0.62MB   0.8%  0.62MB               ...
# 386  0.4%  0.25MB   0.4%  0.25MB               ...
# 387  1.0%  0.62MB   1.0%  0.63MB               ...
# 388  2.5%  4.32MB   2.5%  4.31MB               ...
# 389  0.5%  0.03MB   0.5%  0.08MB               ...
# 390  0.4%  2.76MB   0.4%  1.96MB               ...
# 391  0.3%  0.44MB   0.3%  0.45MB               ...
# 392  1.0%  0.70MB   1.0%  0.71MB               ...
# 393  0.5%  2.94MB   0.4%  1.98MB               ...
# 394  0.3%  0.44MB   0.3%  0.45MB               ...
# 395  0.4%  2.67MB   0.3%  1.97MB               ...
# 396  0.3%  0.38MB   0.3%  0.38MB               ...
# 397  1.5%  2.84MB   1.5%  2.79MB               ...
# 398  1.1%  0.60MB   1.1%  0.60MB               ...
# 399  0.7%  0.71MB   0.8%  0.72MB               ...
# 400  0.4%  0.09MB   0.4%  0.09MB               ...
# 401  1.2%  2.85MB   1.2%  2.81MB               ...
# 402  1.1%  0.62MB   1.1%  0.62MB               ...
# 403  1.1%  0.71MB   1.1%  0.71MB               ...
# 404  0.7%  0.69MB   0.7%  0.70MB               ...
#
#         Unnamed: 12     Unnamed: 13     Unnamed: 14     Unnamed: 15  \
# 9             Day 8           Day 9          Day 10          Day 11
# 10     0.5%  0.41MB    0.5%  0.08MB    0.5%  0.08MB   3.5%  19.02MB
# 11     0.5%  0.21MB    0.5%  0.08MB    0.5%  0.08MB   3.9%  14.50MB
# 12     0.5%  0.40MB    0.5%  0.08MB    0.5%  0.08MB   2.3%  11.53MB
# 13     0.6%  0.40MB    0.5%  0.08MB    0.5%  0.08MB   4.1%  17.81MB
# 14     0.6%  0.08MB    0.6%  0.08MB    0.6%  0.08MB   2.9%  14.51MB
# 15     0.5%  0.09MB    0.5%  0.09MB    0.5%  0.10MB    0.5%  0.11MB
# 16     1.4%  1.85MB    1.4%  1.88MB    1.4%  1.87MB    1.4%  1.91MB
# 17     0.0%  0.00MB    0.0%  0.00MB    0.0%  0.01MB    0.0%  0.00MB
# 18     0.1%  2.26MB    0.1%  2.24MB    0.1%  2.24MB    0.1%  2.26MB
# 19     0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB
# 20     0.7%  0.87MB    0.7%  0.90MB    0.6%  0.87MB    0.6%  0.86MB
# 21     0.9%  0.17MB    0.9%  0.17MB    0.9%  0.17MB    0.9%  0.17MB
# 22     1.0%  0.63MB    1.0%  0.64MB    1.1%  0.62MB    1.1%  0.62MB
# 23   19.5%  14.82MB   14.5%  9.92MB   14.5%  9.94MB   14.2%  9.86MB
# 24     1.0%  0.88MB    1.0%  0.87MB    1.0%  0.88MB    1.0%  0.87MB
# 25     0.1%  0.11MB    0.1%  0.11MB    0.2%  0.11MB    0.1%  0.11MB
# 26     0.9%  0.97MB    1.0%  0.93MB    1.0%  0.67MB    0.8%  0.73MB
# 27     0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB
# 28     0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB
# 29     1.0%  0.88MB    1.1%  0.91MB    1.0%  0.88MB    1.0%  0.88MB
# 30     2.1%  0.68MB    2.1%  0.70MB    2.1%  0.68MB    2.0%  0.62MB
# 31     0.6%  0.08MB    0.6%  0.08MB    0.7%  0.08MB    0.7%  0.08MB
# 32     1.7%  1.42MB    1.4%  1.45MB    1.7%  1.45MB    1.8%  1.47MB
# 33     0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB
# 34     0.9%  1.09MB    0.9%  1.07MB    0.9%  0.80MB    0.9%  0.93MB
# 35     0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB    0.0%  0.03MB
# 36     0.7%  0.08MB    0.7%  0.08MB    0.7%  0.08MB    0.7%  0.08MB
# 37     2.4%  0.69MB    2.4%  0.70MB    2.4%  0.69MB    2.4%  0.63MB
# 38   3.4%  164.05MB  3.4%  161.15MB  3.4%  161.40MB  3.4%  158.62MB
# ..              ...             ...             ...             ...
# 375    0.4%  5.30MB    0.4%  5.33MB    0.4%  5.30MB    0.4%  4.90MB
# 376    0.6%  0.43MB    0.6%  0.46MB    0.6%  0.43MB    0.5%  0.41MB
# 377    0.8%  0.56MB    0.8%  0.56MB    0.8%  0.56MB    0.8%  0.56MB
# 378    1.4%  2.91MB    1.4%  2.91MB    1.4%  2.91MB    1.4%  2.91MB
# 379    2.2%  0.16MB    1.1%  0.16MB    1.2%  0.15MB    1.4%  0.16MB
# 380    0.3%  0.43MB    0.3%  0.46MB    0.3%  0.43MB    0.3%  0.39MB
# 381    1.7%  0.25MB    1.7%  0.25MB    1.7%  0.25MB   2.9%  23.90MB
# 382    0.7%  2.90MB    0.7%  2.96MB    0.7%  3.16MB    0.7%  3.30MB
# 383    1.2%  3.06MB    1.2%  3.06MB    1.2%  3.06MB    1.2%  3.06MB
# 384    1.5%  0.23MB    1.5%  0.23MB    1.5%  0.23MB    1.5%  0.23MB
# 385    0.9%  0.62MB    0.8%  0.63MB    0.7%  0.63MB    0.7%  0.58MB
# 386    0.4%  0.25MB    0.5%  0.25MB    0.5%  0.25MB    0.4%  0.25MB
# 387    1.0%  0.63MB    1.0%  0.62MB    1.0%  0.62MB    1.0%  0.58MB
# 388    2.6%  5.38MB    2.7%  5.38MB    2.8%  5.40MB    2.9%  4.43MB
# 389    0.5%  0.08MB    0.4%  0.03MB    0.5%  0.03MB    0.5%  0.03MB
# 390    0.4%  0.44MB    0.4%  0.46MB    0.4%  0.44MB    0.4%  0.38MB
# 391    0.3%  0.42MB    0.3%  0.45MB    0.3%  0.42MB    0.3%  0.38MB
# 392    1.2%  0.70MB    1.2%  0.70MB    1.1%  0.70MB    1.1%  0.66MB
# 393    0.4%  0.46MB    0.4%  0.48MB    0.4%  0.46MB    0.4%  0.40MB
# 394    0.3%  0.41MB    0.3%  0.44MB    0.3%  0.41MB    0.3%  0.37MB
# 395    0.3%  0.44MB    0.3%  0.47MB    0.3%  0.44MB    0.3%  0.38MB
# 396    0.3%  0.36MB    0.2%  0.40MB    0.3%  0.37MB    0.2%  0.33MB
# 397    1.5%  2.47MB    1.5%  2.47MB    1.5%  2.47MB    1.5%  2.47MB
# 398    1.1%  0.59MB    1.3%  0.59MB    1.3%  0.59MB    1.2%  0.59MB
# 399    0.8%  0.71MB    0.8%  0.71MB    0.8%  0.71MB    0.7%  0.66MB
# 400    0.5%  0.09MB    0.5%  0.09MB    0.5%  0.09MB    0.5%  0.09MB
# 401    1.0%  2.19MB    1.0%  2.19MB    1.0%  2.19MB    1.0%  2.19MB
# 402    1.0%  0.62MB    1.1%  0.62MB    1.0%  0.62MB    1.0%  0.57MB
# 403    1.1%  0.70MB    1.1%  0.70MB    1.1%  0.71MB    1.1%  0.66MB
# 404    0.7%  0.69MB    0.7%  0.69MB    0.7%  0.69MB    0.7%  0.65MB
#
#          Unnamed: 16     Unnamed: 17     Unnamed: 18  \
# 9             Day 12          Day 13          Day 14
# 10      0.8%  1.68MB    2.1%  2.85MB    5.2%  8.29MB
# 11      0.6%  0.77MB    3.7%  9.70MB    5.1%  8.11MB
# 12      0.7%  1.42MB    2.5%  4.47MB    5.3%  7.71MB
# 13      0.6%  0.90MB    3.5%  8.75MB    5.1%  7.69MB
# 14      0.9%  1.70MB    3.7%  9.27MB    5.2%  7.86MB
# 15      0.5%  0.08MB    0.5%  0.09MB    0.5%  0.10MB
# 16      1.4%  1.86MB    1.4%  1.82MB    1.4%  1.87MB
# 17      0.0%  0.01MB    0.0%  0.00MB    0.0%  0.00MB
# 18      0.1%  2.27MB    0.1%  2.24MB    0.1%  2.24MB
# 19      0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB
# 20      0.6%  0.81MB    0.7%  0.88MB    0.7%  0.87MB
# 21      0.9%  0.17MB    0.9%  0.17MB    0.9%  0.17MB
# 22      1.0%  0.56MB    1.1%  0.35MB    1.2%  0.36MB
# 23     14.1%  9.82MB   14.1%  9.86MB   14.0%  9.91MB
# 24      0.9%  0.82MB    1.0%  0.91MB    1.0%  0.88MB
# 25      0.1%  0.11MB    0.1%  0.10MB    0.1%  0.11MB
# 26      0.8%  0.93MB    0.9%  0.93MB    0.9%  1.00MB
# 27      0.0%  0.03MB    0.0%  0.00MB    0.0%  0.00MB
# 28      0.0%  0.03MB    0.0%  0.00MB    0.0%  0.00MB
# 29      0.9%  0.81MB    1.0%  0.89MB    1.0%  0.88MB
# 30      1.9%  0.52MB    2.1%  0.69MB    2.1%  0.72MB
# 31      0.7%  0.08MB    0.7%  0.08MB    0.7%  0.08MB
# 32      1.8%  1.46MB    1.7%  1.55MB    1.8%  1.60MB
# 33      0.0%  0.03MB    0.0%  0.00MB    0.0%  0.00MB
# 34      0.9%  1.11MB    0.9%  1.05MB    0.9%  1.11MB
# 35      0.0%  0.00MB    0.0%  0.00MB    0.0%  0.00MB
# 36      0.7%  0.08MB    0.7%  0.08MB    0.7%  0.51MB
# 37      2.2%  0.52MB    2.2%  0.69MB    2.3%  0.72MB
# 38    3.3%  157.09MB  3.3%  157.71MB  3.3%  158.22MB
# ..               ...             ...             ...
# 375     0.3%  0.42MB    0.3%  0.41MB    0.3%  1.42MB
# 376     0.6%  0.43MB    0.6%  0.42MB    0.7%  0.78MB
# 377     0.9%  0.75MB    0.9%  0.71MB    0.9%  0.71MB
# 378     1.5%  2.87MB    1.5%  2.87MB    1.7%  3.17MB
# 379     1.3%  0.19MB    2.0%  0.16MB    2.8%  0.18MB
# 380     0.2%  0.09MB    0.2%  0.09MB    0.3%  1.99MB
# 381  18.4%  350.58MB    2.4%  3.80MB    2.6%  7.53MB
# 382     0.7%  3.37MB    0.7%  4.86MB    0.8%  5.23MB
# 383     1.2%  3.00MB    1.2%  3.00MB    1.3%  4.53MB
# 384     1.5%  0.23MB    1.5%  0.22MB    1.4%  0.24MB
# 385     0.8%  0.68MB    0.7%  0.60MB    0.7%  0.63MB
# 386     0.5%  0.25MB    0.5%  0.25MB    0.4%  0.25MB
# 387     1.0%  0.66MB    1.0%  0.60MB    1.0%  0.62MB
# 388     2.6%  4.38MB    2.4%  4.49MB    2.5%  4.48MB
# 389     0.5%  0.08MB    0.4%  0.03MB    0.4%  0.03MB
# 390     0.4%  0.42MB    0.3%  0.42MB    0.3%  1.40MB
# 391     0.2%  0.10MB    0.2%  0.10MB    0.3%  2.01MB
# 392     1.1%  0.77MB    1.1%  0.68MB    1.1%  0.98MB
# 393     0.4%  0.44MB    0.3%  0.44MB    0.4%  1.43MB
# 394     0.2%  0.08MB    0.2%  0.08MB    0.2%  2.22MB
# 395     0.3%  0.43MB    0.2%  0.42MB    0.3%  1.57MB
# 396     0.2%  0.09MB    0.2%  0.09MB    0.3%  2.55MB
# 397     1.5%  2.48MB    1.5%  2.74MB    1.6%  4.05MB
# 398     1.2%  0.59MB    1.1%  0.59MB    1.1%  0.66MB
# 399     0.8%  0.75MB    0.7%  0.70MB    0.8%  0.71MB
# 400     0.5%  0.09MB    0.5%  0.09MB    0.5%  0.09MB
# 401     1.0%  2.21MB    1.0%  2.47MB    1.2%  2.75MB
# 402     1.1%  0.67MB    1.1%  0.59MB    1.1%  0.63MB
# 403     1.2%  0.76MB    1.2%  0.68MB    1.2%  0.95MB
# 404     0.7%  0.73MB    0.7%  0.67MB    0.8%  0.69MB
#
#                         Unnamed: 19                 Unnamed: 20  \
# 9    14-Day Average CPU Utilization  14-Day Average Network I/O
# 10                             1.3%                      3.61MB
# 11                             1.4%                      3.29MB
# 12                             1.2%                      3.21MB
# 13                             1.4%                      3.82MB
# 14                             1.3%                      3.29MB
# 15                             0.5%                      0.09MB
# 16                             1.4%                      1.85MB
# 17                             0.0%                      0.00MB
# 18                             0.1%                      2.24MB
# 19                             0.0%                      0.00MB
# 20                             0.6%                      0.87MB
# 21                             0.9%                      0.17MB
# 22                             1.0%                      0.58MB
# 23                            11.0%                      7.82MB
# 24                             0.9%                      0.88MB
# 25                             0.1%                      0.11MB
# 26                             0.9%                      0.86MB
# 27                             0.0%                      0.00MB
# 28                             0.0%                      0.00MB
# 29                             1.0%                      0.88MB
# 30                             2.1%                      0.67MB
# 31                             0.7%                      0.44MB
# 32                             1.6%                      1.44MB
# 33                             0.0%                      0.00MB
# 34                             0.9%                      1.01MB
# 35                             0.0%                      0.00MB
# 36                             0.7%                      0.13MB
# 37                             2.4%                      0.68MB
# 38                             2.6%                    108.07MB
# ..                              ...                         ...
# 375                            0.3%                      4.29MB
# 376                            0.6%                      0.45MB
# 377                            0.8%                      0.62MB
# 378                            1.5%                      3.05MB
# 379                            1.4%                      0.16MB
# 380                            0.3%                      0.51MB
# 381                            3.1%                     27.74MB
# 382                            0.7%                      3.13MB
# 383                            1.2%                      3.15MB
# 384                            1.5%                      0.23MB
# 385                            0.8%                      0.62MB
# 386                            0.4%                      0.25MB
# 387                            1.0%                      0.62MB
# 388                            2.6%                      4.70MB
# 389                            0.5%                      0.04MB
# 390                            0.4%                      2.06MB
# 391                            0.3%                      0.50MB
# 392                            1.1%                      0.72MB
# 393                            0.4%                      2.32MB
# 394                            0.3%                      0.51MB
# 395                            0.3%                      1.92MB
# 396                            0.2%                      0.49MB
# 397                            1.5%                      2.73MB
# 398                            1.1%                      0.60MB
# 399                            0.8%                      0.71MB
# 400                            0.5%                      0.09MB
# 401                            1.1%                      2.52MB
# 402                            1.1%                      0.62MB
# 403                            1.1%                      0.72MB
# 404                            0.7%                      0.69MB
#
#                         Unnamed: 21
# 9    Number of Days Low Utilization
# 10                          10 days
# 11                          10 days
# 12                          10 days
# 13                           9 days
# 14                          10 days
# 15                          14 days
# 16                          14 days
# 17                          14 days
# 18                          14 days
# 19                          14 days
# 20                          14 days
# 21                          14 days
# 22                          14 days
# 23                           4 days
# 24                          14 days
# 25                          14 days
# 26                          14 days
# 27                          14 days
# 28                          14 days
# 29                          14 days
# 30                          14 days
# 31                          14 days
# 32                          14 days
# 33                          14 days
# 34                          14 days
# 35                          14 days
# 36                          10 days
# 37                          14 days
# 38                           4 days
# ..                              ...
# 375                          4 days
# 376                         14 days
# 377                         14 days
# 378                         14 days
# 379                         14 days
# 380                         14 days
# 381                         11 days
# 382                         13 days
# 383                         14 days
# 384                         14 days
# 385                         14 days
# 386                         14 days
# 387                         14 days
# 388                         10 days
# 389                         14 days
# 390                         11 days
# 391                         14 days
# 392                         14 days
# 393                         11 days
# 394                         14 days
# 395                         11 days
# 396                         14 days
# 397                         14 days
# 398                         14 days
# 399                         14 days
# 400                         14 days
# 401                         14 days
# 402                         14 days
# 403                         14 days
# 404                         14 days
#
# [396 rows x 22 columns]>

# %%
awsdf.columns
# Out:
# Index(['Low Utilization Amazon EC2 Instances', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21'],
#       dtype='object')

# %%
awsdf[['Low Utilization Amazon EC2 Instances' ,'Unnamed: 1' ]]
# Out:
#     Low Utilization Amazon EC2 Instances           Unnamed: 1
# 9                              Region/AZ          Instance ID
# 10                            us-east-1b  i-0b8c413d9408beffd
# 11                            us-east-1b  i-04273cd6ba4f96e13
# 12                            us-east-1b  i-06fdd339e4dd0c201
# 13                            us-east-1b  i-0ea7b16baee2b6a4e
# 14                            us-east-1b  i-0799accd01f99ced4
# 15                            us-east-1a  i-06d31cee3dda4deef
# 16                            us-east-1b  i-09cbdb36893061df2
# 17                            us-east-1a  i-07fb4f02d91195d15
# 18                            us-east-1a  i-0d1479acf8da50b79
# 19                            us-east-1d           i-05796685
# 20                            us-east-1a  i-08e131de99f5df529
# 21                            us-east-1a           i-1ba68582
# 22                            us-east-1a  i-0d7c1335eb078fbbc
# 23                            us-east-1a           i-ff2b7e66
# 24                            us-east-1a  i-0ea5aae11f2dff98b
# 25                            us-east-1a  i-0fb195dc77040aefd
# 26                            us-east-1a  i-046db2ec47a78e978
# 27                            us-east-1d  i-063b159a3eb19859a
# 28                            us-east-1b  i-0e67624235981119f
# 29                            us-east-1a  i-082b2f013ad943078
# 30                            us-east-1a  i-01ab0b254fc3b4d27
# 31                            us-east-1a  i-0fa419f85c5953797
# 32                            us-east-1a  i-010d1716f2e866436
# 33                            us-east-1d  i-0635ef4116afb19cb
# 34                            us-east-1b  i-0bc83aa3c255e5aa5
# 35                            us-east-1d  i-050c27614d0ee1ab3
# 36                            us-east-1a  i-0a4f2943e5c3387a5
# 37                            us-east-1a  i-088b01b14287e5abf
# 38                            us-east-1b           i-972e5604
# ..                                   ...                  ...
# 375                           us-west-2b  i-0644d7ce3fd34ac1c
# 376                           us-west-2b  i-04672d63c22ccf398
# 377                           us-west-2b  i-04dd1b3446d09d42e
# 378                           us-west-2b  i-0130bd4dd18e6d454
# 379                           us-west-2b  i-0c6da90e44073fa61
# 380                           us-west-2a  i-0b21036a62bb8c15b
# 381                           us-west-2a  i-09693da91e4b48924
# 382                           us-west-2c  i-0eef23416ad0bc235
# 383                           us-west-2b  i-0e06a4028aba142f8
# 384                           us-west-2a  i-0e1279e2468a761f0
# 385                           us-west-2a  i-0968e78091fa22a9e
# 386                           us-west-2a  i-027a6ee33c4195cfe
# 387                           us-west-2b  i-09595d133b3aa414f
# 388                           us-west-2a  i-021d8edb75f24cf3d
# 389                           us-west-2c  i-0adbda33e7af57464
# 390                           us-west-2c  i-05bff8c0774270e7b
# 391                           us-west-2a  i-0ecd40787b9b666b7
# 392                           us-west-2a  i-0e4851b99203dfd38
# 393                           us-west-2c  i-079c6439572c3dc8d
# 394                           us-west-2a  i-0319137377b855c09
# 395                           us-west-2c  i-027abbd572db684eb
# 396                           us-west-2a  i-05e469826ac040b59
# 397                           us-west-2c  i-05e1e56dda75b13c6
# 398                           us-west-2b  i-0d54e9c0569920289
# 399                           us-west-2b  i-002540052279ee66d
# 400                           us-west-2a  i-07abd2d3f879ca525
# 401                           us-west-2c  i-0717a93f09aa3e5e4
# 402                           us-west-2a  i-047acb4371d2800f7
# 403                           us-west-2a  i-04395870150b6739c
# 404                           us-west-2b  i-04c9cb74f423207c9
#
# [396 rows x 2 columns]

# %%
awsdf.iloc[0:6,0:5]
# Out:
#    Low Utilization Amazon EC2 Instances           Unnamed: 1  \
# 9                             Region/AZ          Instance ID
# 10                           us-east-1b  i-0b8c413d9408beffd
# 11                           us-east-1b  i-04273cd6ba4f96e13
# 12                           us-east-1b  i-06fdd339e4dd0c201
# 13                           us-east-1b  i-0ea7b16baee2b6a4e
# 14                           us-east-1b  i-0799accd01f99ced4
#
#                   Unnamed: 2     Unnamed: 3                 Unnamed: 4
# 9              Instance Name  Instance Type  Estimated Monthly Savings
# 10  Quark-Dev-Testing-stgvpc      m3.xlarge                    $136.80
# 11  Quark-Dev-Testing-stgvpc      m3.xlarge                    $136.80
# 12  Quark-Dev-Testing-stgvpc      m3.xlarge                    $136.80
# 13  Quark-Dev-Testing-stgvpc      m3.xlarge                    $123.12
# 14  Quark-Dev-Testing-stgvpc      m3.xlarge                    $136.80

# %%
rdf = awsdf.iloc[9:,0] + str(' ') + awsdf.iloc[9:,3] + str(' ') + awsdf.iloc[9:,4]
rdf
# Out:
# 18     us-east-1a m4.2xlarge $288.00
# 19     us-east-1d c3.4xlarge $604.80
# 20     us-east-1a c4.2xlarge $286.56
# 21      us-east-1a c4.xlarge $143.28
# 22      us-east-1a c4.xlarge $143.28
# 23       us-east-1a c4.xlarge $40.94
# 24     us-east-1a c4.2xlarge $286.56
# 25        us-east-1a m4.large $72.00
# 26      us-east-1a c4.xlarge $143.28
# 27        us-east-1d m4.large $72.00
# 28     us-east-1b m4.4xlarge $576.00
# 29     us-east-1a c4.2xlarge $286.56
# 30      us-east-1a c4.xlarge $143.28
# 31      us-east-1a m3.xlarge $191.52
# 32      us-east-1a c4.xlarge $143.28
# 33      us-east-1d m4.xlarge $144.00
# 34      us-east-1b c4.xlarge $143.28
# 35     us-east-1d m4.2xlarge $288.00
# 36      us-east-1a m3.xlarge $191.52
# 37      us-east-1a c4.xlarge $143.28
# 38     us-east-1b c3.4xlarge $172.80
# 39     us-east-1b c4.2xlarge $286.56
# 40      us-east-1a c4.xlarge $143.28
# 41       us-east-1a c4.xlarge $51.17
# 42     us-east-1b c4.2xlarge $286.56
# 43      us-east-1b i3.xlarge $112.32
# 44      us-east-1a c4.xlarge $143.28
# 45      us-east-1a c4.xlarge $143.28
# 46     us-east-1a c4.2xlarge $286.56
# 47      us-east-1a m4.xlarge $144.00
#                    ...
# 375    us-west-2b m4.4xlarge $164.57
# 376    us-west-2b c4.2xlarge $286.56
# 377    us-west-2b c4.2xlarge $286.56
# 378     us-west-2b c4.xlarge $143.28
# 379     us-west-2b c4.xlarge $143.28
# 380    us-west-2a m4.4xlarge $576.00
# 381     us-west-2a c4.xlarge $112.58
# 382     us-west-2c m4.xlarge $133.71
# 383     us-west-2b c4.xlarge $143.28
# 384     us-west-2a c4.xlarge $143.28
# 385    us-west-2a c4.2xlarge $286.56
# 386       us-west-2a m4.large $72.00
# 387    us-west-2b c4.2xlarge $286.56
# 388     us-west-2a i2.xlarge $438.69
# 389     us-west-2c m4.xlarge $144.00
# 390    us-west-2c m4.4xlarge $452.57
# 391    us-west-2a m4.4xlarge $576.00
# 392    us-west-2a c4.2xlarge $286.56
# 393    us-west-2c m4.4xlarge $452.57
# 394    us-west-2a m4.4xlarge $576.00
# 395    us-west-2c m4.4xlarge $452.57
# 396    us-west-2a m4.4xlarge $576.00
# 397     us-west-2c c4.xlarge $143.28
# 398     us-west-2b c4.xlarge $143.28
# 399    us-west-2b c4.2xlarge $286.56
# 400       us-west-2a c4.large $72.00
# 401     us-west-2c c4.xlarge $143.28
# 402    us-west-2a c4.2xlarge $286.56
# 403    us-west-2a c4.2xlarge $286.56
# 404    us-west-2b c4.2xlarge $286.56
# Length: 387, dtype: object

# %%
awsdf.dtypes
# Out:
# Low Utilization Amazon EC2 Instances    object
# Unnamed: 1                              object
# Unnamed: 2                              object
# Unnamed: 3                              object
# Unnamed: 4                              object
# Unnamed: 5                              object
# Unnamed: 6                              object
# Unnamed: 7                              object
# Unnamed: 8                              object
# Unnamed: 9                              object
# Unnamed: 10                             object
# Unnamed: 11                             object
# Unnamed: 12                             object
# Unnamed: 13                             object
# Unnamed: 14                             object
# Unnamed: 15                             object
# Unnamed: 16                             object
# Unnamed: 17                             object
# Unnamed: 18                             object
# Unnamed: 19                             object
# Unnamed: 20                             object
# Unnamed: 21                             object
# dtype: object

# %%
awsdf.columns
# Out:
# Index(['Low Utilization Amazon EC2 Instances', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21'],
#       dtype='object')

# %%
awsdf.iloc[0,range(5)]
# Out:
# Low Utilization Amazon EC2 Instances                    Region/AZ
# Unnamed: 1                                            Instance ID
# Unnamed: 2                                          Instance Name
# Unnamed: 3                                          Instance Type
# Unnamed: 4                              Estimated Monthly Savings
# Name: 9, dtype: object

# %%
df.values
# Out:
# array([['AWS Account ID: 287432581570', nan, nan, ..., nan, nan, nan],
#        ['Description: Checks the Amazon Elastic Compute Cloud (Amazon EC2) instances that were running at any time during the last 14 days and alerts you if the daily CPU utilization was 10% or less and network I/O was 5 MB or less on 4 or more days. Running instances generate hourly usage charges. Although some scenarios can result in low utilization by design, you can often lower your costs by managing the number and size of your instances.\n\n\n\nEstimated monthly savings are calculated by using the current usage rate for On-Demand Instances and the estimated number of days the instance might be underutilized. Actual savings will vary if you are using Reserved Instances or Spot Instances, or if the instance is not running for a full day. To get daily utilization data, download the report for this check. \n\n\n\n\nAlert Criteria\n\nYellow: An instance had 10% or less daily average CPU utilization and 5 MB or less network I/O on at least 4 of the previous 14 days.\n\n\n\nRecommended Action\n\nConsider stopping or terminating instances that have low utilization, or scale the number of instances by using Auto Scaling. For more information, see Stop and Start Your Instance, Terminate Your Instance, and What is Auto Scaling?\n\n\n\nAdditional Resources\n\nMonitoring Amazon EC2\n\nInstance Metadata and User Data\n\nAmazon CloudWatch Developer Guide\n\nAuto Scaling Developer Guide',
#         nan, nan, ..., nan, nan, nan],
#        ['Status: warning', nan, nan, ..., nan, nan, nan],
#        ...,
#        ['us-west-2a', 'i-047acb4371d2800f7',
#         'odpsync-w2a-01.odp.comcast.net', ..., '1.1%', '0.62MB',
#         '14 days'],
#        ['us-west-2a', 'i-04395870150b6739c',
#         'odpcore-w2a-08.odp.comcast.net', ..., '1.1%', '0.72MB',
#         '14 days'],
#        ['us-west-2b', 'i-04c9cb74f423207c9',
#         'odpcore-w2b-05.odp.comcast.net', ..., '0.7%', '0.69MB',
#         '14 days']], dtype=object)

# %%
df.columns
# Out:
# Index(['Low Utilization Amazon EC2 Instances', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21'],
#       dtype='object')

# %%
awsdf.values
# Out:
# array([['Region/AZ', 'Instance ID', 'Instance Name', ...,
#         '14-Day Average CPU Utilization', '14-Day Average Network I/O',
#         'Number of Days Low Utilization'],
#        ['us-east-1b', 'i-0b8c413d9408beffd', 'Quark-Dev-Testing-stgvpc',
#         ..., '1.3%', '3.61MB', '10 days'],
#        ['us-east-1b', 'i-04273cd6ba4f96e13', 'Quark-Dev-Testing-stgvpc',
#         ..., '1.4%', '3.29MB', '10 days'],
#        ...,
#        ['us-west-2a', 'i-047acb4371d2800f7',
#         'odpsync-w2a-01.odp.comcast.net', ..., '1.1%', '0.62MB',
#         '14 days'],
#        ['us-west-2a', 'i-04395870150b6739c',
#         'odpcore-w2a-08.odp.comcast.net', ..., '1.1%', '0.72MB',
#         '14 days'],
#        ['us-west-2b', 'i-04c9cb74f423207c9',
#         'odpcore-w2b-05.odp.comcast.net', ..., '0.7%', '0.69MB',
#         '14 days']], dtype=object)

# %%
awsdflen=len(awsdf.iloc[0])
for x in awsdf.values:
    for y in range(awsdflen):
        print(x[y])
# Out:
# Region/AZ
# Instance ID
# Instance Name
# Instance Type
# Estimated Monthly Savings
# Day 1
# Day 2
# Day 3
# Day 4
# Day 5
# Day 6
# Day 7
# Day 8
# Day 9
# Day 10
# Day 11
# Day 12
# Day 13
# Day 14
# 14-Day Average CPU Utilization
# 14-Day Average Network I/O
# Number of Days Low Utilization
# us-east-1b
# i-0b8c413d9408beffd
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.7%  3.12MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 0.5%  0.60MB
# 0.7%  7.07MB
# 0.7%  1.22MB
# 0.7%  5.92MB
# 0.5%  0.41MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 3.5%  19.02MB
# 0.8%  1.68MB
# 2.1%  2.85MB
# 5.2%  8.29MB
# 1.3%
# 3.61MB
# 10 days
# us-east-1b
# i-04273cd6ba4f96e13
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.7%  3.02MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 0.6%  0.60MB
# 0.7%  7.18MB
# 0.6%  0.89MB
# 0.5%  0.77MB
# 0.5%  0.21MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 3.9%  14.50MB
# 0.6%  0.77MB
# 3.7%  9.70MB
# 5.1%  8.11MB
# 1.4%
# 3.29MB
# 10 days
# us-east-1b
# i-06fdd339e4dd0c201
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.6%  3.13MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.6%  0.64MB
# 0.7%  7.70MB
# 0.6%  0.89MB
# 0.8%  6.75MB
# 0.5%  0.40MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 2.3%  11.53MB
# 0.7%  1.42MB
# 2.5%  4.47MB
# 5.3%  7.71MB
# 1.2%
# 3.21MB
# 10 days
# us-east-1b
# i-0ea7b16baee2b6a4e
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $123.12
# 0.6%  3.05MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.6%  0.60MB
# 0.8%  7.12MB
# 0.6%  0.89MB
# 0.7%  5.97MB
# 0.6%  0.40MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 4.1%  17.81MB
# 0.6%  0.90MB
# 3.5%  8.75MB
# 5.1%  7.69MB
# 1.4%
# 3.82MB
# 9 days
# us-east-1b
# i-0799accd01f99ced4
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.6%  3.05MB
# 0.6%  0.09MB
# 0.6%  0.10MB
# 0.5%  0.61MB
# 0.8%  6.97MB
# 0.7%  1.22MB
# 0.6%  0.46MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 2.9%  14.51MB
# 0.9%  1.70MB
# 3.7%  9.27MB
# 5.2%  7.86MB
# 1.3%
# 3.29MB
# 10 days
# us-east-1a
# i-06d31cee3dda4deef
# cbelkdata-e1a-01s.cb.comcast.net
# i3.xlarge
# $224.64
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.5%  0.09MB
# 0.5%  0.10MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.5%  0.11MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.10MB
# 0.5%  0.11MB
# 0.5%  0.08MB
# 0.5%  0.09MB
# 0.5%  0.10MB
# 0.5%
# 0.09MB
# 14 days
# us-east-1b
# i-09cbdb36893061df2
# odprabbit-e1b-01.odp.comcast.net
# c4.xlarge
# $143.28
# 1.5%  1.78MB
# 1.5%  1.83MB
# 1.5%  1.81MB
# 1.4%  1.84MB
# 1.5%  1.83MB
# 1.5%  1.84MB
# 1.5%  1.84MB
# 1.4%  1.85MB
# 1.4%  1.88MB
# 1.4%  1.87MB
# 1.4%  1.91MB
# 1.4%  1.86MB
# 1.4%  1.82MB
# 1.4%  1.87MB
# 1.4%
# 1.85MB
# 14 days
# us-east-1a
# i-07fb4f02d91195d15
# cb-puppet-master
# t2.xlarge
# $135.36
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-0d1479acf8da50b79
# new-dev-elk-master-node-1a
# m4.2xlarge
# $288.00
# 0.1%  2.24MB
# 0.1%  2.24MB
# 0.1%  2.24MB
# 0.1%  2.24MB
# 0.1%  2.24MB
# 0.1%  2.24MB
# 0.1%  2.26MB
# 0.1%  2.26MB
# 0.1%  2.24MB
# 0.1%  2.24MB
# 0.1%  2.26MB
# 0.1%  2.27MB
# 0.1%  2.24MB
# 0.1%  2.24MB
# 0.1%
# 2.24MB
# 14 days
# us-east-1d
# i-05796685
# Cassandra-dev-2
# c3.4xlarge
# $604.80
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-08e131de99f5df529
# odpcworker-e1a-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.7%  0.86MB
# 0.7%  0.91MB
# 0.6%  0.87MB
# 0.6%  0.90MB
# 0.6%  0.87MB
# 0.6%  0.87MB
# 0.6%  0.86MB
# 0.7%  0.87MB
# 0.7%  0.90MB
# 0.6%  0.87MB
# 0.6%  0.86MB
# 0.6%  0.81MB
# 0.7%  0.88MB
# 0.7%  0.87MB
# 0.6%
# 0.87MB
# 14 days
# us-east-1a
# i-1ba68582
# cbapi-e1a-04s.cb.comcast.net
# c4.xlarge
# $143.28
# 0.9%  0.17MB
# 1.0%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%  0.17MB
# 0.9%
# 0.17MB
# 14 days
# us-east-1a
# i-0d7c1335eb078fbbc
# odprabbit-e1a-03.odp.comcast.net
# c4.xlarge
# $143.28
# 1.0%  0.60MB
# 1.0%  0.64MB
# 1.0%  0.62MB
# 1.0%  0.63MB
# 1.0%  0.62MB
# 1.0%  0.62MB
# 1.0%  0.61MB
# 1.0%  0.63MB
# 1.0%  0.64MB
# 1.1%  0.62MB
# 1.1%  0.62MB
# 1.0%  0.56MB
# 1.1%  0.35MB
# 1.2%  0.36MB
# 1.0%
# 0.58MB
# 14 days
# us-east-1a
# i-ff2b7e66
# cbapi-e1a-02.cb.comcast.net
# c4.xlarge
# $40.94
# 0.8%  0.16MB
# 0.9%  0.16MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 8.3%  6.04MB
# 18.5%  13.98MB
# 19.3%  14.64MB
# 19.5%  14.82MB
# 14.5%  9.92MB
# 14.5%  9.94MB
# 14.2%  9.86MB
# 14.1%  9.82MB
# 14.1%  9.86MB
# 14.0%  9.91MB
# 11.0%
# 7.82MB
# 4 days
# us-east-1a
# i-0ea5aae11f2dff98b
# odpcworker-e1a-01.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.9%  0.87MB
# 0.9%  0.92MB
# 0.8%  0.88MB
# 0.8%  0.91MB
# 0.8%  0.88MB
# 0.9%  0.88MB
# 0.9%  0.86MB
# 1.0%  0.88MB
# 1.0%  0.87MB
# 1.0%  0.88MB
# 1.0%  0.87MB
# 0.9%  0.82MB
# 1.0%  0.91MB
# 1.0%  0.88MB
# 0.9%
# 0.88MB
# 14 days
# us-east-1a
# i-0fb195dc77040aefd
# cbelkweb-e1a-01stg.cb.comcast.net
# m4.large
# $72.00
# 0.1%  0.11MB
# 0.1%  0.10MB
# 0.1%  0.11MB
# 0.1%  0.10MB
# 0.1%  0.11MB
# 0.1%  0.10MB
# 0.1%  0.11MB
# 0.1%  0.11MB
# 0.1%  0.11MB
# 0.2%  0.11MB
# 0.1%  0.11MB
# 0.1%  0.11MB
# 0.1%  0.10MB
# 0.1%  0.11MB
# 0.1%
# 0.11MB
# 14 days
# us-east-1a
# i-046db2ec47a78e978
# odpredis-e1a-03.odp.comcast.net
# c4.xlarge
# $143.28
# 0.9%  0.84MB
# 0.9%  0.85MB
# 0.9%  0.83MB
# 0.9%  0.83MB
# 0.9%  0.84MB
# 0.9%  0.82MB
# 0.9%  0.84MB
# 0.9%  0.97MB
# 1.0%  0.93MB
# 1.0%  0.67MB
# 0.8%  0.73MB
# 0.8%  0.93MB
# 0.9%  0.93MB
# 0.9%  1.00MB
# 0.9%
# 0.86MB
# 14 days
# us-east-1d
# i-063b159a3eb19859a
# django_test
# m4.large
# $72.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1b
# i-0e67624235981119f
# CB-STG-NODE-1B
# m4.4xlarge
# $576.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-082b2f013ad943078
# odpcworker-e1a-03.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.85MB
# 1.0%  0.88MB
# 0.9%  0.88MB
# 0.8%  0.90MB
# 1.0%  0.88MB
# 1.0%  0.88MB
# 1.0%  0.86MB
# 1.0%  0.88MB
# 1.1%  0.91MB
# 1.0%  0.88MB
# 1.0%  0.88MB
# 0.9%  0.81MB
# 1.0%  0.89MB
# 1.0%  0.88MB
# 1.0%
# 0.88MB
# 14 days
# us-east-1a
# i-01ab0b254fc3b4d27
# odpsync-e1a-06.odp.comcast.net
# c4.xlarge
# $143.28
# 2.1%  0.68MB
# 2.1%  0.69MB
# 2.1%  0.69MB
# 2.1%  0.70MB
# 2.1%  0.67MB
# 2.1%  0.68MB
# 2.1%  0.68MB
# 2.1%  0.68MB
# 2.1%  0.70MB
# 2.1%  0.68MB
# 2.0%  0.62MB
# 1.9%  0.52MB
# 2.1%  0.69MB
# 2.1%  0.72MB
# 2.1%
# 0.67MB
# 14 days
# us-east-1a
# i-0fa419f85c5953797
# Netscout Kpi hourly dev
# m3.xlarge
# $191.52
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.59MB
# 1.0%  4.59MB
# 0.7%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%
# 0.44MB
# 14 days
# us-east-1a
# i-010d1716f2e866436
# odprabbit-e1a-02.odp.comcast.net
# c4.xlarge
# $143.28
# 1.6%  1.35MB
# 1.5%  1.38MB
# 1.6%  1.40MB
# 1.6%  1.41MB
# 1.7%  1.41MB
# 1.5%  1.43MB
# 1.6%  1.42MB
# 1.7%  1.42MB
# 1.4%  1.45MB
# 1.7%  1.45MB
# 1.8%  1.47MB
# 1.8%  1.46MB
# 1.7%  1.55MB
# 1.8%  1.60MB
# 1.6%
# 1.44MB
# 14 days
# us-east-1d
# i-0635ef4116afb19cb
# django_exec2_STG
# m4.xlarge
# $144.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1b
# i-0bc83aa3c255e5aa5
# odpredis-e1b-01.odp.comcast.net
# c4.xlarge
# $143.28
# 0.9%  0.99MB
# 0.9%  1.03MB
# 0.9%  1.06MB
# 0.9%  0.95MB
# 0.9%  1.02MB
# 0.9%  1.00MB
# 0.9%  0.99MB
# 0.9%  1.09MB
# 0.9%  1.07MB
# 0.9%  0.80MB
# 0.9%  0.93MB
# 0.9%  1.11MB
# 0.9%  1.05MB
# 0.9%  1.11MB
# 0.9%
# 1.01MB
# 14 days
# us-east-1d
# i-050c27614d0ee1ab3
# Django STG
# m4.2xlarge
# $288.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-0a4f2943e5c3387a5
# nan
# m3.xlarge
# $191.52
# nan
# nan
# nan
# nan
# 1.0%  0.12MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.08MB
# 0.7%  0.51MB
# 0.7%
# 0.13MB
# 10 days
# us-east-1a
# i-088b01b14287e5abf
# odpsync-e1a-01.odp.comcast.net
# c4.xlarge
# $143.28
# 2.4%  0.67MB
# 2.4%  0.70MB
# 2.4%  0.69MB
# 2.5%  0.71MB
# 2.4%  0.69MB
# 2.4%  0.69MB
# 2.5%  0.69MB
# 2.4%  0.69MB
# 2.4%  0.70MB
# 2.4%  0.69MB
# 2.4%  0.63MB
# 2.2%  0.52MB
# 2.2%  0.69MB
# 2.3%  0.72MB
# 2.4%
# 0.68MB
# 14 days
# us-east-1b
# i-972e5604
# cbdb-e1b-05.cb.comcast.net
# c3.4xlarge
# $172.80
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 2.0%  69.25MB
# 3.4%  161.10MB
# 3.4%  163.21MB
# 3.4%  164.05MB
# 3.4%  161.15MB
# 3.4%  161.40MB
# 3.4%  158.62MB
# 3.3%  157.09MB
# 3.3%  157.71MB
# 3.3%  158.22MB
# 2.6%
# 108.07MB
# 4 days
# us-east-1b
# i-0c8a426dd399b11bc
# odpsync-e1b-09.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.8%  0.80MB
# 0.8%  0.81MB
# 0.8%  0.80MB
# 0.8%  0.83MB
# 0.8%  0.82MB
# 0.8%  0.84MB
# 0.8%  0.81MB
# 0.8%  0.81MB
# 0.8%  0.80MB
# 0.8%  0.80MB
# 0.8%  0.77MB
# 0.7%  0.65MB
# 0.9%  0.88MB
# 0.9%  0.92MB
# 0.8%
# 0.81MB
# 14 days
# us-east-1a
# i-055bb6fd5891a0921
# odpproxy-e1a-01.odp.comcast.net
# c4.xlarge
# $143.28
# 1.2%  0.29MB
# 1.1%  0.31MB
# 1.2%  0.31MB
# 1.2%  0.31MB
# 1.2%  0.31MB
# 1.2%  0.32MB
# 1.1%  0.32MB
# 0.8%  0.31MB
# 1.1%  0.31MB
# 1.2%  0.31MB
# 1.1%  0.31MB
# 0.8%  0.31MB
# 1.1%  0.30MB
# 0.8%  0.31MB
# 1.1%
# 0.31MB
# 14 days
# us-east-1a
# i-fc2b7e65
# cbapi-e1a-03.cb.comcast.net
# c4.xlarge
# $51.17
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 5.9%  3.42MB
# 13.1%  7.81MB
# 13.3%  7.94MB
# 13.2%  7.99MB
# 13.4%  8.08MB
# 13.5%  8.11MB
# 13.4%  7.99MB
# 13.2%  7.91MB
# 13.3%  7.94MB
# 13.3%  7.99MB
# 9.2%
# 5.42MB
# 5 days
# us-east-1b
# i-0b2c002a7211f3f06
# odpsync-e1b-08.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.78MB
# 1.1%  0.82MB
# 1.1%  0.79MB
# 1.1%  0.83MB
# 1.1%  0.81MB
# 1.1%  0.83MB
# 1.2%  0.81MB
# 1.2%  0.81MB
# 1.2%  0.79MB
# 1.2%  0.79MB
# 1.1%  0.77MB
# 1.0%  0.57MB
# 1.0%  0.55MB
# 1.0%  0.59MB
# 1.1%
# 0.75MB
# 14 days
# us-east-1b
# i-0fafb41652b51958b
# new-dev-elk-data-node-1b
# i3.xlarge
# $112.32
# 15.4%  120.01MB
# 15.5%  120.38MB
# 15.9%  122.14MB
# 16.1%  122.21MB
# 15.2%  116.02MB
# 15.5%  118.16MB
# 15.4%  128.04MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 8.0%
# 60.75MB
# 7 days
# us-east-1a
# i-28a784b1
# cbapi-e1a-02s.cb.comcast.net
# c4.xlarge
# $143.28
# 0.9%  0.16MB
# 0.9%  0.17MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.9%  0.16MB
# 0.8%  0.17MB
# 0.8%  0.16MB
# 0.8%  0.17MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.8%  0.16MB
# 0.8%
# 0.16MB
# 14 days
# us-east-1a
# i-0332a2a91602fcb63
# odpzoo-e1a-02.odp.comcast.net
# c4.xlarge
# $143.28
# 2.1%  0.40MB
# 2.0%  0.43MB
# 1.9%  0.44MB
# 2.0%  0.44MB
# 2.0%  0.44MB
# 2.0%  0.44MB
# 2.1%  0.44MB
# 2.1%  0.44MB
# 2.0%  0.43MB
# 2.2%  0.43MB
# 2.0%  0.43MB
# 2.1%  0.42MB
# 1.9%  0.41MB
# 1.9%  0.42MB
# 2.0%
# 0.43MB
# 14 days
# us-east-1a
# i-0d41df987b524443b
# odpsync-e1a-11.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.65MB
# 1.1%  0.66MB
# 1.1%  0.66MB
# 1.1%  0.67MB
# 1.1%  0.64MB
# 1.1%  0.65MB
# 1.1%  0.65MB
# 1.0%  0.65MB
# 1.1%  0.67MB
# 1.0%  0.65MB
# 1.0%  0.59MB
# 0.9%  0.51MB
# 1.1%  0.67MB
# 1.1%  0.68MB
# 1.0%
# 0.64MB
# 14 days
# us-east-1a
# i-02c53df44edde17a8
# cbelkmstr-e1a-02.cb.comcast.net
# m4.xlarge
# $144.00
# 0.7%  2.63MB
# 0.7%  2.62MB
# 0.7%  2.62MB
# 0.7%  2.62MB
# 0.7%  2.62MB
# 0.8%  2.62MB
# 0.7%  2.63MB
# 0.7%  2.63MB
# 0.7%  2.64MB
# 0.8%  2.64MB
# 0.7%  2.64MB
# 0.7%  2.64MB
# 0.8%  2.65MB
# 0.8%  2.36MB
# 0.7%
# 2.61MB
# 14 days
# us-east-1a
# i-0b4cb5100460bd590
# Karthik-docker-test
# t2.micro
# $8.64
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.02MB
# 0.2%  0.01MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%
# 0.00MB
# 14 days
# us-east-1b
# i-0d9b7546e6b59b23a
# odpredis-e1b-03.odp.comcast.net
# c4.xlarge
# $143.28
# 1.2%  0.90MB
# 1.2%  0.93MB
# 1.2%  0.96MB
# 1.2%  0.85MB
# 1.2%  0.93MB
# 1.2%  0.91MB
# 1.2%  0.90MB
# 1.2%  0.99MB
# 1.2%  0.97MB
# 1.1%  0.71MB
# 1.1%  0.83MB
# 1.2%  1.01MB
# 1.2%  0.94MB
# 1.2%  1.02MB
# 1.2%
# 0.92MB
# 14 days
# us-east-1b
# i-090b1de732878e219
# odpsync-e1b-10.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.79MB
# 1.1%  0.82MB
# 1.0%  0.80MB
# 1.0%  0.83MB
# 1.0%  0.84MB
# 1.1%  0.86MB
# 1.0%  0.84MB
# 1.1%  0.83MB
# 1.1%  0.82MB
# 1.1%  0.81MB
# 1.1%  0.79MB
# 1.0%  0.65MB
# 1.1%  0.87MB
# 1.1%  0.92MB
# 1.1%
# 0.82MB
# 14 days
# us-east-1a
# i-0618899e6b14162dd
# new-dev-elk-web-kibana-node-1a
# m4.large
# $72.00
# 0.1%  0.11MB
# 0.2%  0.11MB
# 0.1%  0.11MB
# 0.2%  0.12MB
# 0.1%  0.11MB
# 0.1%  0.11MB
# 0.2%  0.12MB
# 0.2%  0.11MB
# 0.2%  0.11MB
# 0.1%  0.11MB
# 0.2%  0.13MB
# 0.2%  0.14MB
# 0.1%  0.11MB
# 0.1%  0.11MB
# 0.2%
# 0.11MB
# 14 days
# us-east-1a
# i-31c2c5a8
# cbdb-e1a-05.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.1%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.29MB
# 1.1%  0.30MB
# 1.1%
# 0.30MB
# 14 days
# us-east-1a
# i-585500c1
# cblb-e1a-01.cb.comcast.net
# c4.xlarge
# $143.28
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.8%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.26MB
# 0.7%  0.27MB
# 0.7%
# 0.27MB
# 14 days
# us-east-1a
# i-b0540129
# cblb-e1a-02.cb.comcast.net
# c4.xlarge
# $143.28
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.28MB
# 0.8%  0.27MB
# 0.7%  0.28MB
# 0.8%
# 0.28MB
# 14 days
# us-east-1a
# i-0ac1c693
# cbdb-e1a-03s.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.31MB
# 1.0%  0.32MB
# 1.0%  0.31MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.32MB
# 1.0%
# 0.31MB
# 14 days
# us-east-1b
# i-0a31b4af2b66fd34b
# odpsync-e1b-05.odp.comcast.net
# c4.xlarge
# $143.28
# 2.1%  0.88MB
# 2.2%  0.84MB
# 2.2%  0.83MB
# 2.2%  0.88MB
# 2.2%  0.86MB
# 2.2%  0.88MB
# 2.2%  0.86MB
# 2.2%  0.85MB
# 2.1%  0.82MB
# 2.1%  0.82MB
# 2.1%  0.79MB
# 2.0%  0.65MB
# 2.3%  0.88MB
# 2.4%  0.94MB
# 2.2%
# 0.84MB
# 14 days
# us-east-1a
# i-03e381966dfd0fef9
# odpcworker-e1a-04.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.9%  0.86MB
# 0.9%  0.92MB
# 0.9%  0.89MB
# 0.9%  0.90MB
# 0.9%  0.88MB
# 0.9%  0.88MB
# 0.9%  0.87MB
# 0.9%  0.88MB
# 0.9%  0.91MB
# 0.9%  0.88MB
# 0.9%  0.87MB
# 0.9%  0.82MB
# 0.9%  0.89MB
# 1.0%  0.88MB
# 0.9%
# 0.88MB
# 14 days
# us-east-1b
# i-992d350a
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $82.08
# 3.8%  6.19MB
# 3.6%  0.85MB
# 3.6%  0.85MB
# 3.7%  5.42MB
# 3.9%  10.12MB
# 3.9%  9.10MB
# 4.0%  5.77MB
# 3.7%  1.93MB
# 3.6%  0.85MB
# 3.6%  0.85MB
# 4.5%  13.09MB
# 4.0%  4.48MB
# 4.3%  16.87MB
# 3.8%  6.63MB
# 3.9%
# 5.93MB
# 6 days
# us-east-1a
# i-092da97789b13bdad
# JMeter-node
# c3.4xlarge
# $604.80
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-0ae0f12292d727db2
# JMeter-node
# c3.4xlarge
# $604.80
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-0db3eab70b075f763
# JMeter-node
# c3.4xlarge
# $604.80
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1b
# i-4c0c98df
# cbapi-e1b-04.cb.comcast.net
# c4.xlarge
# $40.94
# 0.8%  0.17MB
# 0.8%  0.17MB
# 0.8%  0.17MB
# 0.8%  0.17MB
# 18.8%  13.97MB
# 43.3%  32.67MB
# 43.5%  32.79MB
# 43.5%  32.79MB
# 44.1%  33.27MB
# 44.1%  33.28MB
# 43.4%  32.75MB
# 43.0%  32.46MB
# 43.1%  32.56MB
# 43.2%  32.62MB
# 29.5%
# 22.13MB
# 4 days
# us-east-1b
# i-c1039752
# cbapi-e1b-02.cb.comcast.net
# c4.xlarge
# $40.94
# 0.8%  0.17MB
# 0.8%  0.17MB
# 0.8%  0.17MB
# 0.8%  0.17MB
# 7.6%  5.45MB
# 16.7%  12.58MB
# 16.7%  12.65MB
# 16.7%  12.63MB
# 17.0%  12.84MB
# 17.0%  12.87MB
# 16.7%  12.64MB
# 16.5%  12.43MB
# 16.4%  12.42MB
# 16.5%  12.50MB
# 11.5%
# 8.55MB
# 4 days
# us-east-1a
# i-d8c1c641
# cbdb-e1a-02s.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.29MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.29MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%
# 0.28MB
# 14 days
# us-east-1d
# i-4fc5cc7e
# Django API STG(aphealth)
# m4.xlarge
# $144.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.5%  0.01MB
# 0.9%  0.01MB
# 0.4%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.2%
# 0.00MB
# 14 days
# us-east-1a
# i-0cf1dfcc2e31c56e1
# odpsync-e1a-07.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.9%  0.64MB
# 0.9%  0.67MB
# 0.9%  0.67MB
# 1.0%  0.68MB
# 1.0%  0.65MB
# 1.0%  0.66MB
# 1.0%  0.66MB
# 1.0%  0.66MB
# 1.0%  0.67MB
# 1.0%  0.66MB
# 0.9%  0.60MB
# 0.9%  0.50MB
# 1.0%  0.66MB
# 1.0%  0.69MB
# 1.0%
# 0.65MB
# 14 days
# us-east-1d
# i-969891a7
# Django Nginx STG(aphealth)
# m4.xlarge
# $144.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-36c2c5af
# cbdb-e1a-04.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.1%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.29MB
# 1.1%  0.30MB
# 1.0%
# 0.30MB
# 14 days
# us-east-1a
# i-fe2b7e67
# cbapi-e1a-04.cb.comcast.net
# c4.xlarge
# $40.94
# 0.7%  0.16MB
# 0.7%  0.16MB
# 0.7%  0.16MB
# 0.7%  0.17MB
# 13.5%  9.69MB
# 30.8%  22.50MB
# 32.0%  23.34MB
# 32.8%  23.94MB
# 32.8%  24.00MB
# 32.9%  24.10MB
# 32.6%  23.88MB
# 32.5%  23.78MB
# 32.4%  23.80MB
# 32.4%  23.84MB
# 22.0%
# 15.97MB
# 4 days
# us-east-1b
# i-1d02968e
# cbapi-e1b-01.cb.comcast.net
# c4.xlarge
# $40.94
# 0.8%  0.17MB
# 0.8%  0.17MB
# 0.8%  0.17MB
# 0.8%  0.17MB
# 19.0%  13.44MB
# 43.8%  31.44MB
# 43.9%  31.54MB
# 44.1%  31.64MB
# 44.7%  32.03MB
# 44.7%  32.14MB
# 44.0%  31.59MB
# 43.5%  31.27MB
# 43.7%  31.38MB
# 43.7%  31.36MB
# 29.9%
# 21.32MB
# 4 days
# us-east-1a
# i-17a6858e
# cblb-e1a-02s.cb.comcast.net
# c4.xlarge
# $143.28
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%  0.28MB
# 0.7%
# 0.28MB
# 14 days
# us-east-1a
# i-d9c1c640
# cbdb-e1a-04s.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.28MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.28MB
# 1.0%  0.29MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.29MB
# 1.0%
# 0.28MB
# 14 days
# us-east-1d
# i-05cc1ffeddf8d3c4d
# new-dev-elk-master-node-1d
# m4.2xlarge
# $288.00
# 0.1%  0.40MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.40MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.38MB
# 0.1%
# 0.39MB
# 14 days
# us-east-1a
# i-04853074ffa2f70d4
# odpsync-e1a-08.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.63MB
# 1.1%  0.66MB
# 1.2%  0.66MB
# 1.2%  0.67MB
# 1.1%  0.64MB
# 1.1%  0.65MB
# 1.2%  0.65MB
# 1.2%  0.64MB
# 1.1%  0.66MB
# 1.2%  0.65MB
# 1.1%  0.59MB
# 1.1%  0.51MB
# 1.1%  0.67MB
# 1.1%  0.68MB
# 1.1%
# 0.64MB
# 14 days
# us-east-1b
# i-042a9fa155c1850a4
# odpsync-e1b-04.odp.comcast.net
# c4.xlarge
# $143.28
# 2.4%  0.82MB
# 2.4%  0.84MB
# 2.4%  0.83MB
# 2.4%  0.85MB
# 2.4%  0.83MB
# 2.3%  0.86MB
# 2.3%  0.84MB
# 2.3%  0.84MB
# 2.2%  0.82MB
# 2.2%  0.82MB
# 2.1%  0.79MB
# 2.0%  0.66MB
# 2.3%  0.89MB
# 2.3%  0.94MB
# 2.3%
# 0.83MB
# 14 days
# us-east-1b
# i-06630e45db6a1a5f6
# odpcworker-e1b-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.8%  0.87MB
# 0.9%  0.91MB
# 0.8%  0.88MB
# 0.8%  0.91MB
# 0.8%  0.88MB
# 0.8%  0.87MB
# 0.8%  0.86MB
# 0.7%  0.87MB
# 0.7%  0.90MB
# 0.7%  0.88MB
# 0.8%  0.86MB
# 0.8%  0.80MB
# 0.8%  0.89MB
# 0.9%  0.88MB
# 0.8%
# 0.88MB
# 14 days
# us-east-1a
# i-0eb6789774fe4c885
# Netscout Kpi hourly dev
# m3.xlarge
# $191.52
# 3.4%  0.15MB
# 3.4%  0.14MB
# 3.4%  0.14MB
# 3.3%  0.14MB
# 3.3%  0.40MB
# 3.5%  0.27MB
# 3.3%  0.14MB
# 3.3%  0.14MB
# 3.3%  0.14MB
# 3.2%  0.14MB
# 3.3%  0.14MB
# 3.3%  0.14MB
# 3.3%  0.14MB
# 3.3%  0.14MB
# 3.3%
# 0.17MB
# 14 days
# us-east-1a
# i-0ae535f3b04a01e65
# cbelkweb-e1a-01.cb.comcast.net
# m4.large
# $72.00
# 1.0%  0.24MB
# 0.9%  0.23MB
# 0.9%  0.24MB
# 0.9%  0.24MB
# 0.9%  0.24MB
# 0.9%  0.24MB
# 0.9%  0.25MB
# 1.0%  0.25MB
# 1.0%  0.28MB
# 1.0%  0.25MB
# 0.9%  0.24MB
# 1.0%  0.26MB
# 1.0%  0.25MB
# 1.0%  0.25MB
# 1.0%
# 0.25MB
# 14 days
# us-east-1a
# i-37c2c5ae
# cbdb-e1a-01.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.1%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.1%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.31MB
# 1.0%  0.32MB
# 1.0%
# 0.32MB
# 14 days
# us-east-1b
# i-0b11ddbf67d6c176f
# CB-DEV-NODE
# m4.4xlarge
# $576.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1b
# i-0f4fe21f27434b62d
# django Dev
# m4.xlarge
# $144.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1b
# i-05bb2ed02e1cac0d5
# odpcworker-e1b-03.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.9%  0.86MB
# 0.9%  0.91MB
# 0.8%  0.87MB
# 0.8%  0.90MB
# 0.8%  0.87MB
# 0.8%  0.86MB
# 0.8%  0.86MB
# 0.8%  0.86MB
# 0.9%  0.88MB
# 0.8%  0.87MB
# 0.8%  0.85MB
# 0.8%  0.80MB
# 0.8%  0.87MB
# 0.8%  0.88MB
# 0.8%
# 0.87MB
# 14 days
# us-east-1a
# i-0f75d1c0fcf1008e5
# odpsprkm-e1a-01.odp.comcast.net
# c4.4xlarge
# $573.12
# 0.4%  0.74MB
# 0.4%  0.77MB
# 0.4%  0.77MB
# 0.4%  0.78MB
# 0.4%  0.77MB
# 0.4%  0.77MB
# 0.4%  0.80MB
# 0.4%  0.77MB
# 0.4%  0.80MB
# 0.4%  0.76MB
# 0.4%  0.77MB
# 0.4%  0.66MB
# 0.4%  0.78MB
# 0.4%  0.77MB
# 0.4%
# 0.77MB
# 14 days
# us-east-1b
# i-05def4a05818b317b
# odpcworker-e1b-01.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.88MB
# 1.1%  0.92MB
# 1.0%  0.89MB
# 1.0%  0.91MB
# 1.0%  0.88MB
# 1.1%  0.86MB
# 0.8%  0.86MB
# 1.1%  0.87MB
# 1.1%  0.89MB
# 1.0%  0.88MB
# 1.0%  0.86MB
# 1.0%  0.80MB
# 1.0%  0.88MB
# 1.1%  0.88MB
# 1.0%
# 0.88MB
# 14 days
# us-east-1b
# i-0029cb28871d15df0
# cbelkdata-e1b-02.cb.comcast.net
# i3.xlarge
# $208.59
# 2.0%  0.90MB
# 2.0%  0.90MB
# 2.0%  0.90MB
# 2.0%  0.90MB
# 2.0%  0.89MB
# 2.0%  0.89MB
# 2.0%  0.91MB
# 2.0%  0.90MB
# 2.0%  0.94MB
# 2.0%  0.91MB
# 2.1%  0.98MB
# 2.0%  1.01MB
# 2.0%  0.97MB
# 2.5%  105.63MB
# 2.1%
# 8.40MB
# 13 days
# us-east-1a
# i-03c199fcbd48c99ba
# odpsync-e1a-05.odp.comcast.net
# c4.xlarge
# $143.28
# 2.1%  0.69MB
# 2.1%  0.70MB
# 2.1%  0.69MB
# 2.1%  0.71MB
# 2.1%  0.68MB
# 2.1%  0.68MB
# 2.1%  0.68MB
# 2.1%  0.68MB
# 2.1%  0.70MB
# 2.1%  0.69MB
# 2.0%  0.62MB
# 1.9%  0.51MB
# 2.1%  0.69MB
# 2.1%  0.72MB
# 2.1%
# 0.68MB
# 14 days
# us-east-1b
# i-05c99b4d1e5e0c307
# odpsync-e1b-01.odp.comcast.net
# c4.xlarge
# $143.28
# 2.2%  0.82MB
# 2.2%  0.84MB
# 2.2%  0.83MB
# 2.2%  0.86MB
# 2.2%  0.85MB
# 2.2%  0.86MB
# 2.2%  0.84MB
# 2.2%  0.84MB
# 2.2%  0.83MB
# 2.2%  0.82MB
# 2.1%  0.80MB
# 2.0%  0.65MB
# 2.3%  0.89MB
# 2.3%  0.94MB
# 2.2%
# 0.83MB
# 14 days
# us-east-1a
# i-0e4258872597cce69
# odpproxy-e1a-02.odp.comcast.net
# c4.xlarge
# $143.28
# 0.7%  0.29MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.32MB
# 0.7%  0.32MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%  0.31MB
# 0.7%
# 0.31MB
# 14 days
# us-east-1a
# i-dac1c643
# cbdb-e1a-06s.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.27MB
# 1.0%  0.28MB
# 1.0%
# 0.28MB
# 14 days
# us-east-1a
# i-01d73c95a2abeb51a
# odpsync-e1a-03.odp.comcast.net
# c4.xlarge
# $143.28
# 2.1%  0.69MB
# 2.2%  0.70MB
# 2.2%  0.70MB
# 2.2%  0.71MB
# 2.1%  0.68MB
# 2.2%  0.69MB
# 2.2%  0.69MB
# 2.2%  0.69MB
# 2.2%  0.70MB
# 2.2%  0.69MB
# 2.1%  0.63MB
# 1.8%  0.41MB
# 1.8%  0.36MB
# 1.8%  0.37MB
# 2.1%
# 0.62MB
# 14 days
# us-east-1a
# i-1aa68583
# cbapi-e1a-01s.cb.comcast.net
# c4.xlarge
# $143.28
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.17MB
# 0.6%  0.17MB
# 0.6%  0.16MB
# 0.6%  0.17MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%
# 0.16MB
# 14 days
# us-east-1b
# i-08daf06facbf6dcf7
# odpsync-e1b-07.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.84MB
# 1.0%  0.81MB
# 1.1%  0.80MB
# 1.1%  0.83MB
# 1.0%  0.81MB
# 1.1%  0.83MB
# 1.2%  0.81MB
# 1.1%  0.81MB
# 1.2%  0.79MB
# 1.2%  0.79MB
# 1.1%  0.77MB
# 1.0%  0.65MB
# 1.1%  0.87MB
# 1.2%  0.92MB
# 1.1%
# 0.81MB
# 14 days
# us-east-1b
# i-05ce1ea2f93d08fbb
# odpsprkm-e1b-01.odp.comcast.net
# c4.4xlarge
# $245.62
# 0.4%  0.70MB
# 0.4%  0.73MB
# 0.4%  0.73MB
# 0.4%  0.73MB
# 0.4%  0.73MB
# 0.4%  0.73MB
# 0.8%  28.15MB
# 1.7%  90.70MB
# 1.7%  90.69MB
# 1.7%  91.02MB
# 1.7%  90.80MB
# 1.5%  74.93MB
# 0.7%  18.94MB
# 0.8%  19.01MB
# 0.9%
# 36.33MB
# 6 days
# us-east-1d
# i-03930f4a9a1155864
# cbelkmstr-e1d-01stg.cb.comcast.net
# m4.2xlarge
# $288.00
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%  0.71MB
# 0.1%  0.70MB
# 0.1%  0.70MB
# 0.1%
# 0.70MB
# 14 days
# us-east-1a
# i-06f60a83f269dd949
# odpsync-e1a-10.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.9%  0.65MB
# 0.9%  0.67MB
# 0.9%  0.67MB
# 0.9%  0.68MB
# 0.9%  0.65MB
# 0.9%  0.66MB
# 0.9%  0.66MB
# 0.9%  0.65MB
# 0.9%  0.67MB
# 0.9%  0.66MB
# 0.9%  0.60MB
# 0.9%  0.51MB
# 1.0%  0.67MB
# 0.9%  0.69MB
# 0.9%
# 0.65MB
# 14 days
# us-east-1a
# i-08e5a7a72d9307502
# odpzoo-e1a-03.odp.comcast.net
# c4.xlarge
# $143.28
# 1.8%  0.38MB
# 1.8%  0.41MB
# 1.8%  0.41MB
# 1.8%  0.41MB
# 1.8%  0.41MB
# 1.8%  0.41MB
# 1.7%  0.41MB
# 1.7%  0.40MB
# 1.7%  0.40MB
# 1.7%  0.40MB
# 1.7%  0.40MB
# 1.7%  0.40MB
# 2.0%  0.40MB
# 1.8%  0.41MB
# 1.8%
# 0.40MB
# 14 days
# us-east-1b
# i-b72f5724
# cbdb-e1b-03.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.1%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.31MB
# 1.0%  0.32MB
# 1.0%
# 0.32MB
# 14 days
# us-east-1d
# i-07896ecb385a422ab
# cassandra-3.10-databasetest-1
# c3.xlarge
# $151.20
# 0.4%  0.00MB
# 0.5%  0.01MB
# 0.5%  0.00MB
# 0.5%  0.00MB
# 0.5%  0.00MB
# 0.5%  0.01MB
# 0.4%  0.00MB
# 0.4%  0.00MB
# 0.4%  0.01MB
# 0.4%  0.01MB
# 0.4%  0.00MB
# 0.4%  0.00MB
# 0.4%  0.00MB
# 0.4%  0.00MB
# 0.4%
# 0.00MB
# 14 days
# us-east-1a
# i-a6c2c53f
# cbdb-e1a-03.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.1%  0.33MB
# 1.0%  0.32MB
# 1.0%  0.33MB
# 1.0%  0.33MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.0%  0.32MB
# 1.1%  0.32MB
# 1.0%  0.32MB
# 1.0%
# 0.33MB
# 14 days
# us-east-1a
# i-f5a6856c
# cbapi-e1a-03s.cb.comcast.net
# c4.xlarge
# $143.28
# 0.5%  0.16MB
# 0.5%  0.16MB
# 0.5%  0.16MB
# 0.5%  0.16MB
# 0.5%  0.16MB
# 0.6%  0.17MB
# 0.5%  0.17MB
# 0.5%  0.17MB
# 0.5%  0.17MB
# 0.5%  0.17MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.5%
# 0.16MB
# 14 days
# us-east-1a
# i-3b8bcea2
# CB-D3-STG
# m4.4xlarge
# $576.00
# 0.0%  0.01MB
# 0.0%  0.01MB
# 0.0%  0.01MB
# 0.0%  0.01MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%  0.01MB
# 0.0%  0.01MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%  0.01MB
# 0.0%
# 0.01MB
# 14 days
# us-east-1b
# i-0e85524e26f9b5b61
# odpzoo-e1b-03.odp.comcast.net
# c4.xlarge
# $143.28
# 2.0%  0.39MB
# 2.0%  0.43MB
# 2.0%  0.43MB
# 2.0%  0.43MB
# 2.0%  0.43MB
# 2.0%  0.43MB
# 2.0%  0.44MB
# 2.0%  0.44MB
# 2.1%  0.43MB
# 2.1%  0.43MB
# 2.0%  0.43MB
# 2.0%  0.43MB
# 2.0%  0.42MB
# 2.0%  0.43MB
# 2.0%
# 0.43MB
# 14 days
# us-east-1a
# i-82c2c51b
# cbdb-e1a-05s.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.28MB
# 1.0%  0.27MB
# 1.0%  0.28MB
# 1.0%
# 0.28MB
# 14 days
# us-east-1b
# i-0e247d8cc598bb642
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $82.08
# 0.8%  9.12MB
# 0.6%  0.09MB
# 0.7%  0.09MB
# 0.7%  4.45MB
# 0.9%  14.91MB
# 0.8%  7.59MB
# 0.9%  14.68MB
# 0.7%  1.88MB
# 0.6%  0.09MB
# 0.6%  0.09MB
# 1.3%  27.70MB
# 0.8%  11.00MB
# 1.4%  24.22MB
# 5.2%  12.02MB
# 1.2%
# 9.14MB
# 6 days
# us-east-1b
# i-0f24d361a84e1398a
# CB-STG-NODE-RDKB
# m4.4xlarge
# $576.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%
# 0.01MB
# 14 days
# us-east-1a
# i-16a6858f
# cblb-e1a-01s.cb.comcast.net
# c4.xlarge
# $143.28
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.27MB
# 0.5%  0.26MB
# 0.5%  0.27MB
# 0.5%
# 0.27MB
# 14 days
# us-east-1b
# i-0d57e7434a1fdeae9
# odpsync-e1b-03.odp.comcast.net
# c4.xlarge
# $143.28
# 2.2%  0.86MB
# 2.3%  0.84MB
# 2.3%  0.83MB
# 2.3%  0.86MB
# 2.3%  0.85MB
# 2.3%  0.86MB
# 2.2%  0.84MB
# 2.2%  0.84MB
# 2.2%  0.83MB
# 2.2%  0.81MB
# 2.2%  0.80MB
# 2.0%  0.66MB
# 2.4%  0.89MB
# 2.4%  0.94MB
# 2.2%
# 0.84MB
# 14 days
# us-east-1b
# i-06e226dfe7b1c0550
# odpproxy-e1b-02.odp.comcast.net
# c4.xlarge
# $143.28
# 1.1%  0.28MB
# 1.1%  0.31MB
# 1.1%  0.31MB
# 1.1%  0.31MB
# 1.1%  0.31MB
# 1.1%  0.31MB
# 1.1%  0.31MB
# 1.1%  0.31MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.30MB
# 1.1%  0.31MB
# 1.1%
# 0.30MB
# 14 days
# us-east-1d
# i-ce386fff
# CB-D3-DEV
# m4.4xlarge
# $576.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-c6a4a05f
# cbdb-e1a-01s.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%
# 0.31MB
# 14 days
# us-east-1a
# i-049bf742ca97abbf6
# cbelkmstr-e1a-01stg.cb.comcast.net
# m4.2xlarge
# $288.00
# 0.1%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%  0.36MB
# 0.0%
# 0.36MB
# 14 days
# us-east-1b
# i-0b4525e83831d5e86
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $123.12
# 0.6%  3.08MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.5%  0.60MB
# 0.7%  7.40MB
# 0.6%  0.90MB
# 0.8%  6.44MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 2.3%  11.36MB
# 0.8%  1.54MB
# 4.4%  12.94MB
# 5.1%  7.07MB
# 1.3%
# 3.69MB
# 9 days
# us-east-1a
# i-0ad7ddc40007a5941
# CB-ELK-data-node-2
# r3.2xlarge
# $478.80
# 0.5%  0.85MB
# 0.5%  0.86MB
# 0.5%  0.85MB
# 0.5%  0.86MB
# 0.4%  0.85MB
# 0.4%  0.85MB
# 0.5%  0.86MB
# 0.4%  0.86MB
# 0.4%  0.85MB
# 0.4%  0.85MB
# 0.5%  0.86MB
# 0.4%  0.85MB
# 0.5%  0.85MB
# 0.4%  0.85MB
# 0.4%
# 0.86MB
# 14 days
# us-east-1b
# i-0e2549997c61f5231
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $123.12
# 0.7%  3.10MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 0.6%  0.60MB
# 0.8%  7.42MB
# 0.6%  0.89MB
# 0.8%  5.16MB
# 0.6%  0.41MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 2.6%  12.36MB
# 0.7%  0.90MB
# 4.4%  12.91MB
# 5.2%  8.11MB
# 1.4%
# 3.73MB
# 9 days
# us-east-1b
# i-0f4fddd1b9fa2d254
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $150.48
# 0.7%  3.02MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.6%  0.60MB
# 0.8%  7.05MB
# 0.6%  0.90MB
# 0.6%  0.63MB
# 0.6%  0.52MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 4.1%  17.82MB
# 0.6%  0.78MB
# 3.5%  10.02MB
# 0.6%  0.52MB
# 1.1%
# 3.01MB
# 11 days
# us-east-1b
# i-06d293bfcd0535898
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $150.48
# 0.7%  2.89MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.60MB
# 0.8%  7.18MB
# 0.7%  1.23MB
# 0.8%  4.62MB
# 0.6%  0.21MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 2.4%  11.92MB
# 0.7%  0.77MB
# 2.6%  4.75MB
# 5.3%  7.51MB
# 1.3%
# 3.00MB
# 11 days
# us-east-1a
# i-0e2164a13338ccc82
# cbelkweb-e1a-01s.cb.comcast.net
# m4.large
# $72.00
# 0.9%  0.42MB
# 1.0%  0.40MB
# 1.0%  0.40MB
# 0.9%  0.41MB
# 1.0%  0.41MB
# 0.8%  0.41MB
# 0.9%  0.42MB
# 0.9%  0.42MB
# 0.9%  0.42MB
# 0.9%  0.42MB
# 0.9%  0.44MB
# 0.9%  0.44MB
# 1.0%  0.44MB
# 1.0%  0.43MB
# 0.9%
# 0.42MB
# 14 days
# us-east-1d
# i-011b4083dcf557cdf
# django_state_table-api
# t2.large
# $67.68
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-03bd61d590e366986
# odpsync-e1a-04.odp.comcast.net
# c4.xlarge
# $143.28
# 2.2%  0.68MB
# 2.2%  0.69MB
# 2.3%  0.69MB
# 2.3%  0.70MB
# 2.3%  0.67MB
# 2.2%  0.68MB
# 2.2%  0.68MB
# 2.2%  0.68MB
# 2.2%  0.70MB
# 2.2%  0.68MB
# 2.2%  0.62MB
# 2.0%  0.51MB
# 2.3%  0.69MB
# 2.3%  0.72MB
# 2.2%
# 0.67MB
# 14 days
# us-east-1b
# i-5b0c98c8
# cbd3-e1b-03.cb.comcast.net
# c4.xlarge
# $143.28
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.5%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.4%  0.15MB
# 0.5%  0.15MB
# 0.4%  0.15MB
# 0.4%
# 0.15MB
# 14 days
# us-east-1b
# i-0a686dd124d89f7d3
# Django druid
# m4.xlarge
# $144.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.01MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-08d17523328f8af3e
# odprabbit-e1a-01.odp.comcast.net
# c4.xlarge
# $143.28
# 1.6%  1.85MB
# 1.6%  1.90MB
# 1.7%  1.89MB
# 1.6%  1.91MB
# 1.5%  1.90MB
# 1.6%  1.91MB
# 1.6%  1.89MB
# 1.6%  1.92MB
# 1.6%  1.96MB
# 1.5%  1.94MB
# 1.5%  1.96MB
# 1.5%  1.91MB
# 1.5%  1.83MB
# 1.6%  1.88MB
# 1.6%
# 1.90MB
# 14 days
# us-east-1d
# i-0fb9d045a62b31b71
# cbelkdata-e1d-01stg.cb.comcast.net
# i3.xlarge
# $224.64
# 0.1%  0.37MB
# 0.1%  0.37MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.37MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.37MB
# 0.2%  0.38MB
# 0.1%
# 0.38MB
# 14 days
# us-east-1b
# i-0cdae32e637e3525e
# CB-DEV-NODECLUSTER
# m4.4xlarge
# $576.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-09a80282049f8b47f
# nan
# m3.xlarge
# $191.52
# nan
# nan
# nan
# nan
# 0.9%  0.27MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.6%  0.07MB
# 0.5%  0.37MB
# 0.6%
# 0.12MB
# 10 days
# us-east-1a
# i-0fac2a31a5bdcc6a7
# nan
# m3.xlarge
# $191.52
# nan
# nan
# nan
# nan
# 4.1%  1.94MB
# 3.3%  0.14MB
# 3.2%  0.14MB
# 3.2%  0.14MB
# 3.3%  0.14MB
# 3.3%  0.14MB
# 3.2%  0.14MB
# 3.2%  0.13MB
# 3.2%  0.13MB
# 3.2%  0.61MB
# 3.3%
# 0.36MB
# 10 days
# us-east-1b
# i-02efc819e724a5b92
# odpzoo-e1b-02.odp.comcast.net
# c4.xlarge
# $143.28
# 1.8%  0.40MB
# 1.7%  0.43MB
# 1.7%  0.43MB
# 1.7%  0.43MB
# 1.7%  0.42MB
# 1.7%  0.42MB
# 1.7%  0.42MB
# 1.6%  0.41MB
# 1.6%  0.41MB
# 1.8%  0.41MB
# 1.7%  0.40MB
# 1.7%  0.41MB
# 1.6%  0.40MB
# 1.6%  0.41MB
# 1.7%
# 0.41MB
# 14 days
# us-east-1b
# i-2d0195be
# cbapi-e1b-03.cb.comcast.net
# c4.xlarge
# $40.94
# 0.8%  0.16MB
# 0.9%  0.16MB
# 0.9%  0.16MB
# 0.8%  0.16MB
# 23.3%  17.46MB
# 54.0%  41.15MB
# 54.2%  41.31MB
# 54.2%  41.28MB
# 55.1%  42.03MB
# 55.0%  41.98MB
# 53.7%  40.93MB
# 53.1%  40.44MB
# 53.4%  40.72MB
# 53.8%  41.00MB
# 36.6%
# 27.78MB
# 4 days
# us-east-1b
# i-610296f2
# cbd3-e1b-02.cb.comcast.net
# c4.xlarge
# $143.28
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%
# 0.14MB
# 14 days
# us-east-1b
# i-0058415be1060aee8
# cbelkmstr-e1b-01stg.cb.comcast.net
# m4.2xlarge
# $288.00
# 0.1%  1.60MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%  1.59MB
# 0.1%
# 1.59MB
# 14 days
# us-east-1a
# i-212b7eb8
# cbapi-e1a-01.cb.comcast.net
# c4.xlarge
# $143.28
# 6.4%  0.20MB
# 6.5%  0.20MB
# 6.4%  0.20MB
# 6.4%  0.20MB
# 6.4%  0.20MB
# 6.2%  0.20MB
# 6.1%  0.20MB
# 6.1%  0.20MB
# 6.0%  0.20MB
# 6.1%  0.20MB
# 6.6%  0.20MB
# 6.4%  0.20MB
# 6.3%  0.19MB
# 6.2%  0.20MB
# 6.3%
# 0.20MB
# 14 days
# us-east-1b
# i-812e5612
# cbdb-e1b-02.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.16MB
# 1.1%  0.16MB
# 1.1%  0.16MB
# 1.1%  0.17MB
# 1.1%
# 0.17MB
# 14 days
# us-east-1b
# i-0689c44c463537dfd
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.7%  2.99MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.60MB
# 0.8%  7.49MB
# 0.7%  0.91MB
# 0.7%  1.06MB
# 0.7%  0.22MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 4.4%  21.35MB
# 0.7%  1.10MB
# 3.4%  8.06MB
# 5.4%  7.36MB
# 1.4%
# 3.68MB
# 10 days
# us-east-1a
# i-0a7bf540a078c0bae
# cbelkdata-e1a-01stg.cb.comcast.net
# i3.xlarge
# $224.64
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%  0.38MB
# 0.1%
# 0.38MB
# 14 days
# us-east-1a
# i-044682d71bce0e1ff
# cbelkmstr-e1a-01.cb.comcast.net
# m4.xlarge
# $144.00
# 0.7%  0.52MB
# 0.7%  0.51MB
# 0.7%  0.51MB
# 0.7%  0.51MB
# 0.6%  0.51MB
# 0.6%  0.51MB
# 0.7%  0.52MB
# 0.6%  0.52MB
# 0.7%  0.53MB
# 0.7%  0.53MB
# 0.6%  0.51MB
# 0.6%  0.53MB
# 0.6%  0.53MB
# 0.6%  0.50MB
# 0.7%
# 0.52MB
# 14 days
# us-east-1b
# i-c0265e53
# cbdb-e1b-04.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.0%  0.29MB
# 1.1%  0.30MB
# 1.0%
# 0.30MB
# 14 days
# us-east-1b
# i-025d418fa3650b53a
# cbops-e1b-01.cb.comcast.net
# c4.xlarge
# $143.28
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.14MB
# 0.7%  0.13MB
# 0.7%  0.14MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%  0.13MB
# 0.7%
# 0.13MB
# 14 days
# us-east-1a
# i-a5c2c53c
# cbdb-e1a-06.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.0%  0.31MB
# 1.1%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.1%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.30MB
# 1.0%  0.29MB
# 1.1%  0.30MB
# 1.0%
# 0.30MB
# 14 days
# us-east-1d
# i-28e9de26
# django_exec1 STG
# m4.xlarge
# $144.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1a
# i-037e62280f4e25da7
# cbelkmstr-e1a-01s.cb.comcast.net
# m4.xlarge
# $144.00
# 0.4%  0.19MB
# 0.4%  0.19MB
# 0.4%  0.19MB
# 0.4%  0.19MB
# 0.4%  0.18MB
# 0.4%  0.18MB
# 0.4%  0.18MB
# 0.4%  0.19MB
# 0.4%  0.19MB
# 0.5%  0.26MB
# 0.4%  0.19MB
# 0.4%  0.19MB
# 0.4%  0.20MB
# 0.5%  0.23MB
# 0.4%
# 0.20MB
# 14 days
# us-east-1b
# i-0377468f57cc5c9b1
# odpcworker-e1b-04.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.86MB
# 1.0%  0.91MB
# 1.0%  0.88MB
# 1.0%  0.91MB
# 1.0%  0.88MB
# 0.9%  0.88MB
# 0.8%  0.87MB
# 0.8%  0.88MB
# 1.0%  0.89MB
# 1.0%  0.88MB
# 0.8%  0.87MB
# 0.7%  0.80MB
# 0.8%  0.88MB
# 0.8%  0.89MB
# 0.9%
# 0.88MB
# 14 days
# us-east-1b
# i-08c31ae5c7c272a3a
# odpsync-e1b-06.odp.comcast.net
# c4.xlarge
# $143.28
# 2.3%  0.84MB
# 2.5%  0.84MB
# 2.6%  0.83MB
# 2.3%  0.86MB
# 2.3%  0.83MB
# 2.4%  0.85MB
# 2.5%  0.83MB
# 2.5%  0.83MB
# 2.2%  0.82MB
# 2.1%  0.81MB
# 2.1%  0.79MB
# 2.4%  0.65MB
# 2.7%  0.89MB
# 2.7%  0.94MB
# 2.4%
# 0.83MB
# 14 days
# us-east-1b
# i-0871bbea411c3182c
# cbelkdata-e1b-01stg.cb.comcast.net
# i3.xlarge
# $224.64
# 0.2%  0.40MB
# 0.2%  0.40MB
# 0.2%  0.40MB
# 0.2%  0.40MB
# 0.2%  0.40MB
# 0.2%  0.40MB
# 0.2%  0.40MB
# 0.1%  0.40MB
# 0.1%  0.40MB
# 0.1%  0.40MB
# 0.2%  0.40MB
# 0.1%  0.40MB
# 0.1%  0.40MB
# 0.2%  0.40MB
# 0.2%
# 0.40MB
# 14 days
# us-east-1b
# i-b60c9825
# cblb-e1b-01.cb.comcast.net
# c4.xlarge
# $143.28
# 0.6%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.28MB
# 0.5%  0.27MB
# 0.5%  0.28MB
# 0.5%
# 0.28MB
# 14 days
# us-east-1b
# i-0ef1b7cc8786fa741
# odpzoo-e1b-01.odp.comcast.net
# c4.xlarge
# $143.28
# 1.7%  0.35MB
# 1.8%  0.38MB
# 1.8%  0.38MB
# 1.8%  0.38MB
# 1.7%  0.38MB
# 1.7%  0.38MB
# 1.7%  0.39MB
# 1.7%  0.40MB
# 1.8%  0.40MB
# 1.8%  0.39MB
# 1.7%  0.39MB
# 1.7%  0.39MB
# 1.7%  0.39MB
# 1.7%  0.40MB
# 1.7%
# 0.39MB
# 14 days
# us-east-1a
# i-74243963
# CB-Terraform-Jenkins
# t2.small
# $7.10
# 1.6%  49.07MB
# 1.2%  71.11MB
# 0.4%  5.09MB
# 0.7%  21.20MB
# 0.5%  5.92MB
# 0.4%  4.99MB
# 0.4%  3.56MB
# 0.4%  2.60MB
# 0.4%  3.03MB
# 0.4%  1.50MB
# 0.5%  10.28MB
# 0.9%  37.67MB
# 0.4%  2.96MB
# 0.7%  20.55MB
# 0.6%
# 17.11MB
# 6 days
# us-east-1b
# i-014af8b229a8cade1
# odpproxy-e1b-01.odp.comcast.net
# c4.xlarge
# $143.28
# 0.8%  0.29MB
# 0.8%  0.31MB
# 0.8%  0.31MB
# 0.9%  0.31MB
# 0.8%  0.31MB
# 1.1%  0.31MB
# 1.1%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.31MB
# 1.0%  0.30MB
# 1.0%  0.31MB
# 1.0%
# 0.31MB
# 14 days
# us-east-1b
# i-016347d8ea8f2712f
# odprabbit-e1b-02.odp.comcast.net
# c4.xlarge
# $143.28
# 1.7%  1.33MB
# 1.7%  1.36MB
# 1.7%  1.37MB
# 1.7%  1.38MB
# 1.7%  1.39MB
# 1.7%  1.40MB
# 1.6%  1.41MB
# 1.6%  1.41MB
# 1.6%  1.42MB
# 1.7%  1.42MB
# 1.6%  1.46MB
# 1.7%  1.44MB
# 1.5%  1.37MB
# 1.6%  1.38MB
# 1.7%
# 1.39MB
# 14 days
# us-east-1b
# i-0502666ad3180869f
# odpsync-e1b-02.odp.comcast.net
# c4.xlarge
# $143.28
# 2.1%  0.83MB
# 2.1%  0.84MB
# 2.2%  0.83MB
# 2.3%  0.86MB
# 2.1%  0.84MB
# 2.1%  0.86MB
# 2.1%  0.84MB
# 2.1%  0.83MB
# 2.2%  0.82MB
# 2.2%  0.82MB
# 2.1%  0.78MB
# 1.7%  0.58MB
# 1.8%  0.56MB
# 1.8%  0.59MB
# 2.1%
# 0.78MB
# 14 days
# us-east-1a
# i-015e3544aedbda83b
# dev-influxdb
# m3.xlarge
# $191.52
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.3%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.3%  0.05MB
# 0.2%  0.00MB
# 0.2%  0.00MB
# 0.2%
# 0.01MB
# 14 days
# us-east-1d
# i-046ee4953b8b14fd4
# CB-ELK-master-node-1
# m4.2xlarge
# $288.00
# 0.3%  1.21MB
# 0.3%  1.21MB
# 0.3%  1.20MB
# 0.3%  1.23MB
# 0.3%  1.20MB
# 0.3%  1.20MB
# 0.3%  1.21MB
# 0.3%  1.20MB
# 0.3%  1.20MB
# 0.3%  1.20MB
# 0.3%  1.21MB
# 0.3%  1.20MB
# 0.3%  1.20MB
# 0.3%  1.21MB
# 0.3%
# 1.21MB
# 14 days
# us-east-1d
# i-0d6d8a8af8ea1e0b5
# new-dev-elk-data-node-1d
# i3.xlarge
# $112.32
# 16.9%  207.36MB
# 16.9%  205.70MB
# 17.5%  211.36MB
# 17.4%  212.16MB
# 16.4%  200.98MB
# 16.7%  201.82MB
# 16.6%  201.85MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 0.4%  0.50MB
# 8.6%
# 103.19MB
# 7 days
# us-east-1b
# i-f60e9a65
# cbd3-e1b-01.cb.comcast.net
# c4.xlarge
# $143.28
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.15MB
# 0.5%  0.14MB
# 0.5%  0.15MB
# 0.5%
# 0.15MB
# 14 days
# us-east-1b
# i-073f35f7c155c29f7
# cbelkmstr-e1b-01.cb.comcast.net
# m4.xlarge
# $144.00
# 0.8%  0.51MB
# 0.8%  0.51MB
# 0.8%  0.50MB
# 0.8%  0.51MB
# 0.8%  0.50MB
# 0.8%  0.50MB
# 0.8%  0.50MB
# 0.8%  0.51MB
# 0.7%  0.52MB
# 0.8%  0.52MB
# 0.8%  0.53MB
# 0.8%  0.54MB
# 0.7%  0.53MB
# 0.8%  0.48MB
# 0.8%
# 0.51MB
# 14 days
# us-east-1b
# i-00807f77a4eec81fe
# cbelkdata-e1b-01.cb.comcast.net
# i3.xlarge
# $208.59
# 7.4%  1.16MB
# 7.4%  1.15MB
# 7.4%  1.16MB
# 7.4%  1.17MB
# 7.4%  1.15MB
# 7.4%  1.15MB
# 7.4%  1.16MB
# 7.4%  1.16MB
# 7.4%  1.21MB
# 7.4%  1.23MB
# 7.4%  1.31MB
# 7.4%  1.41MB
# 7.4%  1.22MB
# 8.3%  190.50MB
# 7.5%
# 14.72MB
# 13 days
# us-east-1a
# i-0950187d5fe23b596
# odpredis-e1a-02.odp.comcast.net
# c4.xlarge
# $143.28
# 0.9%  0.85MB
# 0.9%  0.85MB
# 0.9%  0.84MB
# 0.9%  0.83MB
# 0.9%  0.85MB
# 0.9%  0.83MB
# 0.9%  0.85MB
# 0.9%  0.97MB
# 0.9%  0.94MB
# 0.9%  0.68MB
# 0.9%  0.74MB
# 0.9%  0.94MB
# 0.9%  0.93MB
# 0.8%  1.01MB
# 0.9%
# 0.87MB
# 14 days
# us-east-1b
# i-05f120fb85eac961c
# odpsync-e1b-12.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.79MB
# 1.1%  0.82MB
# 1.0%  0.80MB
# 1.0%  0.83MB
# 1.0%  0.81MB
# 1.1%  0.83MB
# 1.2%  0.81MB
# 1.1%  0.80MB
# 1.2%  0.79MB
# 1.2%  0.79MB
# 1.1%  0.76MB
# 1.0%  0.64MB
# 1.2%  0.87MB
# 1.2%  0.92MB
# 1.1%
# 0.80MB
# 14 days
# us-east-1d
# i-0fd5fc8efd804a7fe
# CB-ELK-nginx
# t2.micro
# $8.64
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.2%  0.04MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%  0.03MB
# 0.1%
# 0.03MB
# 14 days
# us-east-1b
# i-05531b99339d74a42
# odpsync-e1b-11.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.80MB
# 1.0%  0.82MB
# 1.0%  0.80MB
# 1.0%  0.83MB
# 1.0%  0.81MB
# 1.0%  0.83MB
# 1.0%  0.80MB
# 1.0%  0.80MB
# 1.0%  0.78MB
# 1.0%  0.78MB
# 1.0%  0.76MB
# 0.9%  0.64MB
# 1.1%  0.87MB
# 1.1%  0.92MB
# 1.0%
# 0.80MB
# 14 days
# us-east-1a
# i-09ee49e8e43cad3b2
# odpsync-e1a-02.odp.comcast.net
# c4.xlarge
# $143.28
# 2.3%  0.67MB
# 2.4%  0.70MB
# 2.4%  0.70MB
# 2.4%  0.71MB
# 2.4%  0.68MB
# 2.4%  0.69MB
# 2.4%  0.69MB
# 2.2%  0.69MB
# 2.4%  0.70MB
# 2.4%  0.69MB
# 2.3%  0.62MB
# 2.2%  0.53MB
# 2.4%  0.70MB
# 2.4%  0.72MB
# 2.3%
# 0.68MB
# 14 days
# us-east-1d
# i-03e8fdbc98123a879
# CB-ELK-data-node-1
# r3.2xlarge
# $478.80
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.1%  0.35MB
# 0.1%  0.35MB
# 0.1%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%  0.35MB
# 0.0%
# 0.35MB
# 14 days
# us-east-1a
# i-058568e8d9da0c4d6
# odpsync-e1a-09.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.65MB
# 1.1%  0.66MB
# 1.2%  0.66MB
# 1.2%  0.67MB
# 1.1%  0.64MB
# 1.0%  0.65MB
# 0.9%  0.65MB
# 1.0%  0.65MB
# 1.2%  0.67MB
# 1.1%  0.65MB
# 1.1%  0.59MB
# 1.0%  0.50MB
# 1.1%  0.66MB
# 1.1%  0.69MB
# 1.1%
# 0.64MB
# 14 days
# us-east-1b
# i-ee0d997d
# cblb-e1b-02.cb.comcast.net
# c4.xlarge
# $143.28
# 0.6%  0.27MB
# 0.6%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.6%  0.27MB
# 0.6%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.7%  0.27MB
# 0.6%  0.27MB
# 0.6%  0.27MB
# 0.6%  0.27MB
# 0.7%  0.27MB
# 0.6%  0.27MB
# 0.6%
# 0.27MB
# 14 days
# us-east-1b
# i-0365cc73768ff268f
# new-dev-elk-master-node-1b
# m4.2xlarge
# $288.00
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.42MB
# 0.1%  0.39MB
# 0.1%  0.43MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.38MB
# 0.1%  0.39MB
# 0.1%  0.39MB
# 0.1%  0.38MB
# 0.1%  0.39MB
# 0.1%
# 0.39MB
# 14 days
# us-west-2b
# i-052da9ac27a7bdac4
# odpsprkw-w2b-04.odp.comcast.net
# m4.4xlarge
# $576.00
# 0.5%  3.49MB
# 0.5%  3.52MB
# 0.5%  3.52MB
# 0.5%  3.54MB
# 0.5%  3.53MB
# 0.5%  3.54MB
# 0.5%  3.54MB
# 0.5%  3.54MB
# 0.5%  3.57MB
# 0.5%  3.54MB
# 0.5%  3.26MB
# 0.4%  0.42MB
# 0.4%  0.42MB
# 0.4%  1.20MB
# 0.5%
# 2.90MB
# 14 days
# us-east-1b
# i-f70e9a64
# cbd3-e1b-04.cb.comcast.net
# c4.xlarge
# $143.28
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%  0.14MB
# 0.5%
# 0.14MB
# 14 days
# us-west-2c
# i-014df0589411dd9fb
# odpsync-w2c-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.7%  0.55MB
# 0.7%  0.62MB
# 0.7%  0.62MB
# 0.7%  0.62MB
# 0.7%  0.63MB
# 0.7%  0.63MB
# 0.7%  0.63MB
# 0.7%  0.63MB
# 0.7%  0.62MB
# 0.7%  0.63MB
# 0.7%  0.58MB
# 0.7%  0.66MB
# 0.7%  0.60MB
# 0.7%  0.62MB
# 0.7%
# 0.62MB
# 14 days
# us-west-2c
# i-029486cfaafeeb88d
# odphook-w2c-03.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.5%  0.48MB
# 0.4%  0.52MB
# 0.4%  0.51MB
# 0.4%  0.52MB
# 0.4%  0.52MB
# 0.6%  0.52MB
# 0.6%  0.52MB
# 0.6%  0.52MB
# 0.6%  0.55MB
# 0.6%  0.52MB
# 0.6%  0.48MB
# 0.6%  0.60MB
# 0.6%  0.52MB
# 0.8%  1.15MB
# 0.5%
# 0.57MB
# 14 days
# us-east-1d
# i-046f6293e1eb6f06c
# django STG auth test
# m4.2xlarge
# $288.00
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.03MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-west-2a
# i-02aa31c42281f3550
# orchestrator-chi-01.prod.us-west-2.plume.comcast.net
# t2.medium
# $33.84
# 0.9%  0.20MB
# 0.9%  0.23MB
# 0.9%  0.21MB
# 0.9%  0.19MB
# 0.9%  0.24MB
# 0.9%  0.26MB
# 0.9%  0.32MB
# 0.9%  0.25MB
# 0.9%  0.25MB
# 0.9%  0.26MB
# 0.9%  0.27MB
# 1.0%  0.32MB
# 1.0%  0.29MB
# 1.0%  0.32MB
# 0.9%
# 0.26MB
# 14 days
# us-west-2a
# i-0e56f60da39c4fe0c
# odpsprkw-w2a-14.odp.comcast.net
# m4.4xlarge
# $576.00
# 0.3%  0.49MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.45MB
# 0.3%  0.45MB
# 0.3%  0.42MB
# 0.3%  0.42MB
# 0.3%  0.45MB
# 0.3%  0.42MB
# 0.3%  0.38MB
# 0.2%  0.10MB
# 0.2%  0.10MB
# 0.3%  2.25MB
# 0.3%
# 0.52MB
# 14 days
# us-west-2b
# i-089c1b958407cf6ae
# rabbitmq-chi-02.prod.us-west-2.plume.comcast.net
# m4.xlarge
# $144.00
# 0.3%  1.74MB
# 0.3%  2.15MB
# 0.3%  1.82MB
# 0.3%  1.62MB
# 0.3%  1.64MB
# 0.3%  1.72MB
# 0.4%  2.68MB
# 0.3%  2.15MB
# 0.3%  2.20MB
# 0.3%  2.38MB
# 0.4%  2.50MB
# 0.3%  2.61MB
# 0.4%  4.11MB
# 0.4%  4.44MB
# 0.3%
# 2.41MB
# 14 days
# us-east-1a
# i-09d063492976096e1
# odpsync-e1a-12.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.65MB
# 1.2%  0.66MB
# 1.2%  0.66MB
# 1.1%  0.67MB
# 1.1%  0.64MB
# 1.1%  0.64MB
# 1.1%  0.64MB
# 1.2%  0.64MB
# 1.2%  0.66MB
# 1.1%  0.65MB
# 1.1%  0.59MB
# 0.9%  0.49MB
# 0.9%  0.67MB
# 0.9%  0.69MB
# 1.1%
# 0.64MB
# 14 days
# us-west-2b
# i-027327828a3c28b73
# odphook-w2b-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.6%  0.39MB
# 0.6%  0.42MB
# 0.6%  0.42MB
# 0.6%  0.42MB
# 0.5%  0.42MB
# 0.5%  0.42MB
# 0.5%  0.42MB
# 0.5%  0.42MB
# 0.5%  0.45MB
# 0.6%  0.42MB
# 0.4%  0.40MB
# 0.4%  0.41MB
# 0.4%  0.41MB
# 0.8%  1.12MB
# 0.5%
# 0.47MB
# 14 days
# us-east-1a
# i-0d05acbce9898392e
# Netscout Kpi hourly dev
# m3.xlarge
# $191.52
# 0.6%  0.07MB
# 0.6%  0.07MB
# 0.6%  0.07MB
# 0.6%  0.07MB
# 0.6%  0.32MB
# 0.9%  4.75MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.5%  0.07MB
# 0.6%  0.07MB
# 0.6%  0.07MB
# 0.6%  0.07MB
# 0.6%  0.07MB
# 0.6%  0.07MB
# 0.6%
# 0.42MB
# 14 days
# us-east-1b
# i-86067e15
# cbdb-e1b-06.cb.comcast.net
# c3.4xlarge
# $604.80
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.17MB
# 1.1%  0.16MB
# 1.1%  0.17MB
# 1.1%
# 0.17MB
# 14 days
# us-east-1d
# i-c8acbf56
# Cassandra-dev-3
# c3.4xlarge
# $604.80
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-east-1b
# i-0af79d65fd2c8472b
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.7%  3.19MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 0.6%  0.61MB
# 0.8%  7.13MB
# 0.7%  1.23MB
# 0.6%  0.72MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 3.8%  14.82MB
# 0.7%  0.90MB
# 2.9%  5.31MB
# 5.2%  8.67MB
# 1.3%
# 3.07MB
# 10 days
# us-east-1b
# i-05fbba97430ca3380
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $123.12
# 0.7%  3.03MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 0.6%  0.60MB
# 0.7%  7.06MB
# 0.7%  1.22MB
# 0.8%  5.28MB
# 0.7%  0.21MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 3.2%  17.19MB
# 0.7%  0.90MB
# 3.3%  7.68MB
# 5.5%  8.53MB
# 1.4%
# 3.72MB
# 9 days
# us-east-1b
# i-06ec2bd0fe95b2785
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.7%  3.05MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.60MB
# 0.8%  7.28MB
# 0.7%  0.89MB
# 0.8%  4.63MB
# 0.6%  0.08MB
# 0.6%  0.08MB
# 0.5%  0.08MB
# 4.5%  16.49MB
# 0.8%  1.57MB
# 3.4%  6.82MB
# 5.3%  7.32MB
# 1.5%
# 3.50MB
# 10 days
# us-east-1b
# i-00c8ab6f8ecc73e54
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $123.12
# 0.6%  3.03MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.5%  0.60MB
# 0.7%  7.35MB
# 0.6%  0.90MB
# 0.7%  6.15MB
# 0.5%  0.21MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 2.8%  13.01MB
# 0.6%  0.90MB
# 2.9%  5.19MB
# 5.3%  8.50MB
# 1.2%
# 3.30MB
# 9 days
# us-east-1b
# i-07905f14b54b93e52
# Quark-Dev-Testing-stgvpc
# m3.xlarge
# $136.80
# 0.6%  3.03MB
# 0.5%  0.08MB
# 0.6%  0.08MB
# 0.6%  0.68MB
# 0.8%  6.99MB
# 0.7%  0.98MB
# 0.9%  10.15MB
# 0.6%  0.39MB
# ...
# 0.9%  0.69MB
# 0.9%  0.69MB
# 1.0%  0.69MB
# 1.0%  0.70MB
# 1.0%  0.70MB
# 1.0%  0.70MB
# 0.8%  0.69MB
# 0.8%  0.69MB
# 0.8%  0.69MB
# 0.8%  0.65MB
# 0.8%  0.74MB
# 0.7%  0.68MB
# 0.7%  0.69MB
# 0.9%
# 0.69MB
# 14 days
# us-west-2b
# i-09efd6106efebe319
# es-es-esmaster-01.inf.us-west-2.plume.comcast.net
# t2.medium
# $33.84
# 0.6%  1.02MB
# 0.6%  1.02MB
# 0.6%  1.02MB
# 0.6%  1.02MB
# 0.6%  1.02MB
# 0.6%  1.04MB
# 0.6%  1.05MB
# 0.6%  1.05MB
# 0.6%  1.05MB
# 0.6%  1.05MB
# 0.6%  1.02MB
# 0.6%  1.02MB
# 0.6%  1.02MB
# 0.6%  1.02MB
# 0.6%
# 1.03MB
# 14 days
# us-west-2c
# i-094ab56633cdf36b3
# odprabbit-w2c-03.odp.comcast.net
# c4.xlarge
# $143.28
# 0.9%  0.31MB
# 0.9%  0.34MB
# 0.9%  0.34MB
# 0.9%  0.34MB
# 0.9%  0.55MB
# 0.9%  0.55MB
# 0.9%  0.54MB
# 0.9%  0.35MB
# 0.9%  0.35MB
# 0.9%  0.35MB
# 0.9%  0.35MB
# 0.9%  0.37MB
# 0.9%  0.37MB
# 0.9%  0.39MB
# 0.9%
# 0.39MB
# 14 days
# us-west-2c
# i-07ed9a6df57fafe27
# odpsprkw-w2c-05.odp.comcast.net
# m4.4xlarge
# $452.57
# 0.5%  5.71MB
# 0.5%  5.73MB
# 0.5%  5.74MB
# 0.5%  2.66MB
# 0.4%  1.96MB
# 0.4%  0.44MB
# 0.4%  0.44MB
# 0.4%  0.44MB
# 0.4%  0.47MB
# 0.4%  0.44MB
# 0.4%  0.38MB
# 0.4%  0.43MB
# 0.3%  0.42MB
# 0.4%  1.41MB
# 0.4%
# 1.90MB
# 11 days
# us-west-2a
# i-097ea81d86821a23d
# odpsprkw-w2a-11.odp.comcast.net
# m4.4xlarge
# $576.00
# 0.3%  0.48MB
# 0.3%  0.43MB
# 0.3%  0.47MB
# 0.3%  0.43MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.41MB
# 0.3%  0.42MB
# 0.4%  0.46MB
# 0.3%  0.43MB
# 0.3%  0.39MB
# 0.2%  0.08MB
# 0.2%  0.12MB
# 0.4%  2.52MB
# 0.3%
# 0.54MB
# 14 days
# us-west-2a
# i-0b6c03313be7029f9
# mongodb-production-01.shared.us-west-2.plume.comcast.net
# m4.large
# $72.00
# 0.4%  0.28MB
# 0.4%  0.26MB
# 0.4%  0.26MB
# 0.4%  0.27MB
# 0.4%  0.28MB
# 0.4%  0.28MB
# 0.4%  0.29MB
# 0.4%  0.27MB
# 0.4%  0.27MB
# 0.4%  0.28MB
# 0.4%  0.27MB
# 0.4%  0.27MB
# 0.4%  0.29MB
# 0.4%  0.28MB
# 0.4%
# 0.27MB
# 14 days
# us-west-2b
# i-06fbc38a2d3f04217
# es-es-esdata-03.inf.us-west-2.plume.comcast.net
# i2.xlarge
# $438.69
# 2.5%  4.40MB
# 2.4%  4.36MB
# 2.5%  4.38MB
# 2.5%  4.35MB
# 2.5%  4.38MB
# 2.6%  4.98MB
# 2.3%  5.49MB
# 2.6%  5.43MB
# 2.6%  5.45MB
# 2.7%  5.43MB
# 2.7%  4.43MB
# 2.6%  4.46MB
# 2.4%  4.54MB
# 2.5%  4.57MB
# 2.5%
# 4.76MB
# 10 days
# us-west-2b
# i-06c223af38a264370
# odpcworker-w2b-03.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.21MB
# 0.8%  0.73MB
# 0.8%  0.73MB
# 0.8%  0.73MB
# 0.8%  0.73MB
# 0.7%  0.62MB
# 0.7%  0.59MB
# 0.7%  0.56MB
# 0.7%  0.56MB
# 0.7%  0.56MB
# 0.7%  0.56MB
# 0.8%  0.75MB
# 0.8%  0.71MB
# 0.9%  0.71MB
# 0.8%
# 0.63MB
# 14 days
# us-west-2c
# i-07d63fcd3ed607ad0
# odpcworker-w2c-01.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.20MB
# 0.8%  0.69MB
# 0.8%  0.68MB
# 0.8%  0.69MB
# 0.8%  0.69MB
# 0.8%  0.62MB
# 0.8%  0.52MB
# 0.8%  0.47MB
# 0.7%  0.47MB
# 0.7%  0.47MB
# 0.7%  0.47MB
# 0.9%  0.77MB
# 0.9%  0.71MB
# 0.9%  0.70MB
# 0.8%
# 0.58MB
# 14 days
# us-west-2a
# i-050ef66a44e6c0ef2
# webapi-chi-03.prod.us-west-2.plume.comcast.net
# m4.xlarge
# $133.71
# 1.5%  3.09MB
# 1.5%  3.21MB
# 1.4%  2.93MB
# 1.5%  3.43MB
# 1.8%  4.61MB
# 1.8%  4.34MB
# 2.1%  5.04MB
# 1.8%  4.35MB
# 1.7%  4.12MB
# 1.7%  4.16MB
# 1.9%  4.56MB
# 1.9%  4.56MB
# 1.9%  4.49MB
# 2.1%  4.81MB
# 1.8%
# 4.12MB
# 13 days
# us-west-2c
# i-01cd44ef8796db602
# odpcore-w2c-01.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.67MB
# 1.1%  0.77MB
# 1.1%  0.77MB
# 1.1%  0.78MB
# 1.1%  0.79MB
# 1.2%  0.78MB
# 1.2%  0.79MB
# 1.2%  0.77MB
# 1.2%  0.77MB
# 1.2%  0.77MB
# 1.1%  0.73MB
# 1.2%  0.82MB
# 1.2%  0.74MB
# 1.0%  0.77MB
# 1.2%
# 0.77MB
# 14 days
# us-west-2b
# i-08c245f9f6ca739cb
# odpcore-w2b-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.67MB
# 1.1%  0.70MB
# 1.1%  0.70MB
# 1.1%  0.70MB
# 1.1%  0.71MB
# 1.1%  0.71MB
# 1.1%  0.71MB
# 1.1%  0.70MB
# 1.1%  0.70MB
# 1.1%  0.70MB
# 1.1%  0.66MB
# 1.1%  0.74MB
# 1.1%  0.68MB
# 1.1%  0.70MB
# 1.1%
# 0.70MB
# 14 days
# us-west-2a
# i-0169ed797638df54a
# odpcore-w2a-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.8%  0.69MB
# 0.8%  0.69MB
# 0.8%  0.70MB
# 0.8%  0.70MB
# 0.8%  0.71MB
# 0.8%  0.71MB
# 0.8%  0.72MB
# 0.8%  0.70MB
# 0.8%  0.70MB
# 0.8%  0.70MB
# 0.7%  0.66MB
# 0.8%  0.76MB
# 0.8%  0.68MB
# 0.8%  0.93MB
# 0.8%
# 0.72MB
# 14 days
# us-west-2a
# i-05a54d8acf5ed454d
# odpsync-w2a-06.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.60MB
# 1.0%  0.62MB
# 1.0%  0.62MB
# 0.9%  0.62MB
# 0.9%  0.62MB
# 1.0%  0.62MB
# 0.9%  0.63MB
# 0.8%  0.62MB
# 0.8%  0.63MB
# 0.9%  0.63MB
# 1.0%  0.58MB
# 1.0%  0.67MB
# 1.0%  0.60MB
# 1.0%  0.63MB
# 1.0%
# 0.62MB
# 14 days
# us-west-2c
# i-0070e746654b89b84
# odpcore-w2c-05.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.66MB
# 1.0%  0.69MB
# 1.0%  0.69MB
# 1.0%  0.70MB
# 1.0%  0.71MB
# 1.0%  0.70MB
# 1.0%  0.71MB
# 1.0%  0.70MB
# 1.0%  0.70MB
# 1.0%  0.70MB
# 1.0%  0.65MB
# 1.0%  0.74MB
# 1.0%  0.67MB
# 1.0%  0.69MB
# 1.0%
# 0.69MB
# 14 days
# us-west-2c
# i-0be778b1e164990b6
# es-es-esdata-01.inf.us-west-2.plume.comcast.net
# i2.xlarge
# $394.82
# 2.7%  4.36MB
# 2.8%  4.40MB
# 2.7%  4.35MB
# 2.9%  4.41MB
# 2.9%  4.42MB
# 3.1%  5.02MB
# 2.7%  5.58MB
# 3.0%  5.49MB
# 3.2%  5.51MB
# 3.3%  5.51MB
# 3.1%  4.44MB
# 3.0%  4.52MB
# 2.8%  4.64MB
# 2.8%  4.65MB
# 2.9%
# 4.81MB
# 9 days
# us-west-2c
# i-0e2b3aba77e03919e
# odpsprkw-w2c-11.odp.comcast.net
# m4.4xlarge
# $452.57
# 0.5%  7.50MB
# 0.5%  7.54MB
# 0.5%  7.52MB
# 0.5%  2.93MB
# 0.4%  1.97MB
# 0.4%  0.44MB
# 0.4%  0.44MB
# 0.4%  0.44MB
# 0.4%  0.47MB
# 0.4%  0.44MB
# 0.4%  0.39MB
# 0.4%  0.42MB
# 0.3%  0.42MB
# 0.4%  1.32MB
# 0.4%
# 2.30MB
# 11 days
# us-west-2a
# i-062480bb4d7e9d528
# salt-salt-master-01.inf.us-west-2.plume.comcast.net
# r4.large
# $95.76
# 2.8%  0.08MB
# 2.8%  0.08MB
# 2.8%  0.08MB
# 2.8%  0.08MB
# 2.7%  0.08MB
# 2.9%  0.08MB
# 2.9%  0.08MB
# 2.9%  0.08MB
# 2.9%  0.08MB
# 2.9%  0.08MB
# 2.9%  0.08MB
# 2.9%  0.10MB
# 2.9%  0.08MB
# 2.9%  0.08MB
# 2.8%
# 0.08MB
# 14 days
# us-west-2a
# i-0324d0e5e8ffac0a8
# odpcworker-w2a-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.7%  0.23MB
# 0.6%  0.72MB
# 0.6%  0.73MB
# 0.6%  0.73MB
# 0.6%  0.73MB
# 0.6%  0.71MB
# 0.6%  0.61MB
# 0.5%  0.56MB
# 0.5%  0.56MB
# 0.5%  0.56MB
# 0.5%  0.56MB
# 0.6%  0.77MB
# 0.6%  0.71MB
# 0.6%  0.72MB
# 0.6%
# 0.64MB
# 14 days
# us-west-2b
# i-0a9e5a52afb2541c5
# odpque-w2b-05.odp.comcast.net
# c4.xlarge
# $143.28
# 2.6%  2.95MB
# 2.6%  2.98MB
# 2.6%  2.98MB
# 2.6%  2.98MB
# 2.6%  2.99MB
# 2.6%  2.98MB
# 2.6%  2.97MB
# 2.5%  2.98MB
# 2.6%  2.97MB
# 2.6%  2.97MB
# 2.6%  2.97MB
# 2.6%  2.91MB
# 2.5%  2.92MB
# 2.5%  4.13MB
# 2.6%
# 3.05MB
# 14 days
# us-west-2b
# i-08a822b2e0437cf0f
# odpcworker-w2b-02.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.9%  0.22MB
# 0.8%  0.73MB
# 0.8%  0.73MB
# 0.8%  0.74MB
# 0.8%  0.74MB
# 0.7%  0.62MB
# 0.7%  0.60MB
# 0.7%  0.56MB
# 0.7%  0.56MB
# 0.7%  0.56MB
# 0.7%  0.56MB
# 0.8%  0.76MB
# 0.8%  0.71MB
# 0.8%  0.72MB
# 0.8%
# 0.63MB
# 14 days
# us-west-2c
# i-0d0d7695d0d313b9b
# odpsprkw-w2c-04.odp.comcast.net
# m4.4xlarge
# $452.57
# 0.5%  7.49MB
# 0.5%  7.52MB
# 0.5%  7.51MB
# 0.4%  2.92MB
# 0.4%  1.97MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.47MB
# 0.3%  0.44MB
# 0.3%  0.38MB
# 0.3%  0.43MB
# 0.3%  0.42MB
# 0.3%  1.41MB
# 0.4%
# 2.30MB
# 11 days
# us-west-2c
# i-01623212b4f09d315
# odpproxy-w2c-01.odp.comcast.net
# c4.xlarge
# $143.28
# 0.7%  0.13MB
# 0.7%  0.16MB
# 0.7%  0.16MB
# 0.7%  0.16MB
# 0.7%  0.16MB
# 0.7%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.6%  0.16MB
# 0.7%  0.15MB
# 0.6%  0.15MB
# 0.7%  0.15MB
# 0.7%  0.14MB
# 0.6%  0.16MB
# 0.7%
# 0.15MB
# 14 days
# us-west-2c
# i-00a408a0719c0e5f8
# webapi-chi-02.prod.us-west-2.plume.comcast.net
# m4.xlarge
# $133.71
# 1.6%  3.09MB
# 1.6%  3.21MB
# 1.5%  2.93MB
# 1.6%  3.45MB
# 1.9%  4.63MB
# 1.8%  4.37MB
# 2.2%  5.05MB
# 1.9%  4.35MB
# 1.7%  4.12MB
# 1.8%  4.17MB
# 2.0%  4.57MB
# 2.0%  4.57MB
# 2.0%  4.49MB
# 2.2%  4.81MB
# 1.8%
# 4.13MB
# 13 days
# us-west-2a
# i-0901b767f0688e21b
# Sameer Plume Dev
# t2.medium
# $33.84
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%  0.00MB
# 0.0%
# 0.00MB
# 14 days
# us-west-2b
# i-0cca86f6367894bae
# odpcore-w2b-04.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.2%  0.67MB
# 1.2%  0.70MB
# 1.2%  0.70MB
# 1.2%  0.70MB
# 1.2%  0.71MB
# 1.2%  0.71MB
# 1.2%  0.71MB
# 1.2%  0.70MB
# 1.2%  0.70MB
# 1.2%  0.70MB
# 1.2%  0.65MB
# 1.3%  0.73MB
# 1.3%  0.68MB
# 1.3%  0.70MB
# 1.2%
# 0.70MB
# 14 days
# us-west-2b
# i-0644d7ce3fd34ac1c
# odpsprkw-w2b-09.odp.comcast.net
# m4.4xlarge
# $164.57
# 0.4%  5.26MB
# 0.4%  5.29MB
# 0.4%  5.28MB
# 0.4%  5.29MB
# 0.4%  5.29MB
# 0.4%  5.30MB
# 0.4%  5.30MB
# 0.4%  5.30MB
# 0.4%  5.33MB
# 0.4%  5.30MB
# 0.4%  4.90MB
# 0.3%  0.42MB
# 0.3%  0.41MB
# 0.3%  1.42MB
# 0.3%
# 4.29MB
# 4 days
# us-west-2b
# i-04672d63c22ccf398
# odphook-w2b-04.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.5%  0.39MB
# 0.5%  0.42MB
# 0.5%  0.42MB
# 0.5%  0.43MB
# 0.5%  0.43MB
# 0.6%  0.43MB
# 0.5%  0.43MB
# 0.6%  0.43MB
# 0.6%  0.46MB
# 0.6%  0.43MB
# 0.5%  0.41MB
# 0.6%  0.43MB
# 0.6%  0.42MB
# 0.7%  0.78MB
# 0.6%
# 0.45MB
# 14 days
# us-west-2b
# i-04dd1b3446d09d42e
# odpcworker-w2b-01.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.21MB
# 0.8%  0.73MB
# 0.8%  0.72MB
# 0.8%  0.73MB
# 0.8%  0.73MB
# 0.8%  0.62MB
# 0.8%  0.59MB
# 0.8%  0.56MB
# 0.8%  0.56MB
# 0.8%  0.56MB
# 0.8%  0.56MB
# 0.9%  0.75MB
# 0.9%  0.71MB
# 0.9%  0.71MB
# 0.8%
# 0.62MB
# 14 days
# us-west-2b
# i-0130bd4dd18e6d454
# odplb-w2b-04.odp.comcast.net
# c4.xlarge
# $143.28
# 1.4%  3.03MB
# 1.4%  3.20MB
# 1.4%  3.19MB
# 1.4%  3.20MB
# 1.6%  3.21MB
# 1.5%  3.21MB
# 1.6%  3.16MB
# 1.4%  2.91MB
# 1.4%  2.91MB
# 1.4%  2.91MB
# 1.4%  2.91MB
# 1.5%  2.87MB
# 1.5%  2.87MB
# 1.7%  3.17MB
# 1.5%
# 3.05MB
# 14 days
# us-west-2b
# i-0c6da90e44073fa61
# optimizer-chi-01.prod.us-west-2.plume.comcast.net
# c4.xlarge
# $143.28
# 1.3%  0.15MB
# 0.5%  0.14MB
# 0.3%  0.13MB
# 0.5%  0.13MB
# 0.4%  0.17MB
# 0.8%  0.19MB
# 3.9%  0.22MB
# 2.2%  0.16MB
# 1.1%  0.16MB
# 1.2%  0.15MB
# 1.4%  0.16MB
# 1.3%  0.19MB
# 2.0%  0.16MB
# 2.8%  0.18MB
# 1.4%
# 0.16MB
# 14 days
# us-west-2a
# i-0b21036a62bb8c15b
# odpsprkw-w2a-01.odp.comcast.net
# m4.4xlarge
# $576.00
# 0.3%  0.50MB
# 0.3%  0.44MB
# 0.3%  0.45MB
# 0.3%  0.45MB
# 0.3%  0.46MB
# 0.3%  0.46MB
# 0.3%  0.44MB
# 0.3%  0.43MB
# 0.3%  0.46MB
# 0.3%  0.43MB
# 0.3%  0.39MB
# 0.2%  0.09MB
# 0.2%  0.09MB
# 0.3%  1.99MB
# 0.3%
# 0.51MB
# 14 days
# us-west-2a
# i-09693da91e4b48924
# odpque-w2a-04.odp.comcast.net
# c4.xlarge
# $112.58
# 1.7%  0.23MB
# 1.7%  0.26MB
# 1.7%  0.26MB
# 1.8%  0.26MB
# 1.8%  0.26MB
# 1.7%  0.26MB
# 1.8%  0.26MB
# 1.7%  0.25MB
# 1.7%  0.25MB
# 1.7%  0.25MB
# 2.9%  23.90MB
# 18.4%  350.58MB
# 2.4%  3.80MB
# 2.6%  7.53MB
# 3.1%
# 27.74MB
# 11 days
# us-west-2c
# i-0eef23416ad0bc235
# rabbitmq-chi-03.prod.us-west-2.plume.comcast.net
# m4.xlarge
# $133.71
# 0.6%  2.38MB
# 0.6%  2.83MB
# 0.6%  2.45MB
# 0.6%  2.24MB
# 0.6%  2.25MB
# 0.6%  2.38MB
# 0.7%  3.45MB
# 0.7%  2.90MB
# 0.7%  2.96MB
# 0.7%  3.16MB
# 0.7%  3.30MB
# 0.7%  3.37MB
# 0.7%  4.86MB
# 0.8%  5.23MB
# 0.7%
# 3.13MB
# 13 days
# us-west-2b
# i-0e06a4028aba142f8
# odplb-w2b-02.odp.comcast.net
# c4.xlarge
# $143.28
# 1.2%  3.02MB
# 1.2%  3.05MB
# 1.2%  3.05MB
# 1.2%  3.05MB
# 1.2%  3.06MB
# 1.2%  3.06MB
# 1.2%  3.06MB
# 1.2%  3.06MB
# 1.2%  3.06MB
# 1.2%  3.06MB
# 1.2%  3.06MB
# 1.2%  3.00MB
# 1.2%  3.00MB
# 1.3%  4.53MB
# 1.2%
# 3.15MB
# 14 days
# us-west-2a
# i-0e1279e2468a761f0
# odpzoo-w2a-02.odp.comcast.net
# c4.xlarge
# $143.28
# 1.5%  0.21MB
# 1.5%  0.24MB
# 1.5%  0.24MB
# 1.5%  0.24MB
# 1.5%  0.24MB
# 1.5%  0.24MB
# 1.5%  0.24MB
# 1.5%  0.23MB
# 1.5%  0.23MB
# 1.5%  0.23MB
# 1.5%  0.23MB
# 1.5%  0.23MB
# 1.5%  0.22MB
# 1.4%  0.24MB
# 1.5%
# 0.23MB
# 14 days
# us-west-2a
# i-0968e78091fa22a9e
# odpsync-w2a-05.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.59MB
# 1.0%  0.62MB
# 1.0%  0.62MB
# 0.9%  0.62MB
# 0.8%  0.62MB
# 0.9%  0.62MB
# 0.8%  0.63MB
# 0.9%  0.62MB
# 0.8%  0.63MB
# 0.7%  0.63MB
# 0.7%  0.58MB
# 0.8%  0.68MB
# 0.7%  0.60MB
# 0.7%  0.63MB
# 0.8%
# 0.62MB
# 14 days
# us-west-2a
# i-027a6ee33c4195cfe
# mongodb-production-04.shared.us-west-2.plume.comcast.net
# m4.large
# $72.00
# 0.4%  0.25MB
# 0.4%  0.25MB
# 0.4%  0.25MB
# 0.4%  0.25MB
# 0.4%  0.25MB
# 0.4%  0.25MB
# 0.4%  0.25MB
# 0.4%  0.25MB
# 0.5%  0.25MB
# 0.5%  0.25MB
# 0.4%  0.25MB
# 0.5%  0.25MB
# 0.5%  0.25MB
# 0.4%  0.25MB
# 0.4%
# 0.25MB
# 14 days
# us-west-2b
# i-09595d133b3aa414f
# odpsync-w2b-03.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.0%  0.59MB
# 1.0%  0.62MB
# 1.0%  0.62MB
# 1.0%  0.62MB
# 1.0%  0.63MB
# 1.0%  0.63MB
# 1.0%  0.63MB
# 1.0%  0.63MB
# 1.0%  0.62MB
# 1.0%  0.62MB
# 1.0%  0.58MB
# 1.0%  0.66MB
# 1.0%  0.60MB
# 1.0%  0.62MB
# 1.0%
# 0.62MB
# 14 days
# us-west-2a
# i-021d8edb75f24cf3d
# es-es-esdata-02.inf.us-west-2.plume.comcast.net
# i2.xlarge
# $438.69
# 2.4%  4.30MB
# 2.4%  4.31MB
# 2.5%  4.30MB
# 2.5%  4.32MB
# 2.5%  4.31MB
# 2.6%  4.91MB
# 2.3%  5.44MB
# 2.6%  5.38MB
# 2.7%  5.38MB
# 2.8%  5.40MB
# 2.9%  4.43MB
# 2.6%  4.38MB
# 2.4%  4.49MB
# 2.5%  4.48MB
# 2.6%
# 4.70MB
# 10 days
# us-west-2c
# i-0adbda33e7af57464
# controllershardv2-chi-02.prod.us-west-2.plume.comcast.net
# m4.xlarge
# $144.00
# 0.5%  0.03MB
# 0.4%  0.03MB
# 0.5%  0.03MB
# 0.5%  0.03MB
# 0.5%  0.08MB
# 0.5%  0.08MB
# 0.5%  0.03MB
# 0.5%  0.08MB
# 0.4%  0.03MB
# 0.5%  0.03MB
# 0.5%  0.03MB
# 0.5%  0.08MB
# 0.4%  0.03MB
# 0.4%  0.03MB
# 0.5%
# 0.04MB
# 14 days
# us-west-2c
# i-05bff8c0774270e7b
# odpsprkw-w2c-10.odp.comcast.net
# m4.4xlarge
# $452.57
# 0.5%  6.39MB
# 0.5%  6.43MB
# 0.5%  6.44MB
# 0.4%  2.76MB
# 0.4%  1.96MB
# 0.3%  0.44MB
# 0.4%  0.44MB
# 0.4%  0.44MB
# 0.4%  0.46MB
# 0.4%  0.44MB
# 0.4%  0.38MB
# 0.4%  0.42MB
# 0.3%  0.42MB
# 0.3%  1.40MB
# 0.4%
# 2.06MB
# 11 days
# us-west-2a
# i-0ecd40787b9b666b7
# odpsprkw-w2a-05.odp.comcast.net
# m4.4xlarge
# $576.00
# 0.3%  0.49MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.45MB
# 0.3%  0.45MB
# 0.3%  0.42MB
# 0.3%  0.42MB
# 0.3%  0.45MB
# 0.3%  0.42MB
# 0.3%  0.38MB
# 0.2%  0.10MB
# 0.2%  0.10MB
# 0.3%  2.01MB
# 0.3%
# 0.50MB
# 14 days
# us-west-2a
# i-0e4851b99203dfd38
# odpcore-w2a-05.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.69MB
# 1.2%  0.70MB
# 1.2%  0.70MB
# 1.0%  0.70MB
# 1.0%  0.71MB
# 1.1%  0.71MB
# 1.1%  0.72MB
# 1.2%  0.70MB
# 1.2%  0.70MB
# 1.1%  0.70MB
# 1.1%  0.66MB
# 1.1%  0.77MB
# 1.1%  0.68MB
# 1.1%  0.98MB
# 1.1%
# 0.72MB
# 14 days
# us-west-2c
# i-079c6439572c3dc8d
# odpsprkw-w2c-13.odp.comcast.net
# m4.4xlarge
# $452.57
# 0.5%  7.50MB
# 0.6%  7.54MB
# 0.5%  7.52MB
# 0.5%  2.94MB
# 0.4%  1.98MB
# 0.4%  0.46MB
# 0.4%  0.46MB
# 0.4%  0.46MB
# 0.4%  0.48MB
# 0.4%  0.46MB
# 0.4%  0.40MB
# 0.4%  0.44MB
# 0.3%  0.44MB
# 0.4%  1.43MB
# 0.4%
# 2.32MB
# 11 days
# us-west-2a
# i-0319137377b855c09
# odpsprkw-w2a-12.odp.comcast.net
# m4.4xlarge
# $576.00
# 0.3%  0.49MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.45MB
# 0.3%  0.45MB
# 0.3%  0.42MB
# 0.3%  0.41MB
# 0.3%  0.44MB
# 0.3%  0.41MB
# 0.3%  0.37MB
# 0.2%  0.08MB
# 0.2%  0.08MB
# 0.2%  2.22MB
# 0.3%
# 0.51MB
# 14 days
# us-west-2c
# i-027abbd572db684eb
# odpsprkw-w2c-06.odp.comcast.net
# m4.4xlarge
# $452.57
# 0.4%  5.70MB
# 0.4%  5.75MB
# 0.4%  5.74MB
# 0.4%  2.67MB
# 0.3%  1.97MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.44MB
# 0.3%  0.47MB
# 0.3%  0.44MB
# 0.3%  0.38MB
# 0.3%  0.43MB
# 0.2%  0.42MB
# 0.3%  1.57MB
# 0.3%
# 1.92MB
# 11 days
# us-west-2a
# i-05e469826ac040b59
# odpsprkw-w2a-09.odp.comcast.net
# m4.4xlarge
# $576.00
# 0.2%  0.43MB
# 0.2%  0.37MB
# 0.2%  0.37MB
# 0.3%  0.38MB
# 0.3%  0.38MB
# 0.3%  0.38MB
# 0.3%  0.36MB
# 0.3%  0.36MB
# 0.2%  0.40MB
# 0.3%  0.37MB
# 0.2%  0.33MB
# 0.2%  0.09MB
# 0.2%  0.09MB
# 0.3%  2.55MB
# 0.2%
# 0.49MB
# 14 days
# us-west-2c
# i-05e1e56dda75b13c6
# odplb-w2c-01.odp.comcast.net
# c4.xlarge
# $143.28
# 1.4%  2.81MB
# 1.5%  2.84MB
# 1.5%  2.84MB
# 1.5%  2.84MB
# 1.5%  2.79MB
# 1.5%  2.47MB
# 1.5%  2.47MB
# 1.5%  2.47MB
# 1.5%  2.47MB
# 1.5%  2.47MB
# 1.5%  2.47MB
# 1.5%  2.48MB
# 1.5%  2.74MB
# 1.6%  4.05MB
# 1.5%
# 2.73MB
# 14 days
# us-west-2b
# i-0d54e9c0569920289
# odpredis-w2b-02.odp.comcast.net
# c4.xlarge
# $143.28
# 1.0%  0.57MB
# 1.1%  0.60MB
# 1.1%  0.60MB
# 1.1%  0.60MB
# 1.1%  0.60MB
# 1.1%  0.59MB
# 1.1%  0.60MB
# 1.1%  0.59MB
# 1.3%  0.59MB
# 1.3%  0.59MB
# 1.2%  0.59MB
# 1.2%  0.59MB
# 1.1%  0.59MB
# 1.1%  0.66MB
# 1.1%
# 0.60MB
# 14 days
# us-west-2b
# i-002540052279ee66d
# odpcore-w2b-07.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.7%  0.68MB
# 0.7%  0.71MB
# 0.7%  0.71MB
# 0.7%  0.71MB
# 0.8%  0.72MB
# 0.8%  0.72MB
# 0.8%  0.72MB
# 0.8%  0.71MB
# 0.8%  0.71MB
# 0.8%  0.71MB
# 0.7%  0.66MB
# 0.8%  0.75MB
# 0.7%  0.70MB
# 0.8%  0.71MB
# 0.8%
# 0.71MB
# 14 days
# us-west-2a
# i-07abd2d3f879ca525
# rabbitmq-production-01.shared.us-west-2.plume.comcast.net
# c4.large
# $72.00
# 0.4%  0.09MB
# 0.4%  0.09MB
# 0.4%  0.09MB
# 0.4%  0.09MB
# 0.4%  0.09MB
# 0.4%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%  0.09MB
# 0.5%
# 0.09MB
# 14 days
# us-west-2c
# i-0717a93f09aa3e5e4
# odplb-w2c-03.odp.comcast.net
# c4.xlarge
# $143.28
# 1.2%  2.82MB
# 1.2%  2.85MB
# 1.2%  2.86MB
# 1.2%  2.85MB
# 1.2%  2.81MB
# 1.2%  2.49MB
# 1.2%  2.45MB
# 1.0%  2.19MB
# 1.0%  2.19MB
# 1.0%  2.19MB
# 1.0%  2.19MB
# 1.0%  2.21MB
# 1.0%  2.47MB
# 1.2%  2.75MB
# 1.1%
# 2.52MB
# 14 days
# us-west-2a
# i-047acb4371d2800f7
# odpsync-w2a-01.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.59MB
# 1.1%  0.61MB
# 1.1%  0.61MB
# 1.1%  0.62MB
# 1.1%  0.62MB
# 1.0%  0.62MB
# 1.1%  0.62MB
# 1.0%  0.62MB
# 1.1%  0.62MB
# 1.0%  0.62MB
# 1.0%  0.57MB
# 1.1%  0.67MB
# 1.1%  0.59MB
# 1.1%  0.63MB
# 1.1%
# 0.62MB
# 14 days
# us-west-2a
# i-04395870150b6739c
# odpcore-w2a-08.odp.comcast.net
# c4.2xlarge
# $286.56
# 1.1%  0.69MB
# 1.1%  0.70MB
# 1.1%  0.70MB
# 1.1%  0.71MB
# 1.1%  0.71MB
# 1.1%  0.71MB
# 1.1%  0.72MB
# 1.1%  0.70MB
# 1.1%  0.70MB
# 1.1%  0.71MB
# 1.1%  0.66MB
# 1.2%  0.76MB
# 1.2%  0.68MB
# 1.2%  0.95MB
# 1.1%
# 0.72MB
# 14 days
# us-west-2b
# i-04c9cb74f423207c9
# odpcore-w2b-05.odp.comcast.net
# c4.2xlarge
# $286.56
# 0.7%  0.66MB
# 0.7%  0.69MB
# 0.7%  0.69MB
# 0.7%  0.69MB
# 0.7%  0.70MB
# 0.8%  0.70MB
# 0.7%  0.71MB
# 0.7%  0.69MB
# 0.7%  0.69MB
# 0.7%  0.69MB
# 0.7%  0.65MB
# 0.7%  0.73MB
# 0.7%  0.67MB
# 0.8%  0.69MB
# 0.7%
# 0.69MB
# 14 days

# %%
awsdf.values.tolist()
# Out:
# [['Region/AZ',
#   'Instance ID',
#   'Instance Name',
#   'Instance Type',
#   'Estimated Monthly Savings',
#   'Day 1',
#   'Day 2',
#   'Day 3',
#   'Day 4',
#   'Day 5',
#   'Day 6',
#   'Day 7',
#   'Day 8',
#   'Day 9',
#   'Day 10',
#   'Day 11',
#   'Day 12',
#   'Day 13',
#   'Day 14',
#   '14-Day Average CPU Utilization',
#   '14-Day Average Network I/O',
#   'Number of Days Low Utilization'],
#  ['us-east-1b',
#   'i-0b8c413d9408beffd',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$136.80',
#   '0.7%  3.12MB',
#   '0.6%  0.08MB',
#   '0.5%  0.08MB',
#   '0.5%  0.60MB',
#   '0.7%  7.07MB',
#   '0.7%  1.22MB',
#   '0.7%  5.92MB',
#   '0.5%  0.41MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '3.5%  19.02MB',
#   '0.8%  1.68MB',
#   '2.1%  2.85MB',
#   '5.2%  8.29MB',
#   '1.3%',
#   '3.61MB',
#   '10 days'],
#  ['us-east-1b',
#   'i-04273cd6ba4f96e13',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$136.80',
#   '0.7%  3.02MB',
#   '0.6%  0.08MB',
#   '0.5%  0.08MB',
#   '0.6%  0.60MB',
#   '0.7%  7.18MB',
#   '0.6%  0.89MB',
#   '0.5%  0.77MB',
#   '0.5%  0.21MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '3.9%  14.50MB',
#   '0.6%  0.77MB',
#   '3.7%  9.70MB',
#   '5.1%  8.11MB',
#   '1.4%',
#   '3.29MB',
#   '10 days'],
#  ['us-east-1b',
#   'i-06fdd339e4dd0c201',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$136.80',
#   '0.6%  3.13MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '0.6%  0.64MB',
#   '0.7%  7.70MB',
#   '0.6%  0.89MB',
#   '0.8%  6.75MB',
#   '0.5%  0.40MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '2.3%  11.53MB',
#   '0.7%  1.42MB',
#   '2.5%  4.47MB',
#   '5.3%  7.71MB',
#   '1.2%',
#   '3.21MB',
#   '10 days'],
#  ['us-east-1b',
#   'i-0ea7b16baee2b6a4e',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$123.12',
#   '0.6%  3.05MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '0.6%  0.60MB',
#   '0.8%  7.12MB',
#   '0.6%  0.89MB',
#   '0.7%  5.97MB',
#   '0.6%  0.40MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '4.1%  17.81MB',
#   '0.6%  0.90MB',
#   '3.5%  8.75MB',
#   '5.1%  7.69MB',
#   '1.4%',
#   '3.82MB',
#   '9 days'],
#  ['us-east-1b',
#   'i-0799accd01f99ced4',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$136.80',
#   '0.6%  3.05MB',
#   '0.6%  0.09MB',
#   '0.6%  0.10MB',
#   '0.5%  0.61MB',
#   '0.8%  6.97MB',
#   '0.7%  1.22MB',
#   '0.6%  0.46MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '2.9%  14.51MB',
#   '0.9%  1.70MB',
#   '3.7%  9.27MB',
#   '5.2%  7.86MB',
#   '1.3%',
#   '3.29MB',
#   '10 days'],
#  ['us-east-1a',
#   'i-06d31cee3dda4deef',
#   'cbelkdata-e1a-01s.cb.comcast.net',
#   'i3.xlarge',
#   '$224.64',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '0.5%  0.09MB',
#   '0.5%  0.10MB',
#   '0.5%  0.07MB',
#   '0.5%  0.07MB',
#   '0.5%  0.11MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.10MB',
#   '0.5%  0.11MB',
#   '0.5%  0.08MB',
#   '0.5%  0.09MB',
#   '0.5%  0.10MB',
#   '0.5%',
#   '0.09MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-09cbdb36893061df2',
#   'odprabbit-e1b-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.5%  1.78MB',
#   '1.5%  1.83MB',
#   '1.5%  1.81MB',
#   '1.4%  1.84MB',
#   '1.5%  1.83MB',
#   '1.5%  1.84MB',
#   '1.5%  1.84MB',
#   '1.4%  1.85MB',
#   '1.4%  1.88MB',
#   '1.4%  1.87MB',
#   '1.4%  1.91MB',
#   '1.4%  1.86MB',
#   '1.4%  1.82MB',
#   '1.4%  1.87MB',
#   '1.4%',
#   '1.85MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-07fb4f02d91195d15',
#   'cb-puppet-master',
#   't2.xlarge',
#   '$135.36',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0d1479acf8da50b79',
#   'new-dev-elk-master-node-1a',
#   'm4.2xlarge',
#   '$288.00',
#   '0.1%  2.24MB',
#   '0.1%  2.24MB',
#   '0.1%  2.24MB',
#   '0.1%  2.24MB',
#   '0.1%  2.24MB',
#   '0.1%  2.24MB',
#   '0.1%  2.26MB',
#   '0.1%  2.26MB',
#   '0.1%  2.24MB',
#   '0.1%  2.24MB',
#   '0.1%  2.26MB',
#   '0.1%  2.27MB',
#   '0.1%  2.24MB',
#   '0.1%  2.24MB',
#   '0.1%',
#   '2.24MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-05796685',
#   'Cassandra-dev-2',
#   'c3.4xlarge',
#   '$604.80',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-08e131de99f5df529',
#   'odpcworker-e1a-02.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.7%  0.86MB',
#   '0.7%  0.91MB',
#   '0.6%  0.87MB',
#   '0.6%  0.90MB',
#   '0.6%  0.87MB',
#   '0.6%  0.87MB',
#   '0.6%  0.86MB',
#   '0.7%  0.87MB',
#   '0.7%  0.90MB',
#   '0.6%  0.87MB',
#   '0.6%  0.86MB',
#   '0.6%  0.81MB',
#   '0.7%  0.88MB',
#   '0.7%  0.87MB',
#   '0.6%',
#   '0.87MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-1ba68582',
#   'cbapi-e1a-04s.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.9%  0.17MB',
#   '1.0%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%  0.17MB',
#   '0.9%',
#   '0.17MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0d7c1335eb078fbbc',
#   'odprabbit-e1a-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.0%  0.60MB',
#   '1.0%  0.64MB',
#   '1.0%  0.62MB',
#   '1.0%  0.63MB',
#   '1.0%  0.62MB',
#   '1.0%  0.62MB',
#   '1.0%  0.61MB',
#   '1.0%  0.63MB',
#   '1.0%  0.64MB',
#   '1.1%  0.62MB',
#   '1.1%  0.62MB',
#   '1.0%  0.56MB',
#   '1.1%  0.35MB',
#   '1.2%  0.36MB',
#   '1.0%',
#   '0.58MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-ff2b7e66',
#   'cbapi-e1a-02.cb.comcast.net',
#   'c4.xlarge',
#   '$40.94',
#   '0.8%  0.16MB',
#   '0.9%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '8.3%  6.04MB',
#   '18.5%  13.98MB',
#   '19.3%  14.64MB',
#   '19.5%  14.82MB',
#   '14.5%  9.92MB',
#   '14.5%  9.94MB',
#   '14.2%  9.86MB',
#   '14.1%  9.82MB',
#   '14.1%  9.86MB',
#   '14.0%  9.91MB',
#   '11.0%',
#   '7.82MB',
#   '4 days'],
#  ['us-east-1a',
#   'i-0ea5aae11f2dff98b',
#   'odpcworker-e1a-01.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.9%  0.87MB',
#   '0.9%  0.92MB',
#   '0.8%  0.88MB',
#   '0.8%  0.91MB',
#   '0.8%  0.88MB',
#   '0.9%  0.88MB',
#   '0.9%  0.86MB',
#   '1.0%  0.88MB',
#   '1.0%  0.87MB',
#   '1.0%  0.88MB',
#   '1.0%  0.87MB',
#   '0.9%  0.82MB',
#   '1.0%  0.91MB',
#   '1.0%  0.88MB',
#   '0.9%',
#   '0.88MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0fb195dc77040aefd',
#   'cbelkweb-e1a-01stg.cb.comcast.net',
#   'm4.large',
#   '$72.00',
#   '0.1%  0.11MB',
#   '0.1%  0.10MB',
#   '0.1%  0.11MB',
#   '0.1%  0.10MB',
#   '0.1%  0.11MB',
#   '0.1%  0.10MB',
#   '0.1%  0.11MB',
#   '0.1%  0.11MB',
#   '0.1%  0.11MB',
#   '0.2%  0.11MB',
#   '0.1%  0.11MB',
#   '0.1%  0.11MB',
#   '0.1%  0.10MB',
#   '0.1%  0.11MB',
#   '0.1%',
#   '0.11MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-046db2ec47a78e978',
#   'odpredis-e1a-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.9%  0.84MB',
#   '0.9%  0.85MB',
#   '0.9%  0.83MB',
#   '0.9%  0.83MB',
#   '0.9%  0.84MB',
#   '0.9%  0.82MB',
#   '0.9%  0.84MB',
#   '0.9%  0.97MB',
#   '1.0%  0.93MB',
#   '1.0%  0.67MB',
#   '0.8%  0.73MB',
#   '0.8%  0.93MB',
#   '0.9%  0.93MB',
#   '0.9%  1.00MB',
#   '0.9%',
#   '0.86MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-063b159a3eb19859a',
#   'django_test',
#   'm4.large',
#   '$72.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0e67624235981119f',
#   'CB-STG-NODE-1B',
#   'm4.4xlarge',
#   '$576.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-082b2f013ad943078',
#   'odpcworker-e1a-03.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.0%  0.85MB',
#   '1.0%  0.88MB',
#   '0.9%  0.88MB',
#   '0.8%  0.90MB',
#   '1.0%  0.88MB',
#   '1.0%  0.88MB',
#   '1.0%  0.86MB',
#   '1.0%  0.88MB',
#   '1.1%  0.91MB',
#   '1.0%  0.88MB',
#   '1.0%  0.88MB',
#   '0.9%  0.81MB',
#   '1.0%  0.89MB',
#   '1.0%  0.88MB',
#   '1.0%',
#   '0.88MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-01ab0b254fc3b4d27',
#   'odpsync-e1a-06.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.1%  0.68MB',
#   '2.1%  0.69MB',
#   '2.1%  0.69MB',
#   '2.1%  0.70MB',
#   '2.1%  0.67MB',
#   '2.1%  0.68MB',
#   '2.1%  0.68MB',
#   '2.1%  0.68MB',
#   '2.1%  0.70MB',
#   '2.1%  0.68MB',
#   '2.0%  0.62MB',
#   '1.9%  0.52MB',
#   '2.1%  0.69MB',
#   '2.1%  0.72MB',
#   '2.1%',
#   '0.67MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0fa419f85c5953797',
#   'Netscout Kpi hourly dev',
#   'm3.xlarge',
#   '$191.52',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '0.6%  0.59MB',
#   '1.0%  4.59MB',
#   '0.7%  0.08MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%',
#   '0.44MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-010d1716f2e866436',
#   'odprabbit-e1a-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.6%  1.35MB',
#   '1.5%  1.38MB',
#   '1.6%  1.40MB',
#   '1.6%  1.41MB',
#   '1.7%  1.41MB',
#   '1.5%  1.43MB',
#   '1.6%  1.42MB',
#   '1.7%  1.42MB',
#   '1.4%  1.45MB',
#   '1.7%  1.45MB',
#   '1.8%  1.47MB',
#   '1.8%  1.46MB',
#   '1.7%  1.55MB',
#   '1.8%  1.60MB',
#   '1.6%',
#   '1.44MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-0635ef4116afb19cb',
#   'django_exec2_STG',
#   'm4.xlarge',
#   '$144.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0bc83aa3c255e5aa5',
#   'odpredis-e1b-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.9%  0.99MB',
#   '0.9%  1.03MB',
#   '0.9%  1.06MB',
#   '0.9%  0.95MB',
#   '0.9%  1.02MB',
#   '0.9%  1.00MB',
#   '0.9%  0.99MB',
#   '0.9%  1.09MB',
#   '0.9%  1.07MB',
#   '0.9%  0.80MB',
#   '0.9%  0.93MB',
#   '0.9%  1.11MB',
#   '0.9%  1.05MB',
#   '0.9%  1.11MB',
#   '0.9%',
#   '1.01MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-050c27614d0ee1ab3',
#   'Django STG',
#   'm4.2xlarge',
#   '$288.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0a4f2943e5c3387a5',
#   nan,
#   'm3.xlarge',
#   '$191.52',
#   nan,
#   nan,
#   nan,
#   nan,
#   '1.0%  0.12MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.08MB',
#   '0.7%  0.51MB',
#   '0.7%',
#   '0.13MB',
#   '10 days'],
#  ['us-east-1a',
#   'i-088b01b14287e5abf',
#   'odpsync-e1a-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.4%  0.67MB',
#   '2.4%  0.70MB',
#   '2.4%  0.69MB',
#   '2.5%  0.71MB',
#   '2.4%  0.69MB',
#   '2.4%  0.69MB',
#   '2.5%  0.69MB',
#   '2.4%  0.69MB',
#   '2.4%  0.70MB',
#   '2.4%  0.69MB',
#   '2.4%  0.63MB',
#   '2.2%  0.52MB',
#   '2.2%  0.69MB',
#   '2.3%  0.72MB',
#   '2.4%',
#   '0.68MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-972e5604',
#   'cbdb-e1b-05.cb.comcast.net',
#   'c3.4xlarge',
#   '$172.80',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '2.0%  69.25MB',
#   '3.4%  161.10MB',
#   '3.4%  163.21MB',
#   '3.4%  164.05MB',
#   '3.4%  161.15MB',
#   '3.4%  161.40MB',
#   '3.4%  158.62MB',
#   '3.3%  157.09MB',
#   '3.3%  157.71MB',
#   '3.3%  158.22MB',
#   '2.6%',
#   '108.07MB',
#   '4 days'],
#  ['us-east-1b',
#   'i-0c8a426dd399b11bc',
#   'odpsync-e1b-09.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.8%  0.80MB',
#   '0.8%  0.81MB',
#   '0.8%  0.80MB',
#   '0.8%  0.83MB',
#   '0.8%  0.82MB',
#   '0.8%  0.84MB',
#   '0.8%  0.81MB',
#   '0.8%  0.81MB',
#   '0.8%  0.80MB',
#   '0.8%  0.80MB',
#   '0.8%  0.77MB',
#   '0.7%  0.65MB',
#   '0.9%  0.88MB',
#   '0.9%  0.92MB',
#   '0.8%',
#   '0.81MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-055bb6fd5891a0921',
#   'odpproxy-e1a-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.2%  0.29MB',
#   '1.1%  0.31MB',
#   '1.2%  0.31MB',
#   '1.2%  0.31MB',
#   '1.2%  0.31MB',
#   '1.2%  0.32MB',
#   '1.1%  0.32MB',
#   '0.8%  0.31MB',
#   '1.1%  0.31MB',
#   '1.2%  0.31MB',
#   '1.1%  0.31MB',
#   '0.8%  0.31MB',
#   '1.1%  0.30MB',
#   '0.8%  0.31MB',
#   '1.1%',
#   '0.31MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-fc2b7e65',
#   'cbapi-e1a-03.cb.comcast.net',
#   'c4.xlarge',
#   '$51.17',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '5.9%  3.42MB',
#   '13.1%  7.81MB',
#   '13.3%  7.94MB',
#   '13.2%  7.99MB',
#   '13.4%  8.08MB',
#   '13.5%  8.11MB',
#   '13.4%  7.99MB',
#   '13.2%  7.91MB',
#   '13.3%  7.94MB',
#   '13.3%  7.99MB',
#   '9.2%',
#   '5.42MB',
#   '5 days'],
#  ['us-east-1b',
#   'i-0b2c002a7211f3f06',
#   'odpsync-e1b-08.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.1%  0.78MB',
#   '1.1%  0.82MB',
#   '1.1%  0.79MB',
#   '1.1%  0.83MB',
#   '1.1%  0.81MB',
#   '1.1%  0.83MB',
#   '1.2%  0.81MB',
#   '1.2%  0.81MB',
#   '1.2%  0.79MB',
#   '1.2%  0.79MB',
#   '1.1%  0.77MB',
#   '1.0%  0.57MB',
#   '1.0%  0.55MB',
#   '1.0%  0.59MB',
#   '1.1%',
#   '0.75MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0fafb41652b51958b',
#   'new-dev-elk-data-node-1b',
#   'i3.xlarge',
#   '$112.32',
#   '15.4%  120.01MB',
#   '15.5%  120.38MB',
#   '15.9%  122.14MB',
#   '16.1%  122.21MB',
#   '15.2%  116.02MB',
#   '15.5%  118.16MB',
#   '15.4%  128.04MB',
#   '0.4%  0.50MB',
#   '0.4%  0.50MB',
#   '0.4%  0.50MB',
#   '0.4%  0.50MB',
#   '0.4%  0.50MB',
#   '0.4%  0.50MB',
#   '0.4%  0.50MB',
#   '8.0%',
#   '60.75MB',
#   '7 days'],
#  ['us-east-1a',
#   'i-28a784b1',
#   'cbapi-e1a-02s.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.9%  0.16MB',
#   '0.9%  0.17MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.9%  0.16MB',
#   '0.8%  0.17MB',
#   '0.8%  0.16MB',
#   '0.8%  0.17MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%  0.16MB',
#   '0.8%',
#   '0.16MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0332a2a91602fcb63',
#   'odpzoo-e1a-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.1%  0.40MB',
#   '2.0%  0.43MB',
#   '1.9%  0.44MB',
#   '2.0%  0.44MB',
#   '2.0%  0.44MB',
#   '2.0%  0.44MB',
#   '2.1%  0.44MB',
#   '2.1%  0.44MB',
#   '2.0%  0.43MB',
#   '2.2%  0.43MB',
#   '2.0%  0.43MB',
#   '2.1%  0.42MB',
#   '1.9%  0.41MB',
#   '1.9%  0.42MB',
#   '2.0%',
#   '0.43MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0d41df987b524443b',
#   'odpsync-e1a-11.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.0%  0.65MB',
#   '1.1%  0.66MB',
#   '1.1%  0.66MB',
#   '1.1%  0.67MB',
#   '1.1%  0.64MB',
#   '1.1%  0.65MB',
#   '1.1%  0.65MB',
#   '1.0%  0.65MB',
#   '1.1%  0.67MB',
#   '1.0%  0.65MB',
#   '1.0%  0.59MB',
#   '0.9%  0.51MB',
#   '1.1%  0.67MB',
#   '1.1%  0.68MB',
#   '1.0%',
#   '0.64MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-02c53df44edde17a8',
#   'cbelkmstr-e1a-02.cb.comcast.net',
#   'm4.xlarge',
#   '$144.00',
#   '0.7%  2.63MB',
#   '0.7%  2.62MB',
#   '0.7%  2.62MB',
#   '0.7%  2.62MB',
#   '0.7%  2.62MB',
#   '0.8%  2.62MB',
#   '0.7%  2.63MB',
#   '0.7%  2.63MB',
#   '0.7%  2.64MB',
#   '0.8%  2.64MB',
#   '0.7%  2.64MB',
#   '0.7%  2.64MB',
#   '0.8%  2.65MB',
#   '0.8%  2.36MB',
#   '0.7%',
#   '2.61MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0b4cb5100460bd590',
#   'Karthik-docker-test',
#   't2.micro',
#   '$8.64',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%  0.02MB',
#   '0.2%  0.01MB',
#   '0.2%  0.00MB',
#   '0.2%  0.00MB',
#   '0.2%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0d9b7546e6b59b23a',
#   'odpredis-e1b-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.2%  0.90MB',
#   '1.2%  0.93MB',
#   '1.2%  0.96MB',
#   '1.2%  0.85MB',
#   '1.2%  0.93MB',
#   '1.2%  0.91MB',
#   '1.2%  0.90MB',
#   '1.2%  0.99MB',
#   '1.2%  0.97MB',
#   '1.1%  0.71MB',
#   '1.1%  0.83MB',
#   '1.2%  1.01MB',
#   '1.2%  0.94MB',
#   '1.2%  1.02MB',
#   '1.2%',
#   '0.92MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-090b1de732878e219',
#   'odpsync-e1b-10.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.1%  0.79MB',
#   '1.1%  0.82MB',
#   '1.0%  0.80MB',
#   '1.0%  0.83MB',
#   '1.0%  0.84MB',
#   '1.1%  0.86MB',
#   '1.0%  0.84MB',
#   '1.1%  0.83MB',
#   '1.1%  0.82MB',
#   '1.1%  0.81MB',
#   '1.1%  0.79MB',
#   '1.0%  0.65MB',
#   '1.1%  0.87MB',
#   '1.1%  0.92MB',
#   '1.1%',
#   '0.82MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0618899e6b14162dd',
#   'new-dev-elk-web-kibana-node-1a',
#   'm4.large',
#   '$72.00',
#   '0.1%  0.11MB',
#   '0.2%  0.11MB',
#   '0.1%  0.11MB',
#   '0.2%  0.12MB',
#   '0.1%  0.11MB',
#   '0.1%  0.11MB',
#   '0.2%  0.12MB',
#   '0.2%  0.11MB',
#   '0.2%  0.11MB',
#   '0.1%  0.11MB',
#   '0.2%  0.13MB',
#   '0.2%  0.14MB',
#   '0.1%  0.11MB',
#   '0.1%  0.11MB',
#   '0.2%',
#   '0.11MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-31c2c5a8',
#   'cbdb-e1a-05.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.1%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.29MB',
#   '1.1%  0.30MB',
#   '1.1%',
#   '0.30MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-585500c1',
#   'cblb-e1a-01.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.8%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.27MB',
#   '0.7%  0.26MB',
#   '0.7%  0.27MB',
#   '0.7%',
#   '0.27MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-b0540129',
#   'cblb-e1a-02.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.28MB',
#   '0.8%  0.27MB',
#   '0.7%  0.28MB',
#   '0.8%',
#   '0.28MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0ac1c693',
#   'cbdb-e1a-03s.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.31MB',
#   '1.0%  0.32MB',
#   '1.0%  0.31MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.32MB',
#   '1.0%',
#   '0.31MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0a31b4af2b66fd34b',
#   'odpsync-e1b-05.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.1%  0.88MB',
#   '2.2%  0.84MB',
#   '2.2%  0.83MB',
#   '2.2%  0.88MB',
#   '2.2%  0.86MB',
#   '2.2%  0.88MB',
#   '2.2%  0.86MB',
#   '2.2%  0.85MB',
#   '2.1%  0.82MB',
#   '2.1%  0.82MB',
#   '2.1%  0.79MB',
#   '2.0%  0.65MB',
#   '2.3%  0.88MB',
#   '2.4%  0.94MB',
#   '2.2%',
#   '0.84MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-03e381966dfd0fef9',
#   'odpcworker-e1a-04.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.9%  0.86MB',
#   '0.9%  0.92MB',
#   '0.9%  0.89MB',
#   '0.9%  0.90MB',
#   '0.9%  0.88MB',
#   '0.9%  0.88MB',
#   '0.9%  0.87MB',
#   '0.9%  0.88MB',
#   '0.9%  0.91MB',
#   '0.9%  0.88MB',
#   '0.9%  0.87MB',
#   '0.9%  0.82MB',
#   '0.9%  0.89MB',
#   '1.0%  0.88MB',
#   '0.9%',
#   '0.88MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-992d350a',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$82.08',
#   '3.8%  6.19MB',
#   '3.6%  0.85MB',
#   '3.6%  0.85MB',
#   '3.7%  5.42MB',
#   '3.9%  10.12MB',
#   '3.9%  9.10MB',
#   '4.0%  5.77MB',
#   '3.7%  1.93MB',
#   '3.6%  0.85MB',
#   '3.6%  0.85MB',
#   '4.5%  13.09MB',
#   '4.0%  4.48MB',
#   '4.3%  16.87MB',
#   '3.8%  6.63MB',
#   '3.9%',
#   '5.93MB',
#   '6 days'],
#  ['us-east-1a',
#   'i-092da97789b13bdad',
#   'JMeter-node',
#   'c3.4xlarge',
#   '$604.80',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0ae0f12292d727db2',
#   'JMeter-node',
#   'c3.4xlarge',
#   '$604.80',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0db3eab70b075f763',
#   'JMeter-node',
#   'c3.4xlarge',
#   '$604.80',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-4c0c98df',
#   'cbapi-e1b-04.cb.comcast.net',
#   'c4.xlarge',
#   '$40.94',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '18.8%  13.97MB',
#   '43.3%  32.67MB',
#   '43.5%  32.79MB',
#   '43.5%  32.79MB',
#   '44.1%  33.27MB',
#   '44.1%  33.28MB',
#   '43.4%  32.75MB',
#   '43.0%  32.46MB',
#   '43.1%  32.56MB',
#   '43.2%  32.62MB',
#   '29.5%',
#   '22.13MB',
#   '4 days'],
#  ['us-east-1b',
#   'i-c1039752',
#   'cbapi-e1b-02.cb.comcast.net',
#   'c4.xlarge',
#   '$40.94',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '7.6%  5.45MB',
#   '16.7%  12.58MB',
#   '16.7%  12.65MB',
#   '16.7%  12.63MB',
#   '17.0%  12.84MB',
#   '17.0%  12.87MB',
#   '16.7%  12.64MB',
#   '16.5%  12.43MB',
#   '16.4%  12.42MB',
#   '16.5%  12.50MB',
#   '11.5%',
#   '8.55MB',
#   '4 days'],
#  ['us-east-1a',
#   'i-d8c1c641',
#   'cbdb-e1a-02s.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.29MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.29MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%',
#   '0.28MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-4fc5cc7e',
#   'Django API STG(aphealth)',
#   'm4.xlarge',
#   '$144.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.5%  0.01MB',
#   '0.9%  0.01MB',
#   '0.4%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.2%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0cf1dfcc2e31c56e1',
#   'odpsync-e1a-07.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.9%  0.64MB',
#   '0.9%  0.67MB',
#   '0.9%  0.67MB',
#   '1.0%  0.68MB',
#   '1.0%  0.65MB',
#   '1.0%  0.66MB',
#   '1.0%  0.66MB',
#   '1.0%  0.66MB',
#   '1.0%  0.67MB',
#   '1.0%  0.66MB',
#   '0.9%  0.60MB',
#   '0.9%  0.50MB',
#   '1.0%  0.66MB',
#   '1.0%  0.69MB',
#   '1.0%',
#   '0.65MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-969891a7',
#   'Django Nginx STG(aphealth)',
#   'm4.xlarge',
#   '$144.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-36c2c5af',
#   'cbdb-e1a-04.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.1%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.30MB',
#   '1.0%  0.29MB',
#   '1.1%  0.30MB',
#   '1.0%',
#   '0.30MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-fe2b7e67',
#   'cbapi-e1a-04.cb.comcast.net',
#   'c4.xlarge',
#   '$40.94',
#   '0.7%  0.16MB',
#   '0.7%  0.16MB',
#   '0.7%  0.16MB',
#   '0.7%  0.17MB',
#   '13.5%  9.69MB',
#   '30.8%  22.50MB',
#   '32.0%  23.34MB',
#   '32.8%  23.94MB',
#   '32.8%  24.00MB',
#   '32.9%  24.10MB',
#   '32.6%  23.88MB',
#   '32.5%  23.78MB',
#   '32.4%  23.80MB',
#   '32.4%  23.84MB',
#   '22.0%',
#   '15.97MB',
#   '4 days'],
#  ['us-east-1b',
#   'i-1d02968e',
#   'cbapi-e1b-01.cb.comcast.net',
#   'c4.xlarge',
#   '$40.94',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '0.8%  0.17MB',
#   '19.0%  13.44MB',
#   '43.8%  31.44MB',
#   '43.9%  31.54MB',
#   '44.1%  31.64MB',
#   '44.7%  32.03MB',
#   '44.7%  32.14MB',
#   '44.0%  31.59MB',
#   '43.5%  31.27MB',
#   '43.7%  31.38MB',
#   '43.7%  31.36MB',
#   '29.9%',
#   '21.32MB',
#   '4 days'],
#  ['us-east-1a',
#   'i-17a6858e',
#   'cblb-e1a-02s.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%  0.28MB',
#   '0.7%',
#   '0.28MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-d9c1c640',
#   'cbdb-e1a-04s.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.28MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.28MB',
#   '1.0%  0.29MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.29MB',
#   '1.0%',
#   '0.28MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-05cc1ffeddf8d3c4d',
#   'new-dev-elk-master-node-1d',
#   'm4.2xlarge',
#   '$288.00',
#   '0.1%  0.40MB',
#   '0.1%  0.39MB',
#   '0.1%  0.39MB',
#   '0.1%  0.39MB',
#   '0.1%  0.39MB',
#   '0.1%  0.39MB',
#   '0.1%  0.39MB',
#   '0.1%  0.39MB',
#   '0.1%  0.40MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.39MB',
#   '0.1%  0.39MB',
#   '0.1%  0.38MB',
#   '0.1%',
#   '0.39MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-04853074ffa2f70d4',
#   'odpsync-e1a-08.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.1%  0.63MB',
#   '1.1%  0.66MB',
#   '1.2%  0.66MB',
#   '1.2%  0.67MB',
#   '1.1%  0.64MB',
#   '1.1%  0.65MB',
#   '1.2%  0.65MB',
#   '1.2%  0.64MB',
#   '1.1%  0.66MB',
#   '1.2%  0.65MB',
#   '1.1%  0.59MB',
#   '1.1%  0.51MB',
#   '1.1%  0.67MB',
#   '1.1%  0.68MB',
#   '1.1%',
#   '0.64MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-042a9fa155c1850a4',
#   'odpsync-e1b-04.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.4%  0.82MB',
#   '2.4%  0.84MB',
#   '2.4%  0.83MB',
#   '2.4%  0.85MB',
#   '2.4%  0.83MB',
#   '2.3%  0.86MB',
#   '2.3%  0.84MB',
#   '2.3%  0.84MB',
#   '2.2%  0.82MB',
#   '2.2%  0.82MB',
#   '2.1%  0.79MB',
#   '2.0%  0.66MB',
#   '2.3%  0.89MB',
#   '2.3%  0.94MB',
#   '2.3%',
#   '0.83MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-06630e45db6a1a5f6',
#   'odpcworker-e1b-02.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.8%  0.87MB',
#   '0.9%  0.91MB',
#   '0.8%  0.88MB',
#   '0.8%  0.91MB',
#   '0.8%  0.88MB',
#   '0.8%  0.87MB',
#   '0.8%  0.86MB',
#   '0.7%  0.87MB',
#   '0.7%  0.90MB',
#   '0.7%  0.88MB',
#   '0.8%  0.86MB',
#   '0.8%  0.80MB',
#   '0.8%  0.89MB',
#   '0.9%  0.88MB',
#   '0.8%',
#   '0.88MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0eb6789774fe4c885',
#   'Netscout Kpi hourly dev',
#   'm3.xlarge',
#   '$191.52',
#   '3.4%  0.15MB',
#   '3.4%  0.14MB',
#   '3.4%  0.14MB',
#   '3.3%  0.14MB',
#   '3.3%  0.40MB',
#   '3.5%  0.27MB',
#   '3.3%  0.14MB',
#   '3.3%  0.14MB',
#   '3.3%  0.14MB',
#   '3.2%  0.14MB',
#   '3.3%  0.14MB',
#   '3.3%  0.14MB',
#   '3.3%  0.14MB',
#   '3.3%  0.14MB',
#   '3.3%',
#   '0.17MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0ae535f3b04a01e65',
#   'cbelkweb-e1a-01.cb.comcast.net',
#   'm4.large',
#   '$72.00',
#   '1.0%  0.24MB',
#   '0.9%  0.23MB',
#   '0.9%  0.24MB',
#   '0.9%  0.24MB',
#   '0.9%  0.24MB',
#   '0.9%  0.24MB',
#   '0.9%  0.25MB',
#   '1.0%  0.25MB',
#   '1.0%  0.28MB',
#   '1.0%  0.25MB',
#   '0.9%  0.24MB',
#   '1.0%  0.26MB',
#   '1.0%  0.25MB',
#   '1.0%  0.25MB',
#   '1.0%',
#   '0.25MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-37c2c5ae',
#   'cbdb-e1a-01.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.1%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.1%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.31MB',
#   '1.0%  0.32MB',
#   '1.0%',
#   '0.32MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0b11ddbf67d6c176f',
#   'CB-DEV-NODE',
#   'm4.4xlarge',
#   '$576.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0f4fe21f27434b62d',
#   'django Dev',
#   'm4.xlarge',
#   '$144.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-05bb2ed02e1cac0d5',
#   'odpcworker-e1b-03.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.9%  0.86MB',
#   '0.9%  0.91MB',
#   '0.8%  0.87MB',
#   '0.8%  0.90MB',
#   '0.8%  0.87MB',
#   '0.8%  0.86MB',
#   '0.8%  0.86MB',
#   '0.8%  0.86MB',
#   '0.9%  0.88MB',
#   '0.8%  0.87MB',
#   '0.8%  0.85MB',
#   '0.8%  0.80MB',
#   '0.8%  0.87MB',
#   '0.8%  0.88MB',
#   '0.8%',
#   '0.87MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0f75d1c0fcf1008e5',
#   'odpsprkm-e1a-01.odp.comcast.net',
#   'c4.4xlarge',
#   '$573.12',
#   '0.4%  0.74MB',
#   '0.4%  0.77MB',
#   '0.4%  0.77MB',
#   '0.4%  0.78MB',
#   '0.4%  0.77MB',
#   '0.4%  0.77MB',
#   '0.4%  0.80MB',
#   '0.4%  0.77MB',
#   '0.4%  0.80MB',
#   '0.4%  0.76MB',
#   '0.4%  0.77MB',
#   '0.4%  0.66MB',
#   '0.4%  0.78MB',
#   '0.4%  0.77MB',
#   '0.4%',
#   '0.77MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-05def4a05818b317b',
#   'odpcworker-e1b-01.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.0%  0.88MB',
#   '1.1%  0.92MB',
#   '1.0%  0.89MB',
#   '1.0%  0.91MB',
#   '1.0%  0.88MB',
#   '1.1%  0.86MB',
#   '0.8%  0.86MB',
#   '1.1%  0.87MB',
#   '1.1%  0.89MB',
#   '1.0%  0.88MB',
#   '1.0%  0.86MB',
#   '1.0%  0.80MB',
#   '1.0%  0.88MB',
#   '1.1%  0.88MB',
#   '1.0%',
#   '0.88MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0029cb28871d15df0',
#   'cbelkdata-e1b-02.cb.comcast.net',
#   'i3.xlarge',
#   '$208.59',
#   '2.0%  0.90MB',
#   '2.0%  0.90MB',
#   '2.0%  0.90MB',
#   '2.0%  0.90MB',
#   '2.0%  0.89MB',
#   '2.0%  0.89MB',
#   '2.0%  0.91MB',
#   '2.0%  0.90MB',
#   '2.0%  0.94MB',
#   '2.0%  0.91MB',
#   '2.1%  0.98MB',
#   '2.0%  1.01MB',
#   '2.0%  0.97MB',
#   '2.5%  105.63MB',
#   '2.1%',
#   '8.40MB',
#   '13 days'],
#  ['us-east-1a',
#   'i-03c199fcbd48c99ba',
#   'odpsync-e1a-05.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.1%  0.69MB',
#   '2.1%  0.70MB',
#   '2.1%  0.69MB',
#   '2.1%  0.71MB',
#   '2.1%  0.68MB',
#   '2.1%  0.68MB',
#   '2.1%  0.68MB',
#   '2.1%  0.68MB',
#   '2.1%  0.70MB',
#   '2.1%  0.69MB',
#   '2.0%  0.62MB',
#   '1.9%  0.51MB',
#   '2.1%  0.69MB',
#   '2.1%  0.72MB',
#   '2.1%',
#   '0.68MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-05c99b4d1e5e0c307',
#   'odpsync-e1b-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.2%  0.82MB',
#   '2.2%  0.84MB',
#   '2.2%  0.83MB',
#   '2.2%  0.86MB',
#   '2.2%  0.85MB',
#   '2.2%  0.86MB',
#   '2.2%  0.84MB',
#   '2.2%  0.84MB',
#   '2.2%  0.83MB',
#   '2.2%  0.82MB',
#   '2.1%  0.80MB',
#   '2.0%  0.65MB',
#   '2.3%  0.89MB',
#   '2.3%  0.94MB',
#   '2.2%',
#   '0.83MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-0e4258872597cce69',
#   'odpproxy-e1a-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.7%  0.29MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.32MB',
#   '0.7%  0.32MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%  0.31MB',
#   '0.7%',
#   '0.31MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-dac1c643',
#   'cbdb-e1a-06s.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.27MB',
#   '1.0%  0.28MB',
#   '1.0%',
#   '0.28MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-01d73c95a2abeb51a',
#   'odpsync-e1a-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.1%  0.69MB',
#   '2.2%  0.70MB',
#   '2.2%  0.70MB',
#   '2.2%  0.71MB',
#   '2.1%  0.68MB',
#   '2.2%  0.69MB',
#   '2.2%  0.69MB',
#   '2.2%  0.69MB',
#   '2.2%  0.70MB',
#   '2.2%  0.69MB',
#   '2.1%  0.63MB',
#   '1.8%  0.41MB',
#   '1.8%  0.36MB',
#   '1.8%  0.37MB',
#   '2.1%',
#   '0.62MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-1aa68583',
#   'cbapi-e1a-01s.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.17MB',
#   '0.6%  0.17MB',
#   '0.6%  0.16MB',
#   '0.6%  0.17MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%',
#   '0.16MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-08daf06facbf6dcf7',
#   'odpsync-e1b-07.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.1%  0.84MB',
#   '1.0%  0.81MB',
#   '1.1%  0.80MB',
#   '1.1%  0.83MB',
#   '1.0%  0.81MB',
#   '1.1%  0.83MB',
#   '1.2%  0.81MB',
#   '1.1%  0.81MB',
#   '1.2%  0.79MB',
#   '1.2%  0.79MB',
#   '1.1%  0.77MB',
#   '1.0%  0.65MB',
#   '1.1%  0.87MB',
#   '1.2%  0.92MB',
#   '1.1%',
#   '0.81MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-05ce1ea2f93d08fbb',
#   'odpsprkm-e1b-01.odp.comcast.net',
#   'c4.4xlarge',
#   '$245.62',
#   '0.4%  0.70MB',
#   '0.4%  0.73MB',
#   '0.4%  0.73MB',
#   '0.4%  0.73MB',
#   '0.4%  0.73MB',
#   '0.4%  0.73MB',
#   '0.8%  28.15MB',
#   '1.7%  90.70MB',
#   '1.7%  90.69MB',
#   '1.7%  91.02MB',
#   '1.7%  90.80MB',
#   '1.5%  74.93MB',
#   '0.7%  18.94MB',
#   '0.8%  19.01MB',
#   '0.9%',
#   '36.33MB',
#   '6 days'],
#  ['us-east-1d',
#   'i-03930f4a9a1155864',
#   'cbelkmstr-e1d-01stg.cb.comcast.net',
#   'm4.2xlarge',
#   '$288.00',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%  0.71MB',
#   '0.1%  0.70MB',
#   '0.1%  0.70MB',
#   '0.1%',
#   '0.70MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-06f60a83f269dd949',
#   'odpsync-e1a-10.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.9%  0.65MB',
#   '0.9%  0.67MB',
#   '0.9%  0.67MB',
#   '0.9%  0.68MB',
#   '0.9%  0.65MB',
#   '0.9%  0.66MB',
#   '0.9%  0.66MB',
#   '0.9%  0.65MB',
#   '0.9%  0.67MB',
#   '0.9%  0.66MB',
#   '0.9%  0.60MB',
#   '0.9%  0.51MB',
#   '1.0%  0.67MB',
#   '0.9%  0.69MB',
#   '0.9%',
#   '0.65MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-08e5a7a72d9307502',
#   'odpzoo-e1a-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.8%  0.38MB',
#   '1.8%  0.41MB',
#   '1.8%  0.41MB',
#   '1.8%  0.41MB',
#   '1.8%  0.41MB',
#   '1.8%  0.41MB',
#   '1.7%  0.41MB',
#   '1.7%  0.40MB',
#   '1.7%  0.40MB',
#   '1.7%  0.40MB',
#   '1.7%  0.40MB',
#   '1.7%  0.40MB',
#   '2.0%  0.40MB',
#   '1.8%  0.41MB',
#   '1.8%',
#   '0.40MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-b72f5724',
#   'cbdb-e1b-03.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.1%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.31MB',
#   '1.0%  0.32MB',
#   '1.0%',
#   '0.32MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-07896ecb385a422ab',
#   'cassandra-3.10-databasetest-1',
#   'c3.xlarge',
#   '$151.20',
#   '0.4%  0.00MB',
#   '0.5%  0.01MB',
#   '0.5%  0.00MB',
#   '0.5%  0.00MB',
#   '0.5%  0.00MB',
#   '0.5%  0.01MB',
#   '0.4%  0.00MB',
#   '0.4%  0.00MB',
#   '0.4%  0.01MB',
#   '0.4%  0.01MB',
#   '0.4%  0.00MB',
#   '0.4%  0.00MB',
#   '0.4%  0.00MB',
#   '0.4%  0.00MB',
#   '0.4%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-a6c2c53f',
#   'cbdb-e1a-03.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.1%  0.33MB',
#   '1.0%  0.32MB',
#   '1.0%  0.33MB',
#   '1.0%  0.33MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%  0.32MB',
#   '1.1%  0.32MB',
#   '1.0%  0.32MB',
#   '1.0%',
#   '0.33MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-f5a6856c',
#   'cbapi-e1a-03s.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.5%  0.16MB',
#   '0.5%  0.16MB',
#   '0.5%  0.16MB',
#   '0.5%  0.16MB',
#   '0.5%  0.16MB',
#   '0.6%  0.17MB',
#   '0.5%  0.17MB',
#   '0.5%  0.17MB',
#   '0.5%  0.17MB',
#   '0.5%  0.17MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.5%',
#   '0.16MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-3b8bcea2',
#   'CB-D3-STG',
#   'm4.4xlarge',
#   '$576.00',
#   '0.0%  0.01MB',
#   '0.0%  0.01MB',
#   '0.0%  0.01MB',
#   '0.0%  0.01MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%  0.01MB',
#   '0.0%  0.01MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%  0.01MB',
#   '0.0%',
#   '0.01MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0e85524e26f9b5b61',
#   'odpzoo-e1b-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.0%  0.39MB',
#   '2.0%  0.43MB',
#   '2.0%  0.43MB',
#   '2.0%  0.43MB',
#   '2.0%  0.43MB',
#   '2.0%  0.43MB',
#   '2.0%  0.44MB',
#   '2.0%  0.44MB',
#   '2.1%  0.43MB',
#   '2.1%  0.43MB',
#   '2.0%  0.43MB',
#   '2.0%  0.43MB',
#   '2.0%  0.42MB',
#   '2.0%  0.43MB',
#   '2.0%',
#   '0.43MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-82c2c51b',
#   'cbdb-e1a-05s.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.29MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.28MB',
#   '1.0%  0.27MB',
#   '1.0%  0.28MB',
#   '1.0%',
#   '0.28MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0e247d8cc598bb642',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$82.08',
#   '0.8%  9.12MB',
#   '0.6%  0.09MB',
#   '0.7%  0.09MB',
#   '0.7%  4.45MB',
#   '0.9%  14.91MB',
#   '0.8%  7.59MB',
#   '0.9%  14.68MB',
#   '0.7%  1.88MB',
#   '0.6%  0.09MB',
#   '0.6%  0.09MB',
#   '1.3%  27.70MB',
#   '0.8%  11.00MB',
#   '1.4%  24.22MB',
#   '5.2%  12.02MB',
#   '1.2%',
#   '9.14MB',
#   '6 days'],
#  ['us-east-1b',
#   'i-0f24d361a84e1398a',
#   'CB-STG-NODE-RDKB',
#   'm4.4xlarge',
#   '$576.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%',
#   '0.01MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-16a6858f',
#   'cblb-e1a-01s.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.27MB',
#   '0.5%  0.26MB',
#   '0.5%  0.27MB',
#   '0.5%',
#   '0.27MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0d57e7434a1fdeae9',
#   'odpsync-e1b-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.2%  0.86MB',
#   '2.3%  0.84MB',
#   '2.3%  0.83MB',
#   '2.3%  0.86MB',
#   '2.3%  0.85MB',
#   '2.3%  0.86MB',
#   '2.2%  0.84MB',
#   '2.2%  0.84MB',
#   '2.2%  0.83MB',
#   '2.2%  0.81MB',
#   '2.2%  0.80MB',
#   '2.0%  0.66MB',
#   '2.4%  0.89MB',
#   '2.4%  0.94MB',
#   '2.2%',
#   '0.84MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-06e226dfe7b1c0550',
#   'odpproxy-e1b-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.1%  0.28MB',
#   '1.1%  0.31MB',
#   '1.1%  0.31MB',
#   '1.1%  0.31MB',
#   '1.1%  0.31MB',
#   '1.1%  0.31MB',
#   '1.1%  0.31MB',
#   '1.1%  0.31MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.30MB',
#   '1.1%  0.31MB',
#   '1.1%',
#   '0.30MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-ce386fff',
#   'CB-D3-DEV',
#   'm4.4xlarge',
#   '$576.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-c6a4a05f',
#   'cbdb-e1a-01s.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%  0.31MB',
#   '1.0%',
#   '0.31MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-049bf742ca97abbf6',
#   'cbelkmstr-e1a-01stg.cb.comcast.net',
#   'm4.2xlarge',
#   '$288.00',
#   '0.1%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%  0.36MB',
#   '0.0%',
#   '0.36MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0b4525e83831d5e86',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$123.12',
#   '0.6%  3.08MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '0.5%  0.60MB',
#   '0.7%  7.40MB',
#   '0.6%  0.90MB',
#   '0.8%  6.44MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '2.3%  11.36MB',
#   '0.8%  1.54MB',
#   '4.4%  12.94MB',
#   '5.1%  7.07MB',
#   '1.3%',
#   '3.69MB',
#   '9 days'],
#  ['us-east-1a',
#   'i-0ad7ddc40007a5941',
#   'CB-ELK-data-node-2',
#   'r3.2xlarge',
#   '$478.80',
#   '0.5%  0.85MB',
#   '0.5%  0.86MB',
#   '0.5%  0.85MB',
#   '0.5%  0.86MB',
#   '0.4%  0.85MB',
#   '0.4%  0.85MB',
#   '0.5%  0.86MB',
#   '0.4%  0.86MB',
#   '0.4%  0.85MB',
#   '0.4%  0.85MB',
#   '0.5%  0.86MB',
#   '0.4%  0.85MB',
#   '0.5%  0.85MB',
#   '0.4%  0.85MB',
#   '0.4%',
#   '0.86MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0e2549997c61f5231',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$123.12',
#   '0.7%  3.10MB',
#   '0.6%  0.08MB',
#   '0.5%  0.08MB',
#   '0.6%  0.60MB',
#   '0.8%  7.42MB',
#   '0.6%  0.89MB',
#   '0.8%  5.16MB',
#   '0.6%  0.41MB',
#   '0.6%  0.08MB',
#   '0.5%  0.08MB',
#   '2.6%  12.36MB',
#   '0.7%  0.90MB',
#   '4.4%  12.91MB',
#   '5.2%  8.11MB',
#   '1.4%',
#   '3.73MB',
#   '9 days'],
#  ['us-east-1b',
#   'i-0f4fddd1b9fa2d254',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$150.48',
#   '0.7%  3.02MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '0.6%  0.60MB',
#   '0.8%  7.05MB',
#   '0.6%  0.90MB',
#   '0.6%  0.63MB',
#   '0.6%  0.52MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '4.1%  17.82MB',
#   '0.6%  0.78MB',
#   '3.5%  10.02MB',
#   '0.6%  0.52MB',
#   '1.1%',
#   '3.01MB',
#   '11 days'],
#  ['us-east-1b',
#   'i-06d293bfcd0535898',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
#   '$150.48',
#   '0.7%  2.89MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '0.6%  0.60MB',
#   '0.8%  7.18MB',
#   '0.7%  1.23MB',
#   '0.8%  4.62MB',
#   '0.6%  0.21MB',
#   '0.6%  0.08MB',
#   '0.6%  0.08MB',
#   '2.4%  11.92MB',
#   '0.7%  0.77MB',
#   '2.6%  4.75MB',
#   '5.3%  7.51MB',
#   '1.3%',
#   '3.00MB',
#   '11 days'],
#  ['us-east-1a',
#   'i-0e2164a13338ccc82',
#   'cbelkweb-e1a-01s.cb.comcast.net',
#   'm4.large',
#   '$72.00',
#   '0.9%  0.42MB',
#   '1.0%  0.40MB',
#   '1.0%  0.40MB',
#   '0.9%  0.41MB',
#   '1.0%  0.41MB',
#   '0.8%  0.41MB',
#   '0.9%  0.42MB',
#   '0.9%  0.42MB',
#   '0.9%  0.42MB',
#   '0.9%  0.42MB',
#   '0.9%  0.44MB',
#   '0.9%  0.44MB',
#   '1.0%  0.44MB',
#   '1.0%  0.43MB',
#   '0.9%',
#   '0.42MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-011b4083dcf557cdf',
#   'django_state_table-api',
#   't2.large',
#   '$67.68',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-03bd61d590e366986',
#   'odpsync-e1a-04.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.2%  0.68MB',
#   '2.2%  0.69MB',
#   '2.3%  0.69MB',
#   '2.3%  0.70MB',
#   '2.3%  0.67MB',
#   '2.2%  0.68MB',
#   '2.2%  0.68MB',
#   '2.2%  0.68MB',
#   '2.2%  0.70MB',
#   '2.2%  0.68MB',
#   '2.2%  0.62MB',
#   '2.0%  0.51MB',
#   '2.3%  0.69MB',
#   '2.3%  0.72MB',
#   '2.2%',
#   '0.67MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-5b0c98c8',
#   'cbd3-e1b-03.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.5%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%  0.15MB',
#   '0.5%  0.15MB',
#   '0.4%  0.15MB',
#   '0.4%',
#   '0.15MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0a686dd124d89f7d3',
#   'Django druid',
#   'm4.xlarge',
#   '$144.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.01MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-08d17523328f8af3e',
#   'odprabbit-e1a-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.6%  1.85MB',
#   '1.6%  1.90MB',
#   '1.7%  1.89MB',
#   '1.6%  1.91MB',
#   '1.5%  1.90MB',
#   '1.6%  1.91MB',
#   '1.6%  1.89MB',
#   '1.6%  1.92MB',
#   '1.6%  1.96MB',
#   '1.5%  1.94MB',
#   '1.5%  1.96MB',
#   '1.5%  1.91MB',
#   '1.5%  1.83MB',
#   '1.6%  1.88MB',
#   '1.6%',
#   '1.90MB',
#   '14 days'],
#  ['us-east-1d',
#   'i-0fb9d045a62b31b71',
#   'cbelkdata-e1d-01stg.cb.comcast.net',
#   'i3.xlarge',
#   '$224.64',
#   '0.1%  0.37MB',
#   '0.1%  0.37MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.37MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.38MB',
#   '0.1%  0.37MB',
#   '0.2%  0.38MB',
#   '0.1%',
#   '0.38MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0cdae32e637e3525e',
#   'CB-DEV-NODECLUSTER',
#   'm4.4xlarge',
#   '$576.00',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.03MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-09a80282049f8b47f',
#   nan,
#   'm3.xlarge',
#   '$191.52',
#   nan,
#   nan,
#   nan,
#   nan,
#   '0.9%  0.27MB',
#   '0.5%  0.07MB',
#   '0.5%  0.07MB',
#   '0.5%  0.07MB',
#   '0.5%  0.07MB',
#   '0.5%  0.07MB',
#   '0.5%  0.07MB',
#   '0.5%  0.07MB',
#   '0.6%  0.07MB',
#   '0.5%  0.37MB',
#   '0.6%',
#   '0.12MB',
#   '10 days'],
#  ['us-east-1a',
#   'i-0fac2a31a5bdcc6a7',
#   nan,
#   'm3.xlarge',
#   '$191.52',
#   nan,
#   nan,
#   nan,
#   nan,
#   '4.1%  1.94MB',
#   '3.3%  0.14MB',
#   '3.2%  0.14MB',
#   '3.2%  0.14MB',
#   '3.3%  0.14MB',
#   '3.3%  0.14MB',
#   '3.2%  0.14MB',
#   '3.2%  0.13MB',
#   '3.2%  0.13MB',
#   '3.2%  0.61MB',
#   '3.3%',
#   '0.36MB',
#   '10 days'],
#  ['us-east-1b',
#   'i-02efc819e724a5b92',
#   'odpzoo-e1b-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.8%  0.40MB',
#   '1.7%  0.43MB',
#   '1.7%  0.43MB',
#   '1.7%  0.43MB',
#   '1.7%  0.42MB',
#   '1.7%  0.42MB',
#   '1.7%  0.42MB',
#   '1.6%  0.41MB',
#   '1.6%  0.41MB',
#   '1.8%  0.41MB',
#   '1.7%  0.40MB',
#   '1.7%  0.41MB',
#   '1.6%  0.40MB',
#   '1.6%  0.41MB',
#   '1.7%',
#   '0.41MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-2d0195be',
#   'cbapi-e1b-03.cb.comcast.net',
#   'c4.xlarge',
#   '$40.94',
#   '0.8%  0.16MB',
#   '0.9%  0.16MB',
#   '0.9%  0.16MB',
#   '0.8%  0.16MB',
#   '23.3%  17.46MB',
#   '54.0%  41.15MB',
#   '54.2%  41.31MB',
#   '54.2%  41.28MB',
#   '55.1%  42.03MB',
#   '55.0%  41.98MB',
#   '53.7%  40.93MB',
#   '53.1%  40.44MB',
#   '53.4%  40.72MB',
#   '53.8%  41.00MB',
#   '36.6%',
#   '27.78MB',
#   '4 days'],
#  ['us-east-1b',
#   'i-610296f2',
#   'cbd3-e1b-02.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%  0.14MB',
#   '0.5%',
#   '0.14MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0058415be1060aee8',
#   'cbelkmstr-e1b-01stg.cb.comcast.net',
#   'm4.2xlarge',
#   '$288.00',
#   '0.1%  1.60MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%  1.59MB',
#   '0.1%',
#   '1.59MB',
#   '14 days'],
#  ['us-east-1a',
#   'i-212b7eb8',
#   'cbapi-e1a-01.cb.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '6.4%  0.20MB',
#   '6.5%  0.20MB',
#   '6.4%  0.20MB',
#   '6.4%  0.20MB',
#   '6.4%  0.20MB',
#   '6.2%  0.20MB',
#   '6.1%  0.20MB',
#   '6.1%  0.20MB',
#   '6.0%  0.20MB',
#   '6.1%  0.20MB',
#   '6.6%  0.20MB',
#   '6.4%  0.20MB',
#   '6.3%  0.19MB',
#   '6.2%  0.20MB',
#   '6.3%',
#   '0.20MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-812e5612',
#   'cbdb-e1b-02.cb.comcast.net',
#   'c3.4xlarge',
#   '$604.80',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.17MB',
#   '1.1%  0.16MB',
#   '1.1%  0.16MB',
#   '1.1%  0.16MB',
#   '1.1%  0.17MB',
#   '1.1%',
#   '0.17MB',
#   '14 days'],
#  ['us-east-1b',
#   'i-0689c44c463537dfd',
#   'Quark-Dev-Testing-stgvpc',
#   'm3.xlarge',
# ...
#   '3.0%  4.52MB',
#   '2.8%  4.64MB',
#   '2.8%  4.65MB',
#   '2.9%',
#   '4.81MB',
#   '9 days'],
#  ['us-west-2c',
#   'i-0e2b3aba77e03919e',
#   'odpsprkw-w2c-11.odp.comcast.net',
#   'm4.4xlarge',
#   '$452.57',
#   '0.5%  7.50MB',
#   '0.5%  7.54MB',
#   '0.5%  7.52MB',
#   '0.5%  2.93MB',
#   '0.4%  1.97MB',
#   '0.4%  0.44MB',
#   '0.4%  0.44MB',
#   '0.4%  0.44MB',
#   '0.4%  0.47MB',
#   '0.4%  0.44MB',
#   '0.4%  0.39MB',
#   '0.4%  0.42MB',
#   '0.3%  0.42MB',
#   '0.4%  1.32MB',
#   '0.4%',
#   '2.30MB',
#   '11 days'],
#  ['us-west-2a',
#   'i-062480bb4d7e9d528',
#   'salt-salt-master-01.inf.us-west-2.plume.comcast.net',
#   'r4.large',
#   '$95.76',
#   '2.8%  0.08MB',
#   '2.8%  0.08MB',
#   '2.8%  0.08MB',
#   '2.8%  0.08MB',
#   '2.7%  0.08MB',
#   '2.9%  0.08MB',
#   '2.9%  0.08MB',
#   '2.9%  0.08MB',
#   '2.9%  0.08MB',
#   '2.9%  0.08MB',
#   '2.9%  0.08MB',
#   '2.9%  0.10MB',
#   '2.9%  0.08MB',
#   '2.9%  0.08MB',
#   '2.8%',
#   '0.08MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-0324d0e5e8ffac0a8',
#   'odpcworker-w2a-02.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.7%  0.23MB',
#   '0.6%  0.72MB',
#   '0.6%  0.73MB',
#   '0.6%  0.73MB',
#   '0.6%  0.73MB',
#   '0.6%  0.71MB',
#   '0.6%  0.61MB',
#   '0.5%  0.56MB',
#   '0.5%  0.56MB',
#   '0.5%  0.56MB',
#   '0.5%  0.56MB',
#   '0.6%  0.77MB',
#   '0.6%  0.71MB',
#   '0.6%  0.72MB',
#   '0.6%',
#   '0.64MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-0a9e5a52afb2541c5',
#   'odpque-w2b-05.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '2.6%  2.95MB',
#   '2.6%  2.98MB',
#   '2.6%  2.98MB',
#   '2.6%  2.98MB',
#   '2.6%  2.99MB',
#   '2.6%  2.98MB',
#   '2.6%  2.97MB',
#   '2.5%  2.98MB',
#   '2.6%  2.97MB',
#   '2.6%  2.97MB',
#   '2.6%  2.97MB',
#   '2.6%  2.91MB',
#   '2.5%  2.92MB',
#   '2.5%  4.13MB',
#   '2.6%',
#   '3.05MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-08a822b2e0437cf0f',
#   'odpcworker-w2b-02.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.9%  0.22MB',
#   '0.8%  0.73MB',
#   '0.8%  0.73MB',
#   '0.8%  0.74MB',
#   '0.8%  0.74MB',
#   '0.7%  0.62MB',
#   '0.7%  0.60MB',
#   '0.7%  0.56MB',
#   '0.7%  0.56MB',
#   '0.7%  0.56MB',
#   '0.7%  0.56MB',
#   '0.8%  0.76MB',
#   '0.8%  0.71MB',
#   '0.8%  0.72MB',
#   '0.8%',
#   '0.63MB',
#   '14 days'],
#  ['us-west-2c',
#   'i-0d0d7695d0d313b9b',
#   'odpsprkw-w2c-04.odp.comcast.net',
#   'm4.4xlarge',
#   '$452.57',
#   '0.5%  7.49MB',
#   '0.5%  7.52MB',
#   '0.5%  7.51MB',
#   '0.4%  2.92MB',
#   '0.4%  1.97MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.47MB',
#   '0.3%  0.44MB',
#   '0.3%  0.38MB',
#   '0.3%  0.43MB',
#   '0.3%  0.42MB',
#   '0.3%  1.41MB',
#   '0.4%',
#   '2.30MB',
#   '11 days'],
#  ['us-west-2c',
#   'i-01623212b4f09d315',
#   'odpproxy-w2c-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '0.7%  0.13MB',
#   '0.7%  0.16MB',
#   '0.7%  0.16MB',
#   '0.7%  0.16MB',
#   '0.7%  0.16MB',
#   '0.7%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.6%  0.16MB',
#   '0.7%  0.15MB',
#   '0.6%  0.15MB',
#   '0.7%  0.15MB',
#   '0.7%  0.14MB',
#   '0.6%  0.16MB',
#   '0.7%',
#   '0.15MB',
#   '14 days'],
#  ['us-west-2c',
#   'i-00a408a0719c0e5f8',
#   'webapi-chi-02.prod.us-west-2.plume.comcast.net',
#   'm4.xlarge',
#   '$133.71',
#   '1.6%  3.09MB',
#   '1.6%  3.21MB',
#   '1.5%  2.93MB',
#   '1.6%  3.45MB',
#   '1.9%  4.63MB',
#   '1.8%  4.37MB',
#   '2.2%  5.05MB',
#   '1.9%  4.35MB',
#   '1.7%  4.12MB',
#   '1.8%  4.17MB',
#   '2.0%  4.57MB',
#   '2.0%  4.57MB',
#   '2.0%  4.49MB',
#   '2.2%  4.81MB',
#   '1.8%',
#   '4.13MB',
#   '13 days'],
#  ['us-west-2a',
#   'i-0901b767f0688e21b',
#   'Sameer Plume Dev',
#   't2.medium',
#   '$33.84',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%  0.00MB',
#   '0.0%',
#   '0.00MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-0cca86f6367894bae',
#   'odpcore-w2b-04.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.2%  0.67MB',
#   '1.2%  0.70MB',
#   '1.2%  0.70MB',
#   '1.2%  0.70MB',
#   '1.2%  0.71MB',
#   '1.2%  0.71MB',
#   '1.2%  0.71MB',
#   '1.2%  0.70MB',
#   '1.2%  0.70MB',
#   '1.2%  0.70MB',
#   '1.2%  0.65MB',
#   '1.3%  0.73MB',
#   '1.3%  0.68MB',
#   '1.3%  0.70MB',
#   '1.2%',
#   '0.70MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-0644d7ce3fd34ac1c',
#   'odpsprkw-w2b-09.odp.comcast.net',
#   'm4.4xlarge',
#   '$164.57',
#   '0.4%  5.26MB',
#   '0.4%  5.29MB',
#   '0.4%  5.28MB',
#   '0.4%  5.29MB',
#   '0.4%  5.29MB',
#   '0.4%  5.30MB',
#   '0.4%  5.30MB',
#   '0.4%  5.30MB',
#   '0.4%  5.33MB',
#   '0.4%  5.30MB',
#   '0.4%  4.90MB',
#   '0.3%  0.42MB',
#   '0.3%  0.41MB',
#   '0.3%  1.42MB',
#   '0.3%',
#   '4.29MB',
#   '4 days'],
#  ['us-west-2b',
#   'i-04672d63c22ccf398',
#   'odphook-w2b-04.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.5%  0.39MB',
#   '0.5%  0.42MB',
#   '0.5%  0.42MB',
#   '0.5%  0.43MB',
#   '0.5%  0.43MB',
#   '0.6%  0.43MB',
#   '0.5%  0.43MB',
#   '0.6%  0.43MB',
#   '0.6%  0.46MB',
#   '0.6%  0.43MB',
#   '0.5%  0.41MB',
#   '0.6%  0.43MB',
#   '0.6%  0.42MB',
#   '0.7%  0.78MB',
#   '0.6%',
#   '0.45MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-04dd1b3446d09d42e',
#   'odpcworker-w2b-01.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.0%  0.21MB',
#   '0.8%  0.73MB',
#   '0.8%  0.72MB',
#   '0.8%  0.73MB',
#   '0.8%  0.73MB',
#   '0.8%  0.62MB',
#   '0.8%  0.59MB',
#   '0.8%  0.56MB',
#   '0.8%  0.56MB',
#   '0.8%  0.56MB',
#   '0.8%  0.56MB',
#   '0.9%  0.75MB',
#   '0.9%  0.71MB',
#   '0.9%  0.71MB',
#   '0.8%',
#   '0.62MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-0130bd4dd18e6d454',
#   'odplb-w2b-04.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.4%  3.03MB',
#   '1.4%  3.20MB',
#   '1.4%  3.19MB',
#   '1.4%  3.20MB',
#   '1.6%  3.21MB',
#   '1.5%  3.21MB',
#   '1.6%  3.16MB',
#   '1.4%  2.91MB',
#   '1.4%  2.91MB',
#   '1.4%  2.91MB',
#   '1.4%  2.91MB',
#   '1.5%  2.87MB',
#   '1.5%  2.87MB',
#   '1.7%  3.17MB',
#   '1.5%',
#   '3.05MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-0c6da90e44073fa61',
#   'optimizer-chi-01.prod.us-west-2.plume.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.3%  0.15MB',
#   '0.5%  0.14MB',
#   '0.3%  0.13MB',
#   '0.5%  0.13MB',
#   '0.4%  0.17MB',
#   '0.8%  0.19MB',
#   '3.9%  0.22MB',
#   '2.2%  0.16MB',
#   '1.1%  0.16MB',
#   '1.2%  0.15MB',
#   '1.4%  0.16MB',
#   '1.3%  0.19MB',
#   '2.0%  0.16MB',
#   '2.8%  0.18MB',
#   '1.4%',
#   '0.16MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-0b21036a62bb8c15b',
#   'odpsprkw-w2a-01.odp.comcast.net',
#   'm4.4xlarge',
#   '$576.00',
#   '0.3%  0.50MB',
#   '0.3%  0.44MB',
#   '0.3%  0.45MB',
#   '0.3%  0.45MB',
#   '0.3%  0.46MB',
#   '0.3%  0.46MB',
#   '0.3%  0.44MB',
#   '0.3%  0.43MB',
#   '0.3%  0.46MB',
#   '0.3%  0.43MB',
#   '0.3%  0.39MB',
#   '0.2%  0.09MB',
#   '0.2%  0.09MB',
#   '0.3%  1.99MB',
#   '0.3%',
#   '0.51MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-09693da91e4b48924',
#   'odpque-w2a-04.odp.comcast.net',
#   'c4.xlarge',
#   '$112.58',
#   '1.7%  0.23MB',
#   '1.7%  0.26MB',
#   '1.7%  0.26MB',
#   '1.8%  0.26MB',
#   '1.8%  0.26MB',
#   '1.7%  0.26MB',
#   '1.8%  0.26MB',
#   '1.7%  0.25MB',
#   '1.7%  0.25MB',
#   '1.7%  0.25MB',
#   '2.9%  23.90MB',
#   '18.4%  350.58MB',
#   '2.4%  3.80MB',
#   '2.6%  7.53MB',
#   '3.1%',
#   '27.74MB',
#   '11 days'],
#  ['us-west-2c',
#   'i-0eef23416ad0bc235',
#   'rabbitmq-chi-03.prod.us-west-2.plume.comcast.net',
#   'm4.xlarge',
#   '$133.71',
#   '0.6%  2.38MB',
#   '0.6%  2.83MB',
#   '0.6%  2.45MB',
#   '0.6%  2.24MB',
#   '0.6%  2.25MB',
#   '0.6%  2.38MB',
#   '0.7%  3.45MB',
#   '0.7%  2.90MB',
#   '0.7%  2.96MB',
#   '0.7%  3.16MB',
#   '0.7%  3.30MB',
#   '0.7%  3.37MB',
#   '0.7%  4.86MB',
#   '0.8%  5.23MB',
#   '0.7%',
#   '3.13MB',
#   '13 days'],
#  ['us-west-2b',
#   'i-0e06a4028aba142f8',
#   'odplb-w2b-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.2%  3.02MB',
#   '1.2%  3.05MB',
#   '1.2%  3.05MB',
#   '1.2%  3.05MB',
#   '1.2%  3.06MB',
#   '1.2%  3.06MB',
#   '1.2%  3.06MB',
#   '1.2%  3.06MB',
#   '1.2%  3.06MB',
#   '1.2%  3.06MB',
#   '1.2%  3.06MB',
#   '1.2%  3.00MB',
#   '1.2%  3.00MB',
#   '1.3%  4.53MB',
#   '1.2%',
#   '3.15MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-0e1279e2468a761f0',
#   'odpzoo-w2a-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.5%  0.21MB',
#   '1.5%  0.24MB',
#   '1.5%  0.24MB',
#   '1.5%  0.24MB',
#   '1.5%  0.24MB',
#   '1.5%  0.24MB',
#   '1.5%  0.24MB',
#   '1.5%  0.23MB',
#   '1.5%  0.23MB',
#   '1.5%  0.23MB',
#   '1.5%  0.23MB',
#   '1.5%  0.23MB',
#   '1.5%  0.22MB',
#   '1.4%  0.24MB',
#   '1.5%',
#   '0.23MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-0968e78091fa22a9e',
#   'odpsync-w2a-05.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.0%  0.59MB',
#   '1.0%  0.62MB',
#   '1.0%  0.62MB',
#   '0.9%  0.62MB',
#   '0.8%  0.62MB',
#   '0.9%  0.62MB',
#   '0.8%  0.63MB',
#   '0.9%  0.62MB',
#   '0.8%  0.63MB',
#   '0.7%  0.63MB',
#   '0.7%  0.58MB',
#   '0.8%  0.68MB',
#   '0.7%  0.60MB',
#   '0.7%  0.63MB',
#   '0.8%',
#   '0.62MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-027a6ee33c4195cfe',
#   'mongodb-production-04.shared.us-west-2.plume.comcast.net',
#   'm4.large',
#   '$72.00',
#   '0.4%  0.25MB',
#   '0.4%  0.25MB',
#   '0.4%  0.25MB',
#   '0.4%  0.25MB',
#   '0.4%  0.25MB',
#   '0.4%  0.25MB',
#   '0.4%  0.25MB',
#   '0.4%  0.25MB',
#   '0.5%  0.25MB',
#   '0.5%  0.25MB',
#   '0.4%  0.25MB',
#   '0.5%  0.25MB',
#   '0.5%  0.25MB',
#   '0.4%  0.25MB',
#   '0.4%',
#   '0.25MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-09595d133b3aa414f',
#   'odpsync-w2b-03.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.0%  0.59MB',
#   '1.0%  0.62MB',
#   '1.0%  0.62MB',
#   '1.0%  0.62MB',
#   '1.0%  0.63MB',
#   '1.0%  0.63MB',
#   '1.0%  0.63MB',
#   '1.0%  0.63MB',
#   '1.0%  0.62MB',
#   '1.0%  0.62MB',
#   '1.0%  0.58MB',
#   '1.0%  0.66MB',
#   '1.0%  0.60MB',
#   '1.0%  0.62MB',
#   '1.0%',
#   '0.62MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-021d8edb75f24cf3d',
#   'es-es-esdata-02.inf.us-west-2.plume.comcast.net',
#   'i2.xlarge',
#   '$438.69',
#   '2.4%  4.30MB',
#   '2.4%  4.31MB',
#   '2.5%  4.30MB',
#   '2.5%  4.32MB',
#   '2.5%  4.31MB',
#   '2.6%  4.91MB',
#   '2.3%  5.44MB',
#   '2.6%  5.38MB',
#   '2.7%  5.38MB',
#   '2.8%  5.40MB',
#   '2.9%  4.43MB',
#   '2.6%  4.38MB',
#   '2.4%  4.49MB',
#   '2.5%  4.48MB',
#   '2.6%',
#   '4.70MB',
#   '10 days'],
#  ['us-west-2c',
#   'i-0adbda33e7af57464',
#   'controllershardv2-chi-02.prod.us-west-2.plume.comcast.net',
#   'm4.xlarge',
#   '$144.00',
#   '0.5%  0.03MB',
#   '0.4%  0.03MB',
#   '0.5%  0.03MB',
#   '0.5%  0.03MB',
#   '0.5%  0.08MB',
#   '0.5%  0.08MB',
#   '0.5%  0.03MB',
#   '0.5%  0.08MB',
#   '0.4%  0.03MB',
#   '0.5%  0.03MB',
#   '0.5%  0.03MB',
#   '0.5%  0.08MB',
#   '0.4%  0.03MB',
#   '0.4%  0.03MB',
#   '0.5%',
#   '0.04MB',
#   '14 days'],
#  ['us-west-2c',
#   'i-05bff8c0774270e7b',
#   'odpsprkw-w2c-10.odp.comcast.net',
#   'm4.4xlarge',
#   '$452.57',
#   '0.5%  6.39MB',
#   '0.5%  6.43MB',
#   '0.5%  6.44MB',
#   '0.4%  2.76MB',
#   '0.4%  1.96MB',
#   '0.3%  0.44MB',
#   '0.4%  0.44MB',
#   '0.4%  0.44MB',
#   '0.4%  0.46MB',
#   '0.4%  0.44MB',
#   '0.4%  0.38MB',
#   '0.4%  0.42MB',
#   '0.3%  0.42MB',
#   '0.3%  1.40MB',
#   '0.4%',
#   '2.06MB',
#   '11 days'],
#  ['us-west-2a',
#   'i-0ecd40787b9b666b7',
#   'odpsprkw-w2a-05.odp.comcast.net',
#   'm4.4xlarge',
#   '$576.00',
#   '0.3%  0.49MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.45MB',
#   '0.3%  0.45MB',
#   '0.3%  0.42MB',
#   '0.3%  0.42MB',
#   '0.3%  0.45MB',
#   '0.3%  0.42MB',
#   '0.3%  0.38MB',
#   '0.2%  0.10MB',
#   '0.2%  0.10MB',
#   '0.3%  2.01MB',
#   '0.3%',
#   '0.50MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-0e4851b99203dfd38',
#   'odpcore-w2a-05.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.1%  0.69MB',
#   '1.2%  0.70MB',
#   '1.2%  0.70MB',
#   '1.0%  0.70MB',
#   '1.0%  0.71MB',
#   '1.1%  0.71MB',
#   '1.1%  0.72MB',
#   '1.2%  0.70MB',
#   '1.2%  0.70MB',
#   '1.1%  0.70MB',
#   '1.1%  0.66MB',
#   '1.1%  0.77MB',
#   '1.1%  0.68MB',
#   '1.1%  0.98MB',
#   '1.1%',
#   '0.72MB',
#   '14 days'],
#  ['us-west-2c',
#   'i-079c6439572c3dc8d',
#   'odpsprkw-w2c-13.odp.comcast.net',
#   'm4.4xlarge',
#   '$452.57',
#   '0.5%  7.50MB',
#   '0.6%  7.54MB',
#   '0.5%  7.52MB',
#   '0.5%  2.94MB',
#   '0.4%  1.98MB',
#   '0.4%  0.46MB',
#   '0.4%  0.46MB',
#   '0.4%  0.46MB',
#   '0.4%  0.48MB',
#   '0.4%  0.46MB',
#   '0.4%  0.40MB',
#   '0.4%  0.44MB',
#   '0.3%  0.44MB',
#   '0.4%  1.43MB',
#   '0.4%',
#   '2.32MB',
#   '11 days'],
#  ['us-west-2a',
#   'i-0319137377b855c09',
#   'odpsprkw-w2a-12.odp.comcast.net',
#   'm4.4xlarge',
#   '$576.00',
#   '0.3%  0.49MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.45MB',
#   '0.3%  0.45MB',
#   '0.3%  0.42MB',
#   '0.3%  0.41MB',
#   '0.3%  0.44MB',
#   '0.3%  0.41MB',
#   '0.3%  0.37MB',
#   '0.2%  0.08MB',
#   '0.2%  0.08MB',
#   '0.2%  2.22MB',
#   '0.3%',
#   '0.51MB',
#   '14 days'],
#  ['us-west-2c',
#   'i-027abbd572db684eb',
#   'odpsprkw-w2c-06.odp.comcast.net',
#   'm4.4xlarge',
#   '$452.57',
#   '0.4%  5.70MB',
#   '0.4%  5.75MB',
#   '0.4%  5.74MB',
#   '0.4%  2.67MB',
#   '0.3%  1.97MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.44MB',
#   '0.3%  0.47MB',
#   '0.3%  0.44MB',
#   '0.3%  0.38MB',
#   '0.3%  0.43MB',
#   '0.2%  0.42MB',
#   '0.3%  1.57MB',
#   '0.3%',
#   '1.92MB',
#   '11 days'],
#  ['us-west-2a',
#   'i-05e469826ac040b59',
#   'odpsprkw-w2a-09.odp.comcast.net',
#   'm4.4xlarge',
#   '$576.00',
#   '0.2%  0.43MB',
#   '0.2%  0.37MB',
#   '0.2%  0.37MB',
#   '0.3%  0.38MB',
#   '0.3%  0.38MB',
#   '0.3%  0.38MB',
#   '0.3%  0.36MB',
#   '0.3%  0.36MB',
#   '0.2%  0.40MB',
#   '0.3%  0.37MB',
#   '0.2%  0.33MB',
#   '0.2%  0.09MB',
#   '0.2%  0.09MB',
#   '0.3%  2.55MB',
#   '0.2%',
#   '0.49MB',
#   '14 days'],
#  ['us-west-2c',
#   'i-05e1e56dda75b13c6',
#   'odplb-w2c-01.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.4%  2.81MB',
#   '1.5%  2.84MB',
#   '1.5%  2.84MB',
#   '1.5%  2.84MB',
#   '1.5%  2.79MB',
#   '1.5%  2.47MB',
#   '1.5%  2.47MB',
#   '1.5%  2.47MB',
#   '1.5%  2.47MB',
#   '1.5%  2.47MB',
#   '1.5%  2.47MB',
#   '1.5%  2.48MB',
#   '1.5%  2.74MB',
#   '1.6%  4.05MB',
#   '1.5%',
#   '2.73MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-0d54e9c0569920289',
#   'odpredis-w2b-02.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.0%  0.57MB',
#   '1.1%  0.60MB',
#   '1.1%  0.60MB',
#   '1.1%  0.60MB',
#   '1.1%  0.60MB',
#   '1.1%  0.59MB',
#   '1.1%  0.60MB',
#   '1.1%  0.59MB',
#   '1.3%  0.59MB',
#   '1.3%  0.59MB',
#   '1.2%  0.59MB',
#   '1.2%  0.59MB',
#   '1.1%  0.59MB',
#   '1.1%  0.66MB',
#   '1.1%',
#   '0.60MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-002540052279ee66d',
#   'odpcore-w2b-07.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.7%  0.68MB',
#   '0.7%  0.71MB',
#   '0.7%  0.71MB',
#   '0.7%  0.71MB',
#   '0.8%  0.72MB',
#   '0.8%  0.72MB',
#   '0.8%  0.72MB',
#   '0.8%  0.71MB',
#   '0.8%  0.71MB',
#   '0.8%  0.71MB',
#   '0.7%  0.66MB',
#   '0.8%  0.75MB',
#   '0.7%  0.70MB',
#   '0.8%  0.71MB',
#   '0.8%',
#   '0.71MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-07abd2d3f879ca525',
#   'rabbitmq-production-01.shared.us-west-2.plume.comcast.net',
#   'c4.large',
#   '$72.00',
#   '0.4%  0.09MB',
#   '0.4%  0.09MB',
#   '0.4%  0.09MB',
#   '0.4%  0.09MB',
#   '0.4%  0.09MB',
#   '0.4%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%  0.09MB',
#   '0.5%',
#   '0.09MB',
#   '14 days'],
#  ['us-west-2c',
#   'i-0717a93f09aa3e5e4',
#   'odplb-w2c-03.odp.comcast.net',
#   'c4.xlarge',
#   '$143.28',
#   '1.2%  2.82MB',
#   '1.2%  2.85MB',
#   '1.2%  2.86MB',
#   '1.2%  2.85MB',
#   '1.2%  2.81MB',
#   '1.2%  2.49MB',
#   '1.2%  2.45MB',
#   '1.0%  2.19MB',
#   '1.0%  2.19MB',
#   '1.0%  2.19MB',
#   '1.0%  2.19MB',
#   '1.0%  2.21MB',
#   '1.0%  2.47MB',
#   '1.2%  2.75MB',
#   '1.1%',
#   '2.52MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-047acb4371d2800f7',
#   'odpsync-w2a-01.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.1%  0.59MB',
#   '1.1%  0.61MB',
#   '1.1%  0.61MB',
#   '1.1%  0.62MB',
#   '1.1%  0.62MB',
#   '1.0%  0.62MB',
#   '1.1%  0.62MB',
#   '1.0%  0.62MB',
#   '1.1%  0.62MB',
#   '1.0%  0.62MB',
#   '1.0%  0.57MB',
#   '1.1%  0.67MB',
#   '1.1%  0.59MB',
#   '1.1%  0.63MB',
#   '1.1%',
#   '0.62MB',
#   '14 days'],
#  ['us-west-2a',
#   'i-04395870150b6739c',
#   'odpcore-w2a-08.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '1.1%  0.69MB',
#   '1.1%  0.70MB',
#   '1.1%  0.70MB',
#   '1.1%  0.71MB',
#   '1.1%  0.71MB',
#   '1.1%  0.71MB',
#   '1.1%  0.72MB',
#   '1.1%  0.70MB',
#   '1.1%  0.70MB',
#   '1.1%  0.71MB',
#   '1.1%  0.66MB',
#   '1.2%  0.76MB',
#   '1.2%  0.68MB',
#   '1.2%  0.95MB',
#   '1.1%',
#   '0.72MB',
#   '14 days'],
#  ['us-west-2b',
#   'i-04c9cb74f423207c9',
#   'odpcore-w2b-05.odp.comcast.net',
#   'c4.2xlarge',
#   '$286.56',
#   '0.7%  0.66MB',
#   '0.7%  0.69MB',
#   '0.7%  0.69MB',
#   '0.7%  0.69MB',
#   '0.7%  0.70MB',
#   '0.8%  0.70MB',
#   '0.7%  0.71MB',
#   '0.7%  0.69MB',
#   '0.7%  0.69MB',
#   '0.7%  0.69MB',
#   '0.7%  0.65MB',
#   '0.7%  0.73MB',
#   '0.7%  0.67MB',
#   '0.8%  0.69MB',
#   '0.7%',
#   '0.69MB',
#   '14 days']]

# %%
for x in awsdf.values.tolist():
    print(x[0:2], x[3:5], "\n")
# Out:
# ['Region/AZ', 'Instance ID'] ['Instance Type', 'Estimated Monthly Savings']
#
# ['us-east-1b', 'i-0b8c413d9408beffd'] ['m3.xlarge', '$136.80']
#
# ['us-east-1b', 'i-04273cd6ba4f96e13'] ['m3.xlarge', '$136.80']
#
# ['us-east-1b', 'i-06fdd339e4dd0c201'] ['m3.xlarge', '$136.80']
#
# ['us-east-1b', 'i-0ea7b16baee2b6a4e'] ['m3.xlarge', '$123.12']
#
# ['us-east-1b', 'i-0799accd01f99ced4'] ['m3.xlarge', '$136.80']
#
# ['us-east-1a', 'i-06d31cee3dda4deef'] ['i3.xlarge', '$224.64']
#
# ['us-east-1b', 'i-09cbdb36893061df2'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-07fb4f02d91195d15'] ['t2.xlarge', '$135.36']
#
# ['us-east-1a', 'i-0d1479acf8da50b79'] ['m4.2xlarge', '$288.00']
#
# ['us-east-1d', 'i-05796685'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-08e131de99f5df529'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-1ba68582'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-0d7c1335eb078fbbc'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-ff2b7e66'] ['c4.xlarge', '$40.94']
#
# ['us-east-1a', 'i-0ea5aae11f2dff98b'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-0fb195dc77040aefd'] ['m4.large', '$72.00']
#
# ['us-east-1a', 'i-046db2ec47a78e978'] ['c4.xlarge', '$143.28']
#
# ['us-east-1d', 'i-063b159a3eb19859a'] ['m4.large', '$72.00']
#
# ['us-east-1b', 'i-0e67624235981119f'] ['m4.4xlarge', '$576.00']
#
# ['us-east-1a', 'i-082b2f013ad943078'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-01ab0b254fc3b4d27'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-0fa419f85c5953797'] ['m3.xlarge', '$191.52']
#
# ['us-east-1a', 'i-010d1716f2e866436'] ['c4.xlarge', '$143.28']
#
# ['us-east-1d', 'i-0635ef4116afb19cb'] ['m4.xlarge', '$144.00']
#
# ['us-east-1b', 'i-0bc83aa3c255e5aa5'] ['c4.xlarge', '$143.28']
#
# ['us-east-1d', 'i-050c27614d0ee1ab3'] ['m4.2xlarge', '$288.00']
#
# ['us-east-1a', 'i-0a4f2943e5c3387a5'] ['m3.xlarge', '$191.52']
#
# ['us-east-1a', 'i-088b01b14287e5abf'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-972e5604'] ['c3.4xlarge', '$172.80']
#
# ['us-east-1b', 'i-0c8a426dd399b11bc'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-055bb6fd5891a0921'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-fc2b7e65'] ['c4.xlarge', '$51.17']
#
# ['us-east-1b', 'i-0b2c002a7211f3f06'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1b', 'i-0fafb41652b51958b'] ['i3.xlarge', '$112.32']
#
# ['us-east-1a', 'i-28a784b1'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-0332a2a91602fcb63'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-0d41df987b524443b'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-02c53df44edde17a8'] ['m4.xlarge', '$144.00']
#
# ['us-east-1a', 'i-0b4cb5100460bd590'] ['t2.micro', '$8.64']
#
# ['us-east-1b', 'i-0d9b7546e6b59b23a'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-090b1de732878e219'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-0618899e6b14162dd'] ['m4.large', '$72.00']
#
# ['us-east-1a', 'i-31c2c5a8'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-585500c1'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-b0540129'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-0ac1c693'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1b', 'i-0a31b4af2b66fd34b'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-03e381966dfd0fef9'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1b', 'i-992d350a'] ['m3.xlarge', '$82.08']
#
# ['us-east-1a', 'i-092da97789b13bdad'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-0ae0f12292d727db2'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-0db3eab70b075f763'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1b', 'i-4c0c98df'] ['c4.xlarge', '$40.94']
#
# ['us-east-1b', 'i-c1039752'] ['c4.xlarge', '$40.94']
#
# ['us-east-1a', 'i-d8c1c641'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1d', 'i-4fc5cc7e'] ['m4.xlarge', '$144.00']
#
# ['us-east-1a', 'i-0cf1dfcc2e31c56e1'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1d', 'i-969891a7'] ['m4.xlarge', '$144.00']
#
# ['us-east-1a', 'i-36c2c5af'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-fe2b7e67'] ['c4.xlarge', '$40.94']
#
# ['us-east-1b', 'i-1d02968e'] ['c4.xlarge', '$40.94']
#
# ['us-east-1a', 'i-17a6858e'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-d9c1c640'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1d', 'i-05cc1ffeddf8d3c4d'] ['m4.2xlarge', '$288.00']
#
# ['us-east-1a', 'i-04853074ffa2f70d4'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1b', 'i-042a9fa155c1850a4'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-06630e45db6a1a5f6'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-0eb6789774fe4c885'] ['m3.xlarge', '$191.52']
#
# ['us-east-1a', 'i-0ae535f3b04a01e65'] ['m4.large', '$72.00']
#
# ['us-east-1a', 'i-37c2c5ae'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1b', 'i-0b11ddbf67d6c176f'] ['m4.4xlarge', '$576.00']
#
# ['us-east-1b', 'i-0f4fe21f27434b62d'] ['m4.xlarge', '$144.00']
#
# ['us-east-1b', 'i-05bb2ed02e1cac0d5'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-0f75d1c0fcf1008e5'] ['c4.4xlarge', '$573.12']
#
# ['us-east-1b', 'i-05def4a05818b317b'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1b', 'i-0029cb28871d15df0'] ['i3.xlarge', '$208.59']
#
# ['us-east-1a', 'i-03c199fcbd48c99ba'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-05c99b4d1e5e0c307'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-0e4258872597cce69'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-dac1c643'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-01d73c95a2abeb51a'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-1aa68583'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-08daf06facbf6dcf7'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1b', 'i-05ce1ea2f93d08fbb'] ['c4.4xlarge', '$245.62']
#
# ['us-east-1d', 'i-03930f4a9a1155864'] ['m4.2xlarge', '$288.00']
#
# ['us-east-1a', 'i-06f60a83f269dd949'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-08e5a7a72d9307502'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-b72f5724'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1d', 'i-07896ecb385a422ab'] ['c3.xlarge', '$151.20']
#
# ['us-east-1a', 'i-a6c2c53f'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-f5a6856c'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-3b8bcea2'] ['m4.4xlarge', '$576.00']
#
# ['us-east-1b', 'i-0e85524e26f9b5b61'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-82c2c51b'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1b', 'i-0e247d8cc598bb642'] ['m3.xlarge', '$82.08']
#
# ['us-east-1b', 'i-0f24d361a84e1398a'] ['m4.4xlarge', '$576.00']
#
# ['us-east-1a', 'i-16a6858f'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-0d57e7434a1fdeae9'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-06e226dfe7b1c0550'] ['c4.xlarge', '$143.28']
#
# ['us-east-1d', 'i-ce386fff'] ['m4.4xlarge', '$576.00']
#
# ['us-east-1a', 'i-c6a4a05f'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-049bf742ca97abbf6'] ['m4.2xlarge', '$288.00']
#
# ['us-east-1b', 'i-0b4525e83831d5e86'] ['m3.xlarge', '$123.12']
#
# ['us-east-1a', 'i-0ad7ddc40007a5941'] ['r3.2xlarge', '$478.80']
#
# ['us-east-1b', 'i-0e2549997c61f5231'] ['m3.xlarge', '$123.12']
#
# ['us-east-1b', 'i-0f4fddd1b9fa2d254'] ['m3.xlarge', '$150.48']
#
# ['us-east-1b', 'i-06d293bfcd0535898'] ['m3.xlarge', '$150.48']
#
# ['us-east-1a', 'i-0e2164a13338ccc82'] ['m4.large', '$72.00']
#
# ['us-east-1d', 'i-011b4083dcf557cdf'] ['t2.large', '$67.68']
#
# ['us-east-1a', 'i-03bd61d590e366986'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-5b0c98c8'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-0a686dd124d89f7d3'] ['m4.xlarge', '$144.00']
#
# ['us-east-1a', 'i-08d17523328f8af3e'] ['c4.xlarge', '$143.28']
#
# ['us-east-1d', 'i-0fb9d045a62b31b71'] ['i3.xlarge', '$224.64']
#
# ['us-east-1b', 'i-0cdae32e637e3525e'] ['m4.4xlarge', '$576.00']
#
# ['us-east-1a', 'i-09a80282049f8b47f'] ['m3.xlarge', '$191.52']
#
# ['us-east-1a', 'i-0fac2a31a5bdcc6a7'] ['m3.xlarge', '$191.52']
#
# ['us-east-1b', 'i-02efc819e724a5b92'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-2d0195be'] ['c4.xlarge', '$40.94']
#
# ['us-east-1b', 'i-610296f2'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-0058415be1060aee8'] ['m4.2xlarge', '$288.00']
#
# ['us-east-1a', 'i-212b7eb8'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-812e5612'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1b', 'i-0689c44c463537dfd'] ['m3.xlarge', '$136.80']
#
# ['us-east-1a', 'i-0a7bf540a078c0bae'] ['i3.xlarge', '$224.64']
#
# ['us-east-1a', 'i-044682d71bce0e1ff'] ['m4.xlarge', '$144.00']
#
# ['us-east-1b', 'i-c0265e53'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1b', 'i-025d418fa3650b53a'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-a5c2c53c'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1d', 'i-28e9de26'] ['m4.xlarge', '$144.00']
#
# ['us-east-1a', 'i-037e62280f4e25da7'] ['m4.xlarge', '$144.00']
#
# ['us-east-1b', 'i-0377468f57cc5c9b1'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1b', 'i-08c31ae5c7c272a3a'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-0871bbea411c3182c'] ['i3.xlarge', '$224.64']
#
# ['us-east-1b', 'i-b60c9825'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-0ef1b7cc8786fa741'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-74243963'] ['t2.small', '$7.10']
#
# ['us-east-1b', 'i-014af8b229a8cade1'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-016347d8ea8f2712f'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-0502666ad3180869f'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-015e3544aedbda83b'] ['m3.xlarge', '$191.52']
#
# ['us-east-1d', 'i-046ee4953b8b14fd4'] ['m4.2xlarge', '$288.00']
#
# ['us-east-1d', 'i-0d6d8a8af8ea1e0b5'] ['i3.xlarge', '$112.32']
#
# ['us-east-1b', 'i-f60e9a65'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-073f35f7c155c29f7'] ['m4.xlarge', '$144.00']
#
# ['us-east-1b', 'i-00807f77a4eec81fe'] ['i3.xlarge', '$208.59']
#
# ['us-east-1a', 'i-0950187d5fe23b596'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-05f120fb85eac961c'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1d', 'i-0fd5fc8efd804a7fe'] ['t2.micro', '$8.64']
#
# ['us-east-1b', 'i-05531b99339d74a42'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-09ee49e8e43cad3b2'] ['c4.xlarge', '$143.28']
#
# ['us-east-1d', 'i-03e8fdbc98123a879'] ['r3.2xlarge', '$478.80']
#
# ['us-east-1a', 'i-058568e8d9da0c4d6'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1b', 'i-ee0d997d'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-0365cc73768ff268f'] ['m4.2xlarge', '$288.00']
#
# ['us-west-2b', 'i-052da9ac27a7bdac4'] ['m4.4xlarge', '$576.00']
#
# ['us-east-1b', 'i-f70e9a64'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-014df0589411dd9fb'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-029486cfaafeeb88d'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1d', 'i-046f6293e1eb6f06c'] ['m4.2xlarge', '$288.00']
#
# ['us-west-2a', 'i-02aa31c42281f3550'] ['t2.medium', '$33.84']
#
# ['us-west-2a', 'i-0e56f60da39c4fe0c'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2b', 'i-089c1b958407cf6ae'] ['m4.xlarge', '$144.00']
#
# ['us-east-1a', 'i-09d063492976096e1'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-027327828a3c28b73'] ['c4.2xlarge', '$286.56']
#
# ['us-east-1a', 'i-0d05acbce9898392e'] ['m3.xlarge', '$191.52']
#
# ['us-east-1b', 'i-86067e15'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1d', 'i-c8acbf56'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1b', 'i-0af79d65fd2c8472b'] ['m3.xlarge', '$136.80']
#
# ['us-east-1b', 'i-05fbba97430ca3380'] ['m3.xlarge', '$123.12']
#
# ['us-east-1b', 'i-06ec2bd0fe95b2785'] ['m3.xlarge', '$136.80']
#
# ['us-east-1b', 'i-00c8ab6f8ecc73e54'] ['m3.xlarge', '$123.12']
#
# ['us-east-1b', 'i-07905f14b54b93e52'] ['m3.xlarge', '$136.80']
#
# ['us-east-1a', 'i-0eaf87c3413c5f486'] ['i3.xlarge', '$208.59']
#
# ['us-east-1a', 'i-0d184b41103bf5bfc'] ['c4.xlarge', '$143.28']
#
# ['us-east-1b', 'i-9a2e5609'] ['c3.4xlarge', '$604.80']
#
# ['us-east-1a', 'i-a4c2c53d'] ['c3.4xlarge', '$604.80']
#
# ['us-west-2c', 'i-02ac7975e05251574'] ['c4.xlarge', '$143.28']
#
# ['us-east-1a', 'i-014e1da81548a6cd8'] ['i3.xlarge', '$112.32']
#
# ['us-east-1b', 'i-05757b0d7b2b5eb78'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-0339b3cb9603cc2f1'] ['m4.large', '$72.00']
#
# ['us-west-2b', 'i-0986b2a2d4c31d0b9'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2c', 'i-0997df3be49c806e7'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0ee6cf32728cc0900'] ['t2.medium', '$33.84']
#
# ['us-west-2c', 'i-071a5696fa0b1913b'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-03dd4b19af57c684b'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2c', 'i-04bc8c29baed25c1f'] ['i3.4xlarge', '$898.56']
#
# ['us-west-2c', 'i-0f887e6cb53b01e66'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-09a7dbbb0a2b47753'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-00d3387e894689e56'] ['c4.xlarge', '$51.17']
#
# ['us-west-2a', 'i-0870f2f344806ed7c'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2a', 'i-06e2b22e8e477180d'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-00c2b7fff9ecbae49'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2b', 'i-08ccad0fb72f01083'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-0efe51ba445372078'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0cd2b5921232e99d0'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2a', 'i-045e3b234df617798'] ['c4.large', '$72.00']
#
# ['us-west-2b', 'i-0e910e2c7e217edd2'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2b', 'i-0847c92ac1b6ca764'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-025e162b2de0e3eee'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-014f3ae24b5a100c1'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-09d5a81bdc02ffb08'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-09967d3359b8eff93'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-0134cf6805f98e076'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-08bc321cbe5d53412'] ['c4.large', '$72.00']
#
# ['us-west-2c', 'i-03aa62615862b25ef'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0ff5181133854b422'] ['m4.large', '$72.00']
#
# ['us-west-2a', 'i-0c03712cd97304586'] ['m4.xlarge', '$144.00']
#
# ['us-west-2a', 'i-07c0c293001627a2d'] ['t2.medium', '$33.84']
#
# ['us-west-2a', 'i-0edaff618f4193ffc'] ['c4.large', '$72.00']
#
# ['us-west-2c', 'i-07e75149359dfc347'] ['c4.large', '$72.00']
#
# ['us-west-2a', 'i-0680b362ffe05c4e1'] ['c4.4xlarge', '$532.18']
#
# ['us-west-2b', 'i-0d4746b8ff75257c7'] ['m4.large', '$72.00']
#
# ['us-west-2a', 'i-0943872307994fccd'] ['m4.large', '$72.00']
#
# ['us-west-2c', 'i-0ea42c682adb3b9fb'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0ec5c3b065e018707'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-04504624c1685c0aa'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0f573a0a84a6a67a4'] ['c4.large', '$72.00']
#
# ['us-west-2c', 'i-0f5f76706a7a3a860'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-08bb11837872d91c2'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0c64bd52dfafdeab6'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2b', 'i-0ed0d3e91d30c480b'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0cb8acde50a16044a'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-07c7e042cadefa3e8'] ['m4.xlarge', '$133.71']
#
# ['us-west-2a', 'i-03dd80b5350991fc7'] ['r4.large', '$95.76']
#
# ['us-west-2a', 'i-0e33c9d8223cc7119'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-057c9a5b320da3f43'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0bfbc45cf750e7562'] ['m4.xlarge', '$82.29']
#
# ['us-west-2b', 'i-01191b43aa4beef61'] ['m4.4xlarge', '$164.57']
#
# ['us-west-2c', 'i-04d28ac91013f7c9b'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0b0462986cec6e7bb'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2a', 'i-01b9ef0166d994ae2'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-02bcf4e81f1603222'] ['m4.large', '$46.29']
#
# ['us-west-2b', 'i-0dbf97e8b122d085a'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0faf738c0cc6061a5'] ['c4.xlarge', '$112.58']
#
# ['us-west-2b', 'i-0d4784e8b40ee0fff'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-04e0327d7c5601860'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0f671138c5f5ba7f3'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-05edb97a2a45d3225'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-069fc94d0834884a1'] ['m4.xlarge', '$144.00']
#
# ['us-west-2b', 'i-0985d5934f2a8272e'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-09adadb0add921b2b'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2c', 'i-09123ce2013da7a37'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-05f72abd973f127f1'] ['c4.large', '$72.00']
#
# ['us-west-2b', 'i-0f75f7add94e03d4a'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-058056f5e12700d90'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2a', 'i-0be9c8912dca5a0f3'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0ad953271cbad4bd6'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-0969dcd37f6cf0890'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-056bc68ec6c7d1e2e'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-04335a1ad6c0a355b'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0e32dc0dafc3e268f'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-007d4d119d7608033'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0b19255b6279c42db'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0d75220c04b9a3ac1'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-013c0e5692770918e'] ['c4.4xlarge', '$532.18']
#
# ['us-west-2c', 'i-07f439eec64a501a8'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-052375186d58221dd'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0a07cb2c283588be2'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0ffa5c04a7c091380'] ['c4.large', '$72.00']
#
# ['us-west-2a', 'i-07ed6b95c9b7a8b92'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0f60a3d15dbc718af'] ['m4.xlarge', '$144.00']
#
# ['us-west-2c', 'i-08648d5b6971cf041'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0da1088a1d15db49b'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-026260f72b83ab667'] ['t2.medium', '$33.84']
#
# ['us-west-2a', 'i-0c68b1d939fc675c6'] ['c4.xlarge', '$112.58']
#
# ['us-west-2b', 'i-058869469318d0992'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-063b705133e314943'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-03e829c7fd700b399'] ['c4.4xlarge', '$368.43']
#
# ['us-west-2b', 'i-0a63624123a4fee34'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0bc2f40c8367e7240'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-04ce6c9efc00b01cd'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-05262fab32bf11520'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0d942928e40ae20a0'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0d0fa600e0adb5ad4'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-07f361ec1dc98277f'] ['m4.xlarge', '$51.43']
#
# ['us-west-2a', 'i-066649560c233ad9e'] ['c4.xlarge', '$112.58']
#
# ['us-west-2c', 'i-095e58c80eef0a12c'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-0e25225fe7ae058ee'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0cd5901fdff40af21'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0f002d50b5bdfdff9'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-02c7c26f8994d090c'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2b', 'i-088587472b75a3f50'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0efc964d9acc9e207'] ['c4.4xlarge', '$573.12']
#
# ['us-west-2a', 'i-06c3e3d93a9c8e269'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-0e546a3e85580aac7'] ['m4.xlarge', '$133.71']
#
# ['us-west-2b', 'i-0e63dbed3b6c96d91'] ['m4.xlarge', '$144.00']
#
# ['us-west-2b', 'i-08b6c4902d0efacbe'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-07184792c8bafe396'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-0ae5d44c401292693'] ['m4.large', '$72.00']
#
# ['us-west-2c', 'i-053458e95782bccb2'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0436a79f5e12672f4'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-089d429c38757cffa'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2b', 'i-07182a0a6c5c6c371'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0592703a4f64a7ac3'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-06d3345dbb6f261a8'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2b', 'i-030bc6b25f9f41dec'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0e750514f39d84b41'] ['m4.xlarge', '$144.00']
#
# ['us-west-2a', 'i-0b1872bcce7da5211'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2b', 'i-0746fd28b4109cf33'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-09da4bef5255342b8'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-016f3c2d4916503ef'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-07d27904dff5cdc52'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-065601faf60fbaa2a'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2b', 'i-05a5bd91d60f6bddb'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0f35c60e116c25d42'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0f34bc4ad5a719c26'] ['c4.large', '$72.00']
#
# ['us-west-2c', 'i-0b5325014db172209'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-089c6d287687f1332'] ['m4.xlarge', '$144.00']
#
# ['us-west-2a', 'i-081bc367e84815441'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2a', 'i-02d0cac2b1847ef61'] ['c4.4xlarge', '$573.12']
#
# ['us-west-2c', 'i-0a83ca11d96737122'] ['c4.large', '$72.00']
#
# ['us-west-2a', 'i-05963752ea552e923'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2b', 'i-0ab6bba5a0cedd932'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-04f9940c29c933270'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-07c71969191561877'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0bbce27595db5d117'] ['m4.large', '$72.00']
#
# ['us-west-2a', 'i-0f0593dc05fe5b676'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-020ad23d8a52367bc'] ['t2.medium', '$33.84']
#
# ['us-west-2c', 'i-0b97bdcbdf3823ddf'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-071de42bb2c8c69dd'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2c', 'i-00709f796eb0b0471'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-08bef5fd2f8c1c0a0'] ['t2.micro', '$8.64']
#
# ['us-west-2a', 'i-07619dabc844ea306'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-064d4023e807549df'] ['c4.large', '$72.00']
#
# ['us-west-2c', 'i-024e21118b4208d25'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-062868d44ab2a7ac1'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0f19de67ef19b3e32'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0b4f660b2b3286954'] ['c4.xlarge', '$112.58']
#
# ['us-west-2c', 'i-05a24e11e032c0f85'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-06e9d553a17db4f41'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2c', 'i-0ce4b715059551b4e'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-00e93d2827673eb81'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-08081679b27436cc5'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-057990f6bb7e8da83'] ['m4.xlarge', '$144.00']
#
# ['us-west-2c', 'i-018cc0dff0abcc7da'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0386a676394919e78'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-057160c87626a8bb7'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0fa773bc9f501510c'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0e1514f8de48a2b15'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-09efd6106efebe319'] ['t2.medium', '$33.84']
#
# ['us-west-2c', 'i-094ab56633cdf36b3'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-07ed9a6df57fafe27'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2a', 'i-097ea81d86821a23d'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2a', 'i-0b6c03313be7029f9'] ['m4.large', '$72.00']
#
# ['us-west-2b', 'i-06fbc38a2d3f04217'] ['i2.xlarge', '$438.69']
#
# ['us-west-2b', 'i-06c223af38a264370'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-07d63fcd3ed607ad0'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-050ef66a44e6c0ef2'] ['m4.xlarge', '$133.71']
#
# ['us-west-2c', 'i-01cd44ef8796db602'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-08c245f9f6ca739cb'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-0169ed797638df54a'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-05a54d8acf5ed454d'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0070e746654b89b84'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0be778b1e164990b6'] ['i2.xlarge', '$394.82']
#
# ['us-west-2c', 'i-0e2b3aba77e03919e'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2a', 'i-062480bb4d7e9d528'] ['r4.large', '$95.76']
#
# ['us-west-2a', 'i-0324d0e5e8ffac0a8'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0a9e5a52afb2541c5'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-08a822b2e0437cf0f'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-0d0d7695d0d313b9b'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2c', 'i-01623212b4f09d315'] ['c4.xlarge', '$143.28']
#
# ['us-west-2c', 'i-00a408a0719c0e5f8'] ['m4.xlarge', '$133.71']
#
# ['us-west-2a', 'i-0901b767f0688e21b'] ['t2.medium', '$33.84']
#
# ['us-west-2b', 'i-0cca86f6367894bae'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0644d7ce3fd34ac1c'] ['m4.4xlarge', '$164.57']
#
# ['us-west-2b', 'i-04672d63c22ccf398'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-04dd1b3446d09d42e'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-0130bd4dd18e6d454'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0c6da90e44073fa61'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0b21036a62bb8c15b'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2a', 'i-09693da91e4b48924'] ['c4.xlarge', '$112.58']
#
# ['us-west-2c', 'i-0eef23416ad0bc235'] ['m4.xlarge', '$133.71']
#
# ['us-west-2b', 'i-0e06a4028aba142f8'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0e1279e2468a761f0'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-0968e78091fa22a9e'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-027a6ee33c4195cfe'] ['m4.large', '$72.00']
#
# ['us-west-2b', 'i-09595d133b3aa414f'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-021d8edb75f24cf3d'] ['i2.xlarge', '$438.69']
#
# ['us-west-2c', 'i-0adbda33e7af57464'] ['m4.xlarge', '$144.00']
#
# ['us-west-2c', 'i-05bff8c0774270e7b'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2a', 'i-0ecd40787b9b666b7'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2a', 'i-0e4851b99203dfd38'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2c', 'i-079c6439572c3dc8d'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2a', 'i-0319137377b855c09'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2c', 'i-027abbd572db684eb'] ['m4.4xlarge', '$452.57']
#
# ['us-west-2a', 'i-05e469826ac040b59'] ['m4.4xlarge', '$576.00']
#
# ['us-west-2c', 'i-05e1e56dda75b13c6'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-0d54e9c0569920289'] ['c4.xlarge', '$143.28']
#
# ['us-west-2b', 'i-002540052279ee66d'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-07abd2d3f879ca525'] ['c4.large', '$72.00']
#
# ['us-west-2c', 'i-0717a93f09aa3e5e4'] ['c4.xlarge', '$143.28']
#
# ['us-west-2a', 'i-047acb4371d2800f7'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2a', 'i-04395870150b6739c'] ['c4.2xlarge', '$286.56']
#
# ['us-west-2b', 'i-04c9cb74f423207c9'] ['c4.2xlarge', '$286.56']

# %%
newdf = awsdf.iloc[0:,:5]
newdf
# Out:
#     Low Utilization Amazon EC2 Instances           Unnamed: 1  \
# 9                              Region/AZ          Instance ID
# 10                            us-east-1b  i-0b8c413d9408beffd
# 11                            us-east-1b  i-04273cd6ba4f96e13
# 12                            us-east-1b  i-06fdd339e4dd0c201
# 13                            us-east-1b  i-0ea7b16baee2b6a4e
# 14                            us-east-1b  i-0799accd01f99ced4
# 15                            us-east-1a  i-06d31cee3dda4deef
# 16                            us-east-1b  i-09cbdb36893061df2
# 17                            us-east-1a  i-07fb4f02d91195d15
# 18                            us-east-1a  i-0d1479acf8da50b79
# 19                            us-east-1d           i-05796685
# 20                            us-east-1a  i-08e131de99f5df529
# 21                            us-east-1a           i-1ba68582
# 22                            us-east-1a  i-0d7c1335eb078fbbc
# 23                            us-east-1a           i-ff2b7e66
# 24                            us-east-1a  i-0ea5aae11f2dff98b
# 25                            us-east-1a  i-0fb195dc77040aefd
# 26                            us-east-1a  i-046db2ec47a78e978
# 27                            us-east-1d  i-063b159a3eb19859a
# 28                            us-east-1b  i-0e67624235981119f
# 29                            us-east-1a  i-082b2f013ad943078
# 30                            us-east-1a  i-01ab0b254fc3b4d27
# 31                            us-east-1a  i-0fa419f85c5953797
# 32                            us-east-1a  i-010d1716f2e866436
# 33                            us-east-1d  i-0635ef4116afb19cb
# 34                            us-east-1b  i-0bc83aa3c255e5aa5
# 35                            us-east-1d  i-050c27614d0ee1ab3
# 36                            us-east-1a  i-0a4f2943e5c3387a5
# 37                            us-east-1a  i-088b01b14287e5abf
# 38                            us-east-1b           i-972e5604
# ..                                   ...                  ...
# 375                           us-west-2b  i-0644d7ce3fd34ac1c
# 376                           us-west-2b  i-04672d63c22ccf398
# 377                           us-west-2b  i-04dd1b3446d09d42e
# 378                           us-west-2b  i-0130bd4dd18e6d454
# 379                           us-west-2b  i-0c6da90e44073fa61
# 380                           us-west-2a  i-0b21036a62bb8c15b
# 381                           us-west-2a  i-09693da91e4b48924
# 382                           us-west-2c  i-0eef23416ad0bc235
# 383                           us-west-2b  i-0e06a4028aba142f8
# 384                           us-west-2a  i-0e1279e2468a761f0
# 385                           us-west-2a  i-0968e78091fa22a9e
# 386                           us-west-2a  i-027a6ee33c4195cfe
# 387                           us-west-2b  i-09595d133b3aa414f
# 388                           us-west-2a  i-021d8edb75f24cf3d
# 389                           us-west-2c  i-0adbda33e7af57464
# 390                           us-west-2c  i-05bff8c0774270e7b
# 391                           us-west-2a  i-0ecd40787b9b666b7
# 392                           us-west-2a  i-0e4851b99203dfd38
# 393                           us-west-2c  i-079c6439572c3dc8d
# 394                           us-west-2a  i-0319137377b855c09
# 395                           us-west-2c  i-027abbd572db684eb
# 396                           us-west-2a  i-05e469826ac040b59
# 397                           us-west-2c  i-05e1e56dda75b13c6
# 398                           us-west-2b  i-0d54e9c0569920289
# 399                           us-west-2b  i-002540052279ee66d
# 400                           us-west-2a  i-07abd2d3f879ca525
# 401                           us-west-2c  i-0717a93f09aa3e5e4
# 402                           us-west-2a  i-047acb4371d2800f7
# 403                           us-west-2a  i-04395870150b6739c
# 404                           us-west-2b  i-04c9cb74f423207c9
#
#                                             Unnamed: 2     Unnamed: 3  \
# 9                                        Instance Name  Instance Type
# 10                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 11                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 12                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 13                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 14                            Quark-Dev-Testing-stgvpc      m3.xlarge
# 15                    cbelkdata-e1a-01s.cb.comcast.net      i3.xlarge
# 16                    odprabbit-e1b-01.odp.comcast.net      c4.xlarge
# 17                                    cb-puppet-master      t2.xlarge
# 18                          new-dev-elk-master-node-1a     m4.2xlarge
# 19                                     Cassandra-dev-2     c3.4xlarge
# 20                   odpcworker-e1a-02.odp.comcast.net     c4.2xlarge
# 21                        cbapi-e1a-04s.cb.comcast.net      c4.xlarge
# 22                    odprabbit-e1a-03.odp.comcast.net      c4.xlarge
# 23                         cbapi-e1a-02.cb.comcast.net      c4.xlarge
# 24                   odpcworker-e1a-01.odp.comcast.net     c4.2xlarge
# 25                   cbelkweb-e1a-01stg.cb.comcast.net       m4.large
# 26                     odpredis-e1a-03.odp.comcast.net      c4.xlarge
# 27                                         django_test       m4.large
# 28                                      CB-STG-NODE-1B     m4.4xlarge
# 29                   odpcworker-e1a-03.odp.comcast.net     c4.2xlarge
# 30                      odpsync-e1a-06.odp.comcast.net      c4.xlarge
# 31                             Netscout Kpi hourly dev      m3.xlarge
# 32                    odprabbit-e1a-02.odp.comcast.net      c4.xlarge
# 33                                    django_exec2_STG      m4.xlarge
# 34                     odpredis-e1b-01.odp.comcast.net      c4.xlarge
# 35                                          Django STG     m4.2xlarge
# 36                                                 NaN      m3.xlarge
# 37                      odpsync-e1a-01.odp.comcast.net      c4.xlarge
# 38                          cbdb-e1b-05.cb.comcast.net     c3.4xlarge
# ..                                                 ...            ...
# 375                    odpsprkw-w2b-09.odp.comcast.net     m4.4xlarge
# 376                     odphook-w2b-04.odp.comcast.net     c4.2xlarge
# 377                  odpcworker-w2b-01.odp.comcast.net     c4.2xlarge
# 378                       odplb-w2b-04.odp.comcast.net      c4.xlarge
# 379  optimizer-chi-01.prod.us-west-2.plume.comcast.net      c4.xlarge
# 380                    odpsprkw-w2a-01.odp.comcast.net     m4.4xlarge
# 381                      odpque-w2a-04.odp.comcast.net      c4.xlarge
# 382   rabbitmq-chi-03.prod.us-west-2.plume.comcast.net      m4.xlarge
# 383                       odplb-w2b-02.odp.comcast.net      c4.xlarge
# 384                      odpzoo-w2a-02.odp.comcast.net      c4.xlarge
# 385                     odpsync-w2a-05.odp.comcast.net     c4.2xlarge
# 386  mongodb-production-04.shared.us-west-2.plume.c...       m4.large
# 387                     odpsync-w2b-03.odp.comcast.net     c4.2xlarge
# 388    es-es-esdata-02.inf.us-west-2.plume.comcast.net      i2.xlarge
# 389  controllershardv2-chi-02.prod.us-west-2.plume....      m4.xlarge
# 390                    odpsprkw-w2c-10.odp.comcast.net     m4.4xlarge
# 391                    odpsprkw-w2a-05.odp.comcast.net     m4.4xlarge
# 392                     odpcore-w2a-05.odp.comcast.net     c4.2xlarge
# 393                    odpsprkw-w2c-13.odp.comcast.net     m4.4xlarge
# 394                    odpsprkw-w2a-12.odp.comcast.net     m4.4xlarge
# 395                    odpsprkw-w2c-06.odp.comcast.net     m4.4xlarge
# 396                    odpsprkw-w2a-09.odp.comcast.net     m4.4xlarge
# 397                       odplb-w2c-01.odp.comcast.net      c4.xlarge
# 398                    odpredis-w2b-02.odp.comcast.net      c4.xlarge
# 399                     odpcore-w2b-07.odp.comcast.net     c4.2xlarge
# 400  rabbitmq-production-01.shared.us-west-2.plume....       c4.large
# 401                       odplb-w2c-03.odp.comcast.net      c4.xlarge
# 402                     odpsync-w2a-01.odp.comcast.net     c4.2xlarge
# 403                     odpcore-w2a-08.odp.comcast.net     c4.2xlarge
# 404                     odpcore-w2b-05.odp.comcast.net     c4.2xlarge
#
#                     Unnamed: 4
# 9    Estimated Monthly Savings
# 10                     $136.80
# 11                     $136.80
# 12                     $136.80
# 13                     $123.12
# 14                     $136.80
# 15                     $224.64
# 16                     $143.28
# 17                     $135.36
# 18                     $288.00
# 19                     $604.80
# 20                     $286.56
# 21                     $143.28
# 22                     $143.28
# 23                      $40.94
# 24                     $286.56
# 25                      $72.00
# 26                     $143.28
# 27                      $72.00
# 28                     $576.00
# 29                     $286.56
# 30                     $143.28
# 31                     $191.52
# 32                     $143.28
# 33                     $144.00
# 34                     $143.28
# 35                     $288.00
# 36                     $191.52
# 37                     $143.28
# 38                     $172.80
# ..                         ...
# 375                    $164.57
# 376                    $286.56
# 377                    $286.56
# 378                    $143.28
# 379                    $143.28
# 380                    $576.00
# 381                    $112.58
# 382                    $133.71
# 383                    $143.28
# 384                    $143.28
# 385                    $286.56
# 386                     $72.00
# 387                    $286.56
# 388                    $438.69
# 389                    $144.00
# 390                    $452.57
# 391                    $576.00
# 392                    $286.56
# 393                    $452.57
# 394                    $576.00
# 395                    $452.57
# 396                    $576.00
# 397                    $143.28
# 398                    $143.28
# 399                    $286.56
# 400                     $72.00
# 401                    $143.28
# 402                    $286.56
# 403                    $286.56
# 404                    $286.56
#
# [396 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(211)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title
# Out:
# /usr/local/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# Text(0.5,1,'Easy as 1, 2, 3')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
#plt.title('Histogram of IQ')
plt.title(r'$\sigma_i=15$')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.tan(3*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.ylim(-2,2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# Fixing random state for reproducibility
np.random.seed(19680801)

# make up some data in the interval ]0, 1[
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))

# plot with various axes scales
plt.figure(1)

# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)


# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)


# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.01)
plt.title('symlog')
plt.grid(True)

# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Format the minor tick labels of the y-axis into empty strings with
# `NullFormatter`, to avoid cumbering the axis with too many labels.
plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()
