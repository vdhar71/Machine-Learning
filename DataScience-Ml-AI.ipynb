# %%
"""Intela Solutions 
   Open Data Science
   https://www.intel-edu.com/en/
   https://www.intela.io
   Phone: +1 (866) 7INTELA (746-8352)
   Email: info@intela-edu.com
   Instructors: Joseph Santarcangelo, Ph.D. Data Scientist, IBM"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import geopy
from PIL import Image
# %matplotlib inline

# %%
# %matplotlib inline

# %%
lat=12.9716
long=77.5946
blr = folium.Map(location=[lat,long],zoom_start=15)
blr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
lat=16.21
long=77.34
rcr = folium.Map(location=[lat,long])
rcr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopy 
from geopy.geocoders import Nominatim

geolocator = Nominatim()
addr='6305 Bancroft way San Jose CA 95129'
bancroft = geolocator.geocode(addr)
print(bancroft.raw)
ll=[bancroft.latitude,bancroft.longitude]
ll
# Out:
# {'place_id': '186781809', 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://www.openstreetmap.org/copyright', 'osm_type': 'way', 'osm_id': '8968147', 'boundingbox': ['37.3036712469', '37.3037712469', '-122.01531686889', '-122.01521686889'], 'lat': '37.3037212469001', 'lon': '-122.015266868891', 'display_name': '6305, Bancroft Way, San José, Santa Clara County, California, 95129, United States of America', 'class': 'place', 'type': 'house', 'importance': 0.62025}
# [37.3037212469001, -122.015266868891]

# %%
lat=37.3037712469
long=-122.01531686889
bancroft = folium.Map(location=ll,zoom_start=10)
bancroft
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# create 1000 equally spaced points between -10 and 10
x = np.linspace(-20, 20, 10000)

# calculate the y value for each element of the x vector
pi=22/7
y = -2*(x**2) + 2*x +5


fig, ax = plt.subplots()
ax.plot(x, y)

# %%
t = np.arange(0.0, 2.0, 0.01)  
s = np.sin(2*np.pi*t)  
plt.plot(t, s)  

plt.xlabel('time (s)')  
plt.ylabel('voltage (mV)')  
plt.title('voltage (mV) vs. time (sec)')   
plt.grid(True)  
#plt.savefig("plot-voltage-vs.-time.png")  
plt.show()

# %%
t = np.arange(-2.0, 2.0, 0.01)  
s = np.cos(2*np.pi*t)  
plt.plot(t, s)  

plt.xlabel('time (s)')  
plt.ylabel('voltage (mV)')  
plt.title('voltage (mV) vs. time (sec)')   
plt.grid(True)  
#plt.savefig("plot-voltage-vs.-time.png")  
plt.show()

# %%
theta=np.arange(-1*np.pi,np.pi,0.1)
thresh=10000
plt.plot(np.tan(theta),)

# %%
a=np.arange(2,20,0.1)
b= 4*a*np.pi/6
b
c=np.cos(b)
c
plt.plot(b,c)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z, color='g')

plt.show()

# %%
np.linspace
